# %% [markdown]
# <a href="https://colab.research.google.com/github/zhulkhoirrifat/nuka-pos/blob/main/TimeSeriesElektronik.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install keras_tuner
# Out:
# Requirement already satisfied: keras_tuner in /usr/local/lib/python3.11/dist-packages (1.4.7)
# Requirement already satisfied: keras in /usr/local/lib/python3.11/dist-packages (from keras_tuner) (3.8.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from keras_tuner) (24.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from keras_tuner) (2.32.3)
# Requirement already satisfied: kt-legacy in /usr/local/lib/python3.11/dist-packages (from keras_tuner) (1.0.5)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from keras->keras_tuner) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from keras->keras_tuner) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras->keras_tuner) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras->keras_tuner) (0.0.9)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from keras->keras_tuner) (3.13.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras->keras_tuner) (0.15.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.11/dist-packages (from keras->keras_tuner) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->keras_tuner) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->keras_tuner) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->keras_tuner) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->keras_tuner) (2025.4.26)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from optree->keras->keras_tuner) (4.13.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras->keras_tuner) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras->keras_tuner) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras->keras_tuner) (0.1.2)

# %% [markdown]
# ## Import Library
#
# Langkah pertama adalah mengimpor library yang dibutuhkan untuk proses data dan machine learning.
#
# - `pandas` dan `numpy` untuk manipulasi data
# - `matplotlib` dan `seaborn` untuk visualisasi
# - `sklearn` untuk preprocessing dan model ML

# %%
import os
import holidays
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split, GridSearchCV, TimeSeriesSplit
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

import keras_tuner as kt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Bidirectional, LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import R2Score, MeanSquaredError, MeanAbsoluteError

# %% [markdown]
# ## Load dan Persiapan Data
#
# Dataset diambil dari file CSV. Setelah itu, dilakukan pengecekan awal seperti:
# - Menampilkan 5 data teratas
# - Melihat tipe data dan jumlah missing values
# - Menampilkan statistik deskriptif
# - Menghapus kolom yang tidak relevan
# - Mengubah tipe data jika diperlukan

# %%
products_df = pd.read_csv('products.csv')
transactions_df = pd.read_csv('transactions.csv')
transaction_details_df = pd.read_csv('transaction_details.csv')
stores_df = pd.read_csv('stores.csv')

# %%
transactions_df = transactions_df.rename(columns={
    'discount': 'discountPerson',
    'status': 'statusTransaction'
})
products_df = products_df.rename(columns={
    'name': 'productName',
    'description': 'descriptionProduct',
    'discount': 'productDiscount'
})
stores_df = stores_df.rename(columns={
    'name': 'storeName',
    'description': 'storeDescription',
    'status': 'storeStatus'
})

# %%
transactions_transaction_details_merge = pd.merge(
    transactions_df,
    transaction_details_df,
    on='transactionId',
    how='left'
)

transactions_products_merge = pd.merge(
    transactions_transaction_details_merge,
    products_df,
    on='productId',
    how='left'
)

final_df = pd.merge(
    transactions_products_merge,
    stores_df,
    on='storeId',
    how='left'
)

# %%
final_df.columns
# Out:
# Index(['transactionId', 'invoiceId', 'customerId', 'userId', 'storeId',
#        'paymentMethodId', 'totalAmount', 'cash', 'change', 'discountPerson',
#        'transactionDate', 'statusTransaction', 'transactionDetailId',
#        'productId', 'variantId', 'quantity', 'subtotal', 'productCode',
#        'serialNumber', 'categoryId', 'productName', 'descriptionProduct',
#        'productDiscount', 'basePrice', 'imageUrl', 'isActive', 'StoreCode',
#        'tenantId', 'storeName', 'address', 'email', 'image', 'provinceId',
#        'cityId', 'districtId', 'villageId', 'storeTypeId', 'postalCode',
#        'storeDescription', 'phoneNumber', 'logo', 'permitCertificate',
#        'storeStatus'],
#       dtype='object')

# %%
final_df
# Out:
#         transactionId         invoiceId  customerId  userId  storeId  \
# 0                   1  INV-872171080156      2747.0      62        1
# 1                   1  INV-872171080156      2747.0      62        1
# 2                   2  INV-763345515943       728.0      93        1
# 3                   3  INV-605821091171       870.0      93        1
# 4                   4  INV-411881317458       576.0      93        1
# ...               ...               ...         ...     ...      ...
# 863741         719918  INV-356748409675         NaN      85       30
# 863742         719918  INV-356748409675         NaN      85       30
# 863743         719919  INV-147944059303      4440.0     141       30
# 863744         719920  INV-136116470389       553.0     141       30
# 863745         719920  INV-136116470389       553.0     141       30
#
#         paymentMethodId  totalAmount           cash      change  \
# 0                     4    200000.00  200433.016175  433.016175
# 1                     4    200000.00  200433.016175  433.016175
# 2                     5    200000.00  200976.280882  976.280882
# 3                     1     31300.04   31967.037563  666.997563
# 4                     4     41220.04   41872.546596  652.506596
# ...                 ...          ...            ...         ...
# 863741                4    100000.00  100948.727097  948.727097
# 863742                4    100000.00  100948.727097  948.727097
# 863743                1    100000.00  100327.066901  327.066901
# 863744                7    100000.00  100947.831102  947.831102
# 863745                7    100000.00  100947.831102  947.831102
#
#         discountPerson  ... cityId districtId  villageId  storeTypeId  \
# 0                    0  ...     71       5579      62968            9
# 1                    0  ...     71       5579      62968            9
# 2                    5  ...     71       5579      62968            9
# 3                    5  ...     71       5579      62968            9
# 4                   10  ...     71       5579      62968            9
# ...                ...  ...    ...        ...        ...          ...
# 863741               0  ...     71       5579      62968           12
# 863742               0  ...     71       5579      62968           12
# 863743               0  ...     71       5579      62968           12
# 863744               0  ...     71       5579      62968           12
# 863745               0  ...     71       5579      62968           12
#
#         postalCode                                   storeDescription  \
# 0            35215  Facere eos dignissimos architecto dolor laboru...
# 1            35215  Facere eos dignissimos architecto dolor laboru...
# 2            35215  Facere eos dignissimos architecto dolor laboru...
# 3            35215  Facere eos dignissimos architecto dolor laboru...
# 4            35215  Facere eos dignissimos architecto dolor laboru...
# ...            ...                                                ...
# 863741        2970  Blanditiis repudiandae eius excepturi. Totam m...
# 863742        2970  Blanditiis repudiandae eius excepturi. Totam m...
# 863743        2970  Blanditiis repudiandae eius excepturi. Totam m...
# 863744        2970  Blanditiis repudiandae eius excepturi. Totam m...
# 863745        2970  Blanditiis repudiandae eius excepturi. Totam m...
#
#          phoneNumber                            logo  \
# 0       628143540196  https://dummyimage.com/638x822
# 1       628143540196  https://dummyimage.com/638x822
# 2       628143540196  https://dummyimage.com/638x822
# 3       628143540196  https://dummyimage.com/638x822
# 4       628143540196  https://dummyimage.com/638x822
# ...              ...                             ...
# 863741  628582519226  https://placekitten.com/78/988
# 863742  628582519226  https://placekitten.com/78/988
# 863743  628582519226  https://placekitten.com/78/988
# 863744  628582519226  https://placekitten.com/78/988
# 863745  628582519226  https://placekitten.com/78/988
#
#                      permitCertificate  storeStatus
# 0        https://picsum.photos/923/384       ACTIVE
# 1        https://picsum.photos/923/384       ACTIVE
# 2        https://picsum.photos/923/384       ACTIVE
# 3        https://picsum.photos/923/384       ACTIVE
# 4        https://picsum.photos/923/384       ACTIVE
# ...                                ...          ...
# 863741  https://placekitten.com/715/72       ACTIVE
# 863742  https://placekitten.com/715/72       ACTIVE
# 863743  https://placekitten.com/715/72       ACTIVE
# 863744  https://placekitten.com/715/72       ACTIVE
# 863745  https://placekitten.com/715/72       ACTIVE
#
# [863746 rows x 43 columns]

# %%
store_type_id = 4
final_df = final_df[final_df['storeTypeId'] == store_type_id]
final_df
# Out:
#         transactionId         invoiceId  customerId  userId  storeId  \
# 73151           61105  INV-217517280966       316.0      88        6
# 73152           61106  INV-282544940715      2103.0     101        6
# 73153           61107  INV-688772587697         NaN      90        6
# 73154           61108  INV-559904833185      2645.0      90        6
# 73155           61109  INV-103170649847      3091.0      75        6
# ...               ...               ...         ...     ...      ...
# 280363         233603  INV-201974116568      2201.0     104       10
# 280364         233604  INV-406188404986      4049.0      94       10
# 280365         233604  INV-406188404986      4049.0      94       10
# 280366         233605  INV-334509460705      6048.0     104       10
# 280367         233606  INV-992101192883      1311.0      94       10
#
#         paymentMethodId  totalAmount           cash      change  \
# 73151                 7    800000.00  800394.292860  394.292860
# 73152                 1    100896.24  101139.314063  243.074063
# 73153                 5    800000.00  800076.266008   76.266008
# 73154                 3    100589.68  101110.866418  521.186418
# 73155                 2    800000.00  800000.000000    0.000000
# ...                 ...          ...            ...         ...
# 280363                1    800000.00  800271.848272  271.848272
# 280364                5    800000.00  800950.361994  950.361994
# 280365                5    800000.00  800950.361994  950.361994
# 280366                4     40062.40   41052.926623  990.526623
# 280367                5    800000.00  800731.212174  731.212174
#
#         discountPerson  ... cityId districtId  villageId  storeTypeId  \
# 73151               10  ...     71       5579      62968            4
# 73152                5  ...     71       5579      62968            4
# 73153                5  ...     71       5579      62968            4
# 73154                5  ...     71       5579      62968            4
# 73155                0  ...     71       5579      62968            4
# ...                ...  ...    ...        ...        ...          ...
# 280363               0  ...     71       5783      61366            4
# 280364               5  ...     71       5783      61366            4
# 280365               5  ...     71       5783      61366            4
# 280366               0  ...     71       5783      61366            4
# 280367               0  ...     71       5783      61366            4
#
#         postalCode                                   storeDescription  \
# 73151        34729  Ipsam accusamus molestiae delectus molestias m...
# 73152        34729  Ipsam accusamus molestiae delectus molestias m...
# 73153        34729  Ipsam accusamus molestiae delectus molestias m...
# 73154        34729  Ipsam accusamus molestiae delectus molestias m...
# 73155        34729  Ipsam accusamus molestiae delectus molestias m...
# ...            ...                                                ...
# 280363       27257  Debitis provident saepe quae. Assumenda amet s...
# 280364       27257  Debitis provident saepe quae. Assumenda amet s...
# 280365       27257  Debitis provident saepe quae. Assumenda amet s...
# 280366       27257  Debitis provident saepe quae. Assumenda amet s...
# 280367       27257  Debitis provident saepe quae. Assumenda amet s...
#
#          phoneNumber                           logo  \
# 73151   628188553051  https://picsum.photos/796/928
# 73152   628188553051  https://picsum.photos/796/928
# 73153   628188553051  https://picsum.photos/796/928
# 73154   628188553051  https://picsum.photos/796/928
# 73155   628188553051  https://picsum.photos/796/928
# ...              ...                            ...
# 280363  628883143342  https://picsum.photos/575/237
# 280364  628883143342  https://picsum.photos/575/237
# 280365  628883143342  https://picsum.photos/575/237
# 280366  628883143342  https://picsum.photos/575/237
# 280367  628883143342  https://picsum.photos/575/237
#
#                      permitCertificate  storeStatus
# 73151   https://dummyimage.com/107x409       ACTIVE
# 73152   https://dummyimage.com/107x409       ACTIVE
# 73153   https://dummyimage.com/107x409       ACTIVE
# 73154   https://dummyimage.com/107x409       ACTIVE
# 73155   https://dummyimage.com/107x409       ACTIVE
# ...                                ...          ...
# 280363  https://dummyimage.com/432x974       ACTIVE
# 280364  https://dummyimage.com/432x974       ACTIVE
# 280365  https://dummyimage.com/432x974       ACTIVE
# 280366  https://dummyimage.com/432x974       ACTIVE
# 280367  https://dummyimage.com/432x974       ACTIVE
#
# [33895 rows x 43 columns]

# %%
final_df['storeId'].value_counts()
# Out:
# storeId
# 6     22331
# 10    11564
# Name: count, dtype: int64

# %%
checked = final_df[final_df['storeId'] == 10]

checked.hist(bins=50, figsize=(20, 15))
plt.show()

# %%
final_df = final_df[final_df['storeId'] == 6]

# %%
numeric_columns = final_df.select_dtypes(include='number').columns

plt.figure(figsize=(15, 5 * len(numeric_columns)))

for index, column in enumerate(numeric_columns, 1):
    plt.subplot(len(numeric_columns), 1, index)
    sns.boxplot(x=final_df[column])
    plt.title(f'Boxplot kolom: {column}')
    plt.tight_layout()

plt.show()

# %%
def detect_outliers_iqr(data):
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return (data < lower_bound) | (data > upper_bound)

outliers = detect_outliers_iqr(final_df['totalAmount'])

print(f"Number of outliers detected: {sum(outliers)}")
# Out:
# Number of outliers detected: 0

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

ax1.scatter(range(len(final_df)), final_df['totalAmount'], c=['blue' if not x else 'red' for x in outliers])
ax1.set_title('Outlier pada totalAmount (Scatter Plot)')
ax1.set_xlabel('Index')
ax1.set_ylabel('Value')

sns.boxplot(x=final_df['totalAmount'], ax=ax2)
ax2.set_title('Outlier pada totalAmount (Box Plot)')
ax2.set_xlabel('Value')

plt.tight_layout()
plt.show()

# %%
final_df['transactionDate'] = pd.to_datetime(final_df['transactionDate'])
# Out:
# <ipython-input-74-0ea110b0c623>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['transactionDate'] = pd.to_datetime(final_df['transactionDate'])

# %%
final_df
# Out:
#        transactionId         invoiceId  customerId  userId  storeId  \
# 73151          61105  INV-217517280966       316.0      88        6
# 73152          61106  INV-282544940715      2103.0     101        6
# 73153          61107  INV-688772587697         NaN      90        6
# 73154          61108  INV-559904833185      2645.0      90        6
# 73155          61109  INV-103170649847      3091.0      75        6
# ...              ...               ...         ...     ...      ...
# 95477          79652  INV-542041958670      2353.0     101        6
# 95478          79653  INV-696197647137         NaN      75        6
# 95479          79653  INV-696197647137         NaN      75        6
# 95480          79654  INV-611771844011         NaN      75        6
# 95481          79654  INV-611771844011         NaN      75        6
#
#        paymentMethodId  totalAmount           cash      change  \
# 73151                7    800000.00  800394.292860  394.292860
# 73152                1    100896.24  101139.314063  243.074063
# 73153                5    800000.00  800076.266008   76.266008
# 73154                3    100589.68  101110.866418  521.186418
# 73155                2    800000.00  800000.000000    0.000000
# ...                ...          ...            ...         ...
# 95477                7    800000.00  800758.773251  758.773251
# 95478                1    800000.00  800419.625102  419.625102
# 95479                1    800000.00  800419.625102  419.625102
# 95480                4    209517.28  209727.428659  210.148659
# 95481                4    209517.28  209727.428659  210.148659
#
#        discountPerson  ... cityId districtId  villageId  storeTypeId  \
# 73151              10  ...     71       5579      62968            4
# 73152               5  ...     71       5579      62968            4
# 73153               5  ...     71       5579      62968            4
# 73154               5  ...     71       5579      62968            4
# 73155               0  ...     71       5579      62968            4
# ...               ...  ...    ...        ...        ...          ...
# 95477               0  ...     71       5579      62968            4
# 95478              10  ...     71       5579      62968            4
# 95479              10  ...     71       5579      62968            4
# 95480               0  ...     71       5579      62968            4
# 95481               0  ...     71       5579      62968            4
#
#        postalCode                                   storeDescription  \
# 73151       34729  Ipsam accusamus molestiae delectus molestias m...
# 73152       34729  Ipsam accusamus molestiae delectus molestias m...
# 73153       34729  Ipsam accusamus molestiae delectus molestias m...
# 73154       34729  Ipsam accusamus molestiae delectus molestias m...
# 73155       34729  Ipsam accusamus molestiae delectus molestias m...
# ...           ...                                                ...
# 95477       34729  Ipsam accusamus molestiae delectus molestias m...
# 95478       34729  Ipsam accusamus molestiae delectus molestias m...
# 95479       34729  Ipsam accusamus molestiae delectus molestias m...
# 95480       34729  Ipsam accusamus molestiae delectus molestias m...
# 95481       34729  Ipsam accusamus molestiae delectus molestias m...
#
#         phoneNumber                           logo  \
# 73151  628188553051  https://picsum.photos/796/928
# 73152  628188553051  https://picsum.photos/796/928
# 73153  628188553051  https://picsum.photos/796/928
# 73154  628188553051  https://picsum.photos/796/928
# 73155  628188553051  https://picsum.photos/796/928
# ...             ...                            ...
# 95477  628188553051  https://picsum.photos/796/928
# 95478  628188553051  https://picsum.photos/796/928
# 95479  628188553051  https://picsum.photos/796/928
# 95480  628188553051  https://picsum.photos/796/928
# 95481  628188553051  https://picsum.photos/796/928
#
#                     permitCertificate  storeStatus
# 73151  https://dummyimage.com/107x409       ACTIVE
# 73152  https://dummyimage.com/107x409       ACTIVE
# 73153  https://dummyimage.com/107x409       ACTIVE
# 73154  https://dummyimage.com/107x409       ACTIVE
# 73155  https://dummyimage.com/107x409       ACTIVE
# ...                               ...          ...
# 95477  https://dummyimage.com/107x409       ACTIVE
# 95478  https://dummyimage.com/107x409       ACTIVE
# 95479  https://dummyimage.com/107x409       ACTIVE
# 95480  https://dummyimage.com/107x409       ACTIVE
# 95481  https://dummyimage.com/107x409       ACTIVE
#
# [22331 rows x 43 columns]

# %% [markdown]
# ## Convert ke Time Series, Feature Engineering, dan Pre-processing
#
# Tahapan ini digunakan untuk mengubah dataset menjadi time series untuk memprediksi data historis, menambahkan fitur berbasis agregasi historis untuk meningkatkan performa model, dan pre-processing data sebelum digunakan untuk melatih model forecasting

# %%
time_series = final_df.groupby(final_df['transactionDate'].dt.date)['totalAmount'].sum().reset_index()
time_series.columns = ['date', 'revenue']
time_series['date'] = pd.to_datetime(time_series['date'])
time_series.set_index('date', inplace=True)

# %%
time_series
# Out:
#                  revenue
# date
# 2024-01-01  4.771806e+07
# 2024-01-02  6.134823e+07
# 2024-01-03  3.946636e+07
# 2024-01-04  7.396647e+07
# 2024-01-05  5.250896e+07
# ...                  ...
# 2025-04-28  1.353319e+07
# 2025-04-29  1.514981e+07
# 2025-04-30  1.785458e+07
# 2025-05-01  2.191860e+07
# 2025-05-02  1.161632e+08
#
# [488 rows x 1 columns]

# %%
plt.figure(figsize=(12, 6))
plt.plot(time_series['revenue'], label='Revenue')
plt.title('Daily Revenue (F&B)')
plt.xlabel('Date')
plt.ylabel('Revenue (Rp)')
plt.legend()
plt.show()

# %%
final_df['transactionDate']
# Out:
# 73151   2024-01-04 15:21:53
# 73152   2024-01-02 15:45:11
# 73153   2024-01-06 16:18:24
# 73154   2024-01-05 11:57:10
# 73155   2024-01-01 15:05:06
#                 ...
# 95477   2025-05-02 14:10:19
# 95478   2025-05-01 14:24:12
# 95479   2025-05-01 14:24:12
# 95480   2025-05-02 16:35:10
# 95481   2025-05-02 16:35:10
# Name: transactionDate, Length: 22331, dtype: datetime64[ns]

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plt.figure(figsize=(12, 4))
plot_acf(time_series['revenue'], lags=50)
plt.title('Autocorrelation Function (ACF)')
plt.show()

plt.figure(figsize=(12, 4))
plot_pacf(time_series['revenue'], lags=50)
plt.title('Partial Autocorrelation Function (PACF)')
plt.show()

# %%
time_series['rollingAvg7d'] = time_series['revenue'].rolling(window=7, min_periods=1).mean()

id_holidays = holidays.Indonesia(years=[2024, 2025])
time_series['is_holiday'] = time_series.index.isin(id_holidays).astype(int)
time_series['is_payday'] = time_series.index.day.isin([1, 2, 3, 4, 5]).astype(int)
time_series['is_weekend'] = time_series.index.weekday.isin([5, 6]).astype(int)

def create_lag(df, window=7):
    X, y, check_corr = [], [], []
    for i in range(window, len(df)):
        lag_features = df['revenue'].values[i-window:i]
        payday = df['is_payday'].values[i]
        holiday = df['is_holiday'].values[i]
        weekend = df['is_weekend'].values[i]
        rolling_avg_7d = df['rollingAvg7d'].values[i]

        full_feature = list(lag_features) + [payday, holiday, weekend, rolling_avg_7d]
        benchmark = full_feature + [df['revenue'].values[i]]

        X.append(full_feature)
        y.append(df['revenue'].values[i])
        check_corr.append(benchmark)

    return pd.DataFrame(X, columns=[f'lag_{i}' for i in range(window)] + ['is_payday', 'is_holiday', 'is_weekend', 'rollingAvg7d']), \
       pd.Series(y, name='target'), \
       pd.DataFrame(check_corr, columns=[f'lag_{i}' for i in range(window)] + ['is_payday', 'is_holiday', 'is_weekend', 'rollingAvg7d', 'target'])


X, y, check_corr = create_lag(time_series)
# Out:
# <ipython-input-81-1fac8aae5783>:4: FutureWarning: The behavior of 'isin' with dtype=datetime64[ns] and castable values (e.g. strings) is deprecated. In a future version, these will not be considered matching by isin. Explicitly cast to the appropriate dtype before calling isin instead.
#   time_series['is_holiday'] = time_series.index.isin(id_holidays).astype(int)

# %%
check_corr
# Out:
#            lag_0        lag_1        lag_2        lag_3        lag_4  \
# 0    47718061.64  61348232.72  39466365.00  73966466.40  52508962.80
# 1    61348232.72  39466365.00  73966466.40  52508962.80  28341085.40
# 2    39466365.00  73966466.40  52508962.80  28341085.40  20494117.68
# 3    73966466.40  52508962.80  28341085.40  20494117.68  16700429.52
# 4    52508962.80  28341085.40  20494117.68  16700429.52  13061469.44
# ..           ...          ...          ...          ...          ...
# 476  14998099.52  13956426.52  26081169.04  14210979.92  19758867.80
# 477  13956426.52  26081169.04  14210979.92  19758867.80  32650948.40
# 478  26081169.04  14210979.92  19758867.80  32650948.40  24845905.28
# 479  14210979.92  19758867.80  32650948.40  24845905.28  13533185.16
# 480  19758867.80  32650948.40  24845905.28  13533185.16  15149807.56
#
#            lag_5        lag_6  is_payday  is_holiday  is_weekend  \
# 0    28341085.40  20494117.68          0           0           0
# 1    20494117.68  16700429.52          0           0           0
# 2    16700429.52  13061469.44          0           0           0
# 3    13061469.44  17849963.08          0           0           0
# 4    17849963.08  25613670.44          0           0           0
# ..           ...          ...        ...         ...         ...
# 476  32650948.40  24845905.28          0           0           0
# 477  24845905.28  13533185.16          0           0           0
# 478  13533185.16  15149807.56          0           0           0
# 479  15149807.56  17854578.84          1           1           0
# 480  17854578.84  21918601.84          1           0           0
#
#      rollingAvg7d        target
# 0    4.183224e+07  1.670043e+07
# 1    3.493413e+07  1.306147e+07
# 2    3.184607e+07  1.784996e+07
# 3    2.493853e+07  2.561367e+07
# 4    2.042791e+07  2.093461e+07
# ..            ...           ...
# 476  2.071964e+07  1.353319e+07
# 477  2.089012e+07  1.514981e+07
# 478  1.971490e+07  1.785458e+07
# 479  2.081598e+07  2.191860e+07
# 480  3.458804e+07  1.161632e+08
#
# [481 rows x 12 columns]

# %%
corr_matrix = check_corr.corr()

plt.figure(figsize=(16, 12))

sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')

plt.title('Korelasi Antar Variabel')

plt.show()

# %%
X
# Out:
#            lag_0        lag_1        lag_2        lag_3        lag_4  \
# 0    47718061.64  61348232.72  39466365.00  73966466.40  52508962.80
# 1    61348232.72  39466365.00  73966466.40  52508962.80  28341085.40
# 2    39466365.00  73966466.40  52508962.80  28341085.40  20494117.68
# 3    73966466.40  52508962.80  28341085.40  20494117.68  16700429.52
# 4    52508962.80  28341085.40  20494117.68  16700429.52  13061469.44
# ..           ...          ...          ...          ...          ...
# 476  14998099.52  13956426.52  26081169.04  14210979.92  19758867.80
# 477  13956426.52  26081169.04  14210979.92  19758867.80  32650948.40
# 478  26081169.04  14210979.92  19758867.80  32650948.40  24845905.28
# 479  14210979.92  19758867.80  32650948.40  24845905.28  13533185.16
# 480  19758867.80  32650948.40  24845905.28  13533185.16  15149807.56
#
#            lag_5        lag_6  is_payday  is_holiday  is_weekend  rollingAvg7d
# 0    28341085.40  20494117.68          0           0           0  4.183224e+07
# 1    20494117.68  16700429.52          0           0           0  3.493413e+07
# 2    16700429.52  13061469.44          0           0           0  3.184607e+07
# 3    13061469.44  17849963.08          0           0           0  2.493853e+07
# 4    17849963.08  25613670.44          0           0           0  2.042791e+07
# ..           ...          ...        ...         ...         ...           ...
# 476  32650948.40  24845905.28          0           0           0  2.071964e+07
# 477  24845905.28  13533185.16          0           0           0  2.089012e+07
# 478  13533185.16  15149807.56          0           0           0  1.971490e+07
# 479  15149807.56  17854578.84          1           1           0  2.081598e+07
# 480  17854578.84  21918601.84          1           0           0  3.458804e+07
#
# [481 rows x 11 columns]

# %%
def save_scalers(scaler_X, scaler_y, store_type_id):
    # Buat direktori untuk tipe toko
    os.makedirs(f'/content/models/store_type_{store_type_id}', exist_ok=True)

    # Simpan scaler_X dan scaler_y
    joblib.dump(scaler_X, f'/content/models/store_type_{store_type_id}/scaler_X.pkl')
    joblib.dump(scaler_y, f'/content/models/store_type_{store_type_id}/scaler_y.pkl')

# %%
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1)).ravel()

X_scaled = X_scaled.reshape((X_scaled.shape[0], X_scaled.shape[1], 1))

# %%
save_scalers(scaler_X, scaler_y, store_type_id)

# %%
train_size = int(len(X_scaled) * 0.8)
X_train, X_test = X_scaled[:train_size], X_scaled[train_size:]
y_train, y_test = y_scaled[:train_size], y_scaled[train_size:]

# %% [markdown]
# ## Modeling

# %%
def model_builder(hp):
    model = Sequential()

    model.add(Conv1D(
        filters=hp.Int("conv_filters", min_value=32, max_value=128, step=16),
        kernel_size=hp.Int("kernel_size", min_value=2, max_value=5, step=1),
        activation='relu',
        padding='same',
        input_shape=(X_train.shape[1], X_train.shape[2])
    ))

    model.add(MaxPooling1D(pool_size=1))

    model.add(Conv1D(
        filters=hp.Int("conv_filters_2", min_value=64, max_value=256, step=16),
        kernel_size=hp.Int("kernel_size", min_value=2, max_value=5, step=1),
        activation='relu'
    ))
    model.add(MaxPooling1D(pool_size=2))

    model.add(Bidirectional(
        LSTM(
            units=hp.Int("bilstm_units", min_value=16, max_value=128, step=16),
            activation=hp.Choice("lstm_activation", ["relu", "tanh"]),
            return_sequences=True
        )
    ))
    model.add(Dropout(
        rate=hp.Float("dropout_1", min_value=0.2, max_value=0.5, step=0.1)
    ))
    model.add(LSTM(
        units=hp.Int("lstm_units", min_value=16, max_value=64, step=16),
        activation=hp.Choice("lstm2_activation", ["relu", "tanh"]),
        return_sequences=False
    ))
    model.add(Dropout(
        rate=hp.Float("dropout_2", min_value=0.2, max_value=0.5, step=0.1)
    ))

    model.add(Dense(
        units=hp.Int("dense_units", min_value=16, max_value=64, step=16),
        activation=hp.Choice("dense_activation", ["relu", "tanh"])
    ))

    model.add(Dropout(
        rate=hp.Float("dropout_3", min_value=0.2, max_value=0.5, step=0.1)
    ))

    model.add(Dense(
        units=hp.Int("dense_units_2", min_value=32, max_value=128, step=16),
        activation=hp.Choice("dense_activation", ["relu", "tanh"])
    ))

    model.add(Dense(1))

    model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error', metrics=[R2Score(), MeanSquaredError(), MeanAbsoluteError()])

    return model

# model = Sequential([
#     Bidirectional(LSTM(32, activation='relu', return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2]))),
#     Dropout(0.2),
#     LSTM(64, activation='relu', return_sequences=False),
#     Dropout(0.2),
#     Dense(32, activation='relu'),
#     Dense(1)
# ])

# %%
# !rm -rf tuner_dir/

# %%
from keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=3, mode='max', start_from_epoch=30, restore_best_weights=True)


tuner = kt.RandomSearch(
    model_builder,
    objective='val_loss',
    max_trials=20,
    executions_per_trial=1,
    directory='tuner_dir',
    project_name='lstm_tuning'
)

tuner.search(X_train, y_train, epochs=100, validation_split=0.2, callbacks=[early_stop])
# Out:
# Trial 20 Complete [00h 00m 36s]
# val_loss: 0.002701790537685156
#
# Best val_loss So Far: 0.0026287741493433714
# Total elapsed time: 00h 10m 54s

# %%
best_hp = tuner.get_best_hyperparameters(1)[0]
print(best_hp.values)
best_model = tuner.hypermodel.build(best_hp)
# Out:
# {'conv_filters': 32, 'kernel_size': 5, 'conv_filters_2': 224, 'bilstm_units': 112, 'lstm_activation': 'relu', 'dropout_1': 0.2, 'lstm_units': 32, 'lstm2_activation': 'relu', 'dropout_2': 0.30000000000000004, 'dense_units': 48, 'dense_activation': 'tanh', 'dropout_3': 0.30000000000000004, 'dense_units_2': 112}

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_r2_score', patience=1, restore_best_weights=True)

# %%
history = best_model.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=32,
    validation_split=0.1,
    verbose=1,
    # callbacks=[early_stopping]
)
# Out:
# Epoch 1/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 122ms/step - loss: 0.0577 - mean_absolute_error: 0.1593 - mean_squared_error: 0.0577 - r2_score: -0.5326 - val_loss: 0.0283 - val_mean_absolute_error: 0.1427 - val_mean_squared_error: 0.0283 - val_r2_score: 0.2528
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.0259 - mean_absolute_error: 0.1230 - mean_squared_error: 0.0259 - r2_score: 0.2305 - val_loss: 0.0178 - val_mean_absolute_error: 0.1010 - val_mean_squared_error: 0.0178 - val_r2_score: 0.5290
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.0168 - mean_absolute_error: 0.0976 - mean_squared_error: 0.0168 - r2_score: 0.5534 - val_loss: 0.0125 - val_mean_absolute_error: 0.0723 - val_mean_squared_error: 0.0125 - val_r2_score: 0.6689
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0131 - mean_absolute_error: 0.0708 - mean_squared_error: 0.0131 - r2_score: 0.6242 - val_loss: 0.0073 - val_mean_absolute_error: 0.0587 - val_mean_squared_error: 0.0073 - val_r2_score: 0.8084
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0079 - mean_absolute_error: 0.0624 - mean_squared_error: 0.0079 - r2_score: 0.7745 - val_loss: 0.0164 - val_mean_absolute_error: 0.0770 - val_mean_squared_error: 0.0164 - val_r2_score: 0.5677
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0122 - mean_absolute_error: 0.0697 - mean_squared_error: 0.0122 - r2_score: 0.5876 - val_loss: 0.0106 - val_mean_absolute_error: 0.0864 - val_mean_squared_error: 0.0106 - val_r2_score: 0.7215
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0178 - mean_absolute_error: 0.0851 - mean_squared_error: 0.0178 - r2_score: 0.5033 - val_loss: 0.0071 - val_mean_absolute_error: 0.0632 - val_mean_squared_error: 0.0071 - val_r2_score: 0.8129
# Epoch 8/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0077 - mean_absolute_error: 0.0621 - mean_squared_error: 0.0077 - r2_score: 0.7617 - val_loss: 0.0070 - val_mean_absolute_error: 0.0564 - val_mean_squared_error: 0.0070 - val_r2_score: 0.8157
# Epoch 9/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0074 - mean_absolute_error: 0.0591 - mean_squared_error: 0.0074 - r2_score: 0.7803 - val_loss: 0.0051 - val_mean_absolute_error: 0.0512 - val_mean_squared_error: 0.0051 - val_r2_score: 0.8645
# Epoch 10/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0070 - mean_absolute_error: 0.0576 - mean_squared_error: 0.0070 - r2_score: 0.7842 - val_loss: 0.0066 - val_mean_absolute_error: 0.0584 - val_mean_squared_error: 0.0066 - val_r2_score: 0.8266
# Epoch 11/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0073 - mean_absolute_error: 0.0615 - mean_squared_error: 0.0073 - r2_score: 0.8017 - val_loss: 0.0063 - val_mean_absolute_error: 0.0547 - val_mean_squared_error: 0.0063 - val_r2_score: 0.8343
# Epoch 12/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0063 - mean_absolute_error: 0.0543 - mean_squared_error: 0.0063 - r2_score: 0.7978 - val_loss: 0.0044 - val_mean_absolute_error: 0.0515 - val_mean_squared_error: 0.0044 - val_r2_score: 0.8835
# Epoch 13/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0068 - mean_absolute_error: 0.0562 - mean_squared_error: 0.0068 - r2_score: 0.7934 - val_loss: 0.0059 - val_mean_absolute_error: 0.0630 - val_mean_squared_error: 0.0059 - val_r2_score: 0.8439
# Epoch 14/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0107 - mean_absolute_error: 0.0764 - mean_squared_error: 0.0107 - r2_score: 0.7034 - val_loss: 0.0127 - val_mean_absolute_error: 0.0684 - val_mean_squared_error: 0.0127 - val_r2_score: 0.6637
# Epoch 15/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0082 - mean_absolute_error: 0.0614 - mean_squared_error: 0.0082 - r2_score: 0.7581 - val_loss: 0.0053 - val_mean_absolute_error: 0.0540 - val_mean_squared_error: 0.0053 - val_r2_score: 0.8595
# Epoch 16/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0068 - mean_absolute_error: 0.0531 - mean_squared_error: 0.0068 - r2_score: 0.8201 - val_loss: 0.0047 - val_mean_absolute_error: 0.0496 - val_mean_squared_error: 0.0047 - val_r2_score: 0.8749
# Epoch 17/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0058 - mean_absolute_error: 0.0573 - mean_squared_error: 0.0058 - r2_score: 0.8309 - val_loss: 0.0050 - val_mean_absolute_error: 0.0511 - val_mean_squared_error: 0.0050 - val_r2_score: 0.8685
# Epoch 18/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0047 - mean_absolute_error: 0.0504 - mean_squared_error: 0.0047 - r2_score: 0.8284 - val_loss: 0.0051 - val_mean_absolute_error: 0.0494 - val_mean_squared_error: 0.0051 - val_r2_score: 0.8655
# Epoch 19/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0047 - mean_absolute_error: 0.0490 - mean_squared_error: 0.0047 - r2_score: 0.8722 - val_loss: 0.0047 - val_mean_absolute_error: 0.0532 - val_mean_squared_error: 0.0047 - val_r2_score: 0.8751
# Epoch 20/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0055 - mean_absolute_error: 0.0511 - mean_squared_error: 0.0055 - r2_score: 0.8496 - val_loss: 0.0046 - val_mean_absolute_error: 0.0491 - val_mean_squared_error: 0.0046 - val_r2_score: 0.8775
# Epoch 21/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0054 - mean_absolute_error: 0.0533 - mean_squared_error: 0.0054 - r2_score: 0.8512 - val_loss: 0.0091 - val_mean_absolute_error: 0.0592 - val_mean_squared_error: 0.0091 - val_r2_score: 0.7608
# Epoch 22/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.0070 - mean_absolute_error: 0.0566 - mean_squared_error: 0.0070 - r2_score: 0.7881 - val_loss: 0.0046 - val_mean_absolute_error: 0.0525 - val_mean_squared_error: 0.0046 - val_r2_score: 0.8775
# Epoch 23/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.0057 - mean_absolute_error: 0.0552 - mean_squared_error: 0.0057 - r2_score: 0.8366 - val_loss: 0.0041 - val_mean_absolute_error: 0.0466 - val_mean_squared_error: 0.0041 - val_r2_score: 0.8922
# Epoch 24/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0054 - mean_absolute_error: 0.0528 - mean_squared_error: 0.0054 - r2_score: 0.8545 - val_loss: 0.0058 - val_mean_absolute_error: 0.0539 - val_mean_squared_error: 0.0058 - val_r2_score: 0.8467
# Epoch 25/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0062 - mean_absolute_error: 0.0546 - mean_squared_error: 0.0062 - r2_score: 0.8202 - val_loss: 0.0036 - val_mean_absolute_error: 0.0447 - val_mean_squared_error: 0.0036 - val_r2_score: 0.9053
# Epoch 26/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0042 - mean_absolute_error: 0.0450 - mean_squared_error: 0.0042 - r2_score: 0.8853 - val_loss: 0.0047 - val_mean_absolute_error: 0.0502 - val_mean_squared_error: 0.0047 - val_r2_score: 0.8753
# Epoch 27/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0052 - mean_absolute_error: 0.0524 - mean_squared_error: 0.0052 - r2_score: 0.8563 - val_loss: 0.0050 - val_mean_absolute_error: 0.0543 - val_mean_squared_error: 0.0050 - val_r2_score: 0.8676
# Epoch 28/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0049 - mean_absolute_error: 0.0509 - mean_squared_error: 0.0049 - r2_score: 0.8637 - val_loss: 0.0062 - val_mean_absolute_error: 0.0518 - val_mean_squared_error: 0.0062 - val_r2_score: 0.8364
# Epoch 29/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0067 - mean_absolute_error: 0.0588 - mean_squared_error: 0.0067 - r2_score: 0.8256 - val_loss: 0.0054 - val_mean_absolute_error: 0.0536 - val_mean_squared_error: 0.0054 - val_r2_score: 0.8574
# Epoch 30/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0056 - mean_absolute_error: 0.0506 - mean_squared_error: 0.0056 - r2_score: 0.8386 - val_loss: 0.0045 - val_mean_absolute_error: 0.0504 - val_mean_squared_error: 0.0045 - val_r2_score: 0.8811
# Epoch 31/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0069 - mean_absolute_error: 0.0556 - mean_squared_error: 0.0069 - r2_score: 0.8186 - val_loss: 0.0049 - val_mean_absolute_error: 0.0546 - val_mean_squared_error: 0.0049 - val_r2_score: 0.8706
# Epoch 32/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0045 - mean_absolute_error: 0.0512 - mean_squared_error: 0.0045 - r2_score: 0.8678 - val_loss: 0.0047 - val_mean_absolute_error: 0.0478 - val_mean_squared_error: 0.0047 - val_r2_score: 0.8771
# Epoch 33/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0046 - mean_absolute_error: 0.0488 - mean_squared_error: 0.0046 - r2_score: 0.8713 - val_loss: 0.0048 - val_mean_absolute_error: 0.0525 - val_mean_squared_error: 0.0048 - val_r2_score: 0.8737
# Epoch 34/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0048 - mean_absolute_error: 0.0496 - mean_squared_error: 0.0048 - r2_score: 0.8538 - val_loss: 0.0044 - val_mean_absolute_error: 0.0508 - val_mean_squared_error: 0.0044 - val_r2_score: 0.8849
# Epoch 35/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0072 - mean_absolute_error: 0.0558 - mean_squared_error: 0.0072 - r2_score: 0.8191 - val_loss: 0.0048 - val_mean_absolute_error: 0.0555 - val_mean_squared_error: 0.0048 - val_r2_score: 0.8742
# Epoch 36/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0044 - mean_absolute_error: 0.0507 - mean_squared_error: 0.0044 - r2_score: 0.8760 - val_loss: 0.0034 - val_mean_absolute_error: 0.0446 - val_mean_squared_error: 0.0034 - val_r2_score: 0.9111
# Epoch 37/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0044 - mean_absolute_error: 0.0494 - mean_squared_error: 0.0044 - r2_score: 0.8537 - val_loss: 0.0041 - val_mean_absolute_error: 0.0513 - val_mean_squared_error: 0.0041 - val_r2_score: 0.8911
# Epoch 38/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0043 - mean_absolute_error: 0.0474 - mean_squared_error: 0.0043 - r2_score: 0.8844 - val_loss: 0.0041 - val_mean_absolute_error: 0.0459 - val_mean_squared_error: 0.0041 - val_r2_score: 0.8927
# Epoch 39/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0039 - mean_absolute_error: 0.0451 - mean_squared_error: 0.0039 - r2_score: 0.8885 - val_loss: 0.0035 - val_mean_absolute_error: 0.0469 - val_mean_squared_error: 0.0035 - val_r2_score: 0.9065
# Epoch 40/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0045 - mean_absolute_error: 0.0489 - mean_squared_error: 0.0045 - r2_score: 0.8811 - val_loss: 0.0044 - val_mean_absolute_error: 0.0533 - val_mean_squared_error: 0.0044 - val_r2_score: 0.8828
# Epoch 41/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0050 - mean_absolute_error: 0.0511 - mean_squared_error: 0.0050 - r2_score: 0.8590 - val_loss: 0.0040 - val_mean_absolute_error: 0.0518 - val_mean_squared_error: 0.0040 - val_r2_score: 0.8936
# Epoch 42/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0052 - mean_absolute_error: 0.0504 - mean_squared_error: 0.0052 - r2_score: 0.8641 - val_loss: 0.0038 - val_mean_absolute_error: 0.0472 - val_mean_squared_error: 0.0038 - val_r2_score: 0.8991
# Epoch 43/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0042 - mean_absolute_error: 0.0459 - mean_squared_error: 0.0042 - r2_score: 0.8792 - val_loss: 0.0039 - val_mean_absolute_error: 0.0471 - val_mean_squared_error: 0.0039 - val_r2_score: 0.8978
# Epoch 44/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.0040 - mean_absolute_error: 0.0450 - mean_squared_error: 0.0040 - r2_score: 0.8902 - val_loss: 0.0045 - val_mean_absolute_error: 0.0520 - val_mean_squared_error: 0.0045 - val_r2_score: 0.8818
# Epoch 45/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0047 - mean_absolute_error: 0.0502 - mean_squared_error: 0.0047 - r2_score: 0.8641 - val_loss: 0.0041 - val_mean_absolute_error: 0.0486 - val_mean_squared_error: 0.0041 - val_r2_score: 0.8906
# Epoch 46/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0038 - mean_absolute_error: 0.0457 - mean_squared_error: 0.0038 - r2_score: 0.8975 - val_loss: 0.0050 - val_mean_absolute_error: 0.0516 - val_mean_squared_error: 0.0050 - val_r2_score: 0.8679
# Epoch 47/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0042 - mean_absolute_error: 0.0465 - mean_squared_error: 0.0042 - r2_score: 0.8813 - val_loss: 0.0052 - val_mean_absolute_error: 0.0489 - val_mean_squared_error: 0.0052 - val_r2_score: 0.8626
# Epoch 48/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0045 - mean_absolute_error: 0.0496 - mean_squared_error: 0.0045 - r2_score: 0.8664 - val_loss: 0.0038 - val_mean_absolute_error: 0.0454 - val_mean_squared_error: 0.0038 - val_r2_score: 0.9005
# Epoch 49/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0040 - mean_absolute_error: 0.0443 - mean_squared_error: 0.0040 - r2_score: 0.8792 - val_loss: 0.0037 - val_mean_absolute_error: 0.0480 - val_mean_squared_error: 0.0037 - val_r2_score: 0.9029
# Epoch 50/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0040 - mean_absolute_error: 0.0481 - mean_squared_error: 0.0040 - r2_score: 0.8771 - val_loss: 0.0039 - val_mean_absolute_error: 0.0492 - val_mean_squared_error: 0.0039 - val_r2_score: 0.8964
# Epoch 51/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0038 - mean_absolute_error: 0.0463 - mean_squared_error: 0.0038 - r2_score: 0.8715 - val_loss: 0.0039 - val_mean_absolute_error: 0.0499 - val_mean_squared_error: 0.0039 - val_r2_score: 0.8958
# Epoch 52/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0041 - mean_absolute_error: 0.0467 - mean_squared_error: 0.0041 - r2_score: 0.8822 - val_loss: 0.0048 - val_mean_absolute_error: 0.0476 - val_mean_squared_error: 0.0048 - val_r2_score: 0.8745
# Epoch 53/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0031 - mean_absolute_error: 0.0407 - mean_squared_error: 0.0031 - r2_score: 0.8991 - val_loss: 0.0046 - val_mean_absolute_error: 0.0501 - val_mean_squared_error: 0.0046 - val_r2_score: 0.8779
# Epoch 54/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0046 - mean_absolute_error: 0.0472 - mean_squared_error: 0.0046 - r2_score: 0.8745 - val_loss: 0.0088 - val_mean_absolute_error: 0.0586 - val_mean_squared_error: 0.0088 - val_r2_score: 0.7676
# Epoch 55/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0070 - mean_absolute_error: 0.0552 - mean_squared_error: 0.0070 - r2_score: 0.7963 - val_loss: 0.0033 - val_mean_absolute_error: 0.0411 - val_mean_squared_error: 0.0033 - val_r2_score: 0.9134
# Epoch 56/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0051 - mean_absolute_error: 0.0518 - mean_squared_error: 0.0051 - r2_score: 0.8526 - val_loss: 0.0054 - val_mean_absolute_error: 0.0595 - val_mean_squared_error: 0.0054 - val_r2_score: 0.8566
# Epoch 57/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0049 - mean_absolute_error: 0.0534 - mean_squared_error: 0.0049 - r2_score: 0.8690 - val_loss: 0.0066 - val_mean_absolute_error: 0.0518 - val_mean_squared_error: 0.0066 - val_r2_score: 0.8269
# Epoch 58/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0041 - mean_absolute_error: 0.0464 - mean_squared_error: 0.0041 - r2_score: 0.8797 - val_loss: 0.0040 - val_mean_absolute_error: 0.0453 - val_mean_squared_error: 0.0040 - val_r2_score: 0.8948
# Epoch 59/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0053 - mean_absolute_error: 0.0471 - mean_squared_error: 0.0053 - r2_score: 0.8507 - val_loss: 0.0036 - val_mean_absolute_error: 0.0478 - val_mean_squared_error: 0.0036 - val_r2_score: 0.9050
# Epoch 60/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0033 - mean_absolute_error: 0.0420 - mean_squared_error: 0.0033 - r2_score: 0.8982 - val_loss: 0.0034 - val_mean_absolute_error: 0.0451 - val_mean_squared_error: 0.0034 - val_r2_score: 0.9102
# Epoch 61/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0036 - mean_absolute_error: 0.0431 - mean_squared_error: 0.0036 - r2_score: 0.8974 - val_loss: 0.0041 - val_mean_absolute_error: 0.0474 - val_mean_squared_error: 0.0041 - val_r2_score: 0.8920
# Epoch 62/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0038 - mean_absolute_error: 0.0436 - mean_squared_error: 0.0038 - r2_score: 0.8912 - val_loss: 0.0044 - val_mean_absolute_error: 0.0475 - val_mean_squared_error: 0.0044 - val_r2_score: 0.8851
# Epoch 63/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0037 - mean_absolute_error: 0.0438 - mean_squared_error: 0.0037 - r2_score: 0.8861 - val_loss: 0.0033 - val_mean_absolute_error: 0.0405 - val_mean_squared_error: 0.0033 - val_r2_score: 0.9134
# Epoch 64/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.0043 - mean_absolute_error: 0.0480 - mean_squared_error: 0.0043 - r2_score: 0.8816 - val_loss: 0.0044 - val_mean_absolute_error: 0.0510 - val_mean_squared_error: 0.0044 - val_r2_score: 0.8837
# Epoch 65/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0041 - mean_absolute_error: 0.0452 - mean_squared_error: 0.0041 - r2_score: 0.8820 - val_loss: 0.0033 - val_mean_absolute_error: 0.0443 - val_mean_squared_error: 0.0033 - val_r2_score: 0.9134
# Epoch 66/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0028 - mean_absolute_error: 0.0387 - mean_squared_error: 0.0028 - r2_score: 0.9140 - val_loss: 0.0036 - val_mean_absolute_error: 0.0457 - val_mean_squared_error: 0.0036 - val_r2_score: 0.9046
# Epoch 67/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0040 - mean_absolute_error: 0.0441 - mean_squared_error: 0.0040 - r2_score: 0.8669 - val_loss: 0.0040 - val_mean_absolute_error: 0.0475 - val_mean_squared_error: 0.0040 - val_r2_score: 0.8933
# Epoch 68/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0044 - mean_absolute_error: 0.0481 - mean_squared_error: 0.0044 - r2_score: 0.8772 - val_loss: 0.0036 - val_mean_absolute_error: 0.0425 - val_mean_squared_error: 0.0036 - val_r2_score: 0.9054
# Epoch 69/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0039 - mean_absolute_error: 0.0445 - mean_squared_error: 0.0039 - r2_score: 0.8862 - val_loss: 0.0051 - val_mean_absolute_error: 0.0489 - val_mean_squared_error: 0.0051 - val_r2_score: 0.8640
# Epoch 70/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0055 - mean_absolute_error: 0.0497 - mean_squared_error: 0.0055 - r2_score: 0.8442 - val_loss: 0.0053 - val_mean_absolute_error: 0.0488 - val_mean_squared_error: 0.0053 - val_r2_score: 0.8593
# Epoch 71/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0051 - mean_absolute_error: 0.0476 - mean_squared_error: 0.0051 - r2_score: 0.8553 - val_loss: 0.0030 - val_mean_absolute_error: 0.0418 - val_mean_squared_error: 0.0030 - val_r2_score: 0.9212
# Epoch 72/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0030 - mean_absolute_error: 0.0408 - mean_squared_error: 0.0030 - r2_score: 0.9163 - val_loss: 0.0045 - val_mean_absolute_error: 0.0487 - val_mean_squared_error: 0.0045 - val_r2_score: 0.8806
# Epoch 73/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0031 - mean_absolute_error: 0.0395 - mean_squared_error: 0.0031 - r2_score: 0.8993 - val_loss: 0.0035 - val_mean_absolute_error: 0.0475 - val_mean_squared_error: 0.0035 - val_r2_score: 0.9065
# Epoch 74/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0028 - mean_absolute_error: 0.0404 - mean_squared_error: 0.0028 - r2_score: 0.9128 - val_loss: 0.0037 - val_mean_absolute_error: 0.0452 - val_mean_squared_error: 0.0037 - val_r2_score: 0.9021
# Epoch 75/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0032 - mean_absolute_error: 0.0427 - mean_squared_error: 0.0032 - r2_score: 0.9059 - val_loss: 0.0031 - val_mean_absolute_error: 0.0414 - val_mean_squared_error: 0.0031 - val_r2_score: 0.9170
# Epoch 76/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0039 - mean_absolute_error: 0.0453 - mean_squared_error: 0.0039 - r2_score: 0.8876 - val_loss: 0.0046 - val_mean_absolute_error: 0.0525 - val_mean_squared_error: 0.0046 - val_r2_score: 0.8780
# Epoch 77/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0044 - mean_absolute_error: 0.0498 - mean_squared_error: 0.0044 - r2_score: 0.8782 - val_loss: 0.0038 - val_mean_absolute_error: 0.0445 - val_mean_squared_error: 0.0038 - val_r2_score: 0.8985
# Epoch 78/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0033 - mean_absolute_error: 0.0424 - mean_squared_error: 0.0033 - r2_score: 0.9077 - val_loss: 0.0044 - val_mean_absolute_error: 0.0440 - val_mean_squared_error: 0.0044 - val_r2_score: 0.8844
# Epoch 79/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0036 - mean_absolute_error: 0.0433 - mean_squared_error: 0.0036 - r2_score: 0.8995 - val_loss: 0.0050 - val_mean_absolute_error: 0.0466 - val_mean_squared_error: 0.0050 - val_r2_score: 0.8691
# Epoch 80/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0032 - mean_absolute_error: 0.0407 - mean_squared_error: 0.0032 - r2_score: 0.9174 - val_loss: 0.0038 - val_mean_absolute_error: 0.0438 - val_mean_squared_error: 0.0038 - val_r2_score: 0.9008
# Epoch 81/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0028 - mean_absolute_error: 0.0379 - mean_squared_error: 0.0028 - r2_score: 0.9115 - val_loss: 0.0040 - val_mean_absolute_error: 0.0446 - val_mean_squared_error: 0.0040 - val_r2_score: 0.8935
# Epoch 82/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0024 - mean_absolute_error: 0.0344 - mean_squared_error: 0.0024 - r2_score: 0.9349 - val_loss: 0.0037 - val_mean_absolute_error: 0.0441 - val_mean_squared_error: 0.0037 - val_r2_score: 0.9034
# Epoch 83/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0040 - mean_absolute_error: 0.0423 - mean_squared_error: 0.0040 - r2_score: 0.8833 - val_loss: 0.0055 - val_mean_absolute_error: 0.0500 - val_mean_squared_error: 0.0055 - val_r2_score: 0.8554
# Epoch 84/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0037 - mean_absolute_error: 0.0438 - mean_squared_error: 0.0037 - r2_score: 0.8898 - val_loss: 0.0039 - val_mean_absolute_error: 0.0455 - val_mean_squared_error: 0.0039 - val_r2_score: 0.8975
# Epoch 85/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0033 - mean_absolute_error: 0.0436 - mean_squared_error: 0.0033 - r2_score: 0.9069 - val_loss: 0.0034 - val_mean_absolute_error: 0.0443 - val_mean_squared_error: 0.0034 - val_r2_score: 0.9113
# Epoch 86/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0032 - mean_absolute_error: 0.0409 - mean_squared_error: 0.0032 - r2_score: 0.9144 - val_loss: 0.0040 - val_mean_absolute_error: 0.0492 - val_mean_squared_error: 0.0040 - val_r2_score: 0.8955
# Epoch 87/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.0035 - mean_absolute_error: 0.0421 - mean_squared_error: 0.0035 - r2_score: 0.9015 - val_loss: 0.0033 - val_mean_absolute_error: 0.0408 - val_mean_squared_error: 0.0033 - val_r2_score: 0.9118
# Epoch 88/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0039 - mean_absolute_error: 0.0444 - mean_squared_error: 0.0039 - r2_score: 0.8903 - val_loss: 0.0033 - val_mean_absolute_error: 0.0430 - val_mean_squared_error: 0.0033 - val_r2_score: 0.9118
# Epoch 89/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0033 - mean_absolute_error: 0.0424 - mean_squared_error: 0.0033 - r2_score: 0.9084 - val_loss: 0.0047 - val_mean_absolute_error: 0.0474 - val_mean_squared_error: 0.0047 - val_r2_score: 0.8757
# Epoch 90/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0039 - mean_absolute_error: 0.0426 - mean_squared_error: 0.0039 - r2_score: 0.8867 - val_loss: 0.0033 - val_mean_absolute_error: 0.0424 - val_mean_squared_error: 0.0033 - val_r2_score: 0.9134
# Epoch 91/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0034 - mean_absolute_error: 0.0405 - mean_squared_error: 0.0034 - r2_score: 0.8862 - val_loss: 0.0036 - val_mean_absolute_error: 0.0429 - val_mean_squared_error: 0.0036 - val_r2_score: 0.9041
# Epoch 92/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0037 - mean_absolute_error: 0.0418 - mean_squared_error: 0.0037 - r2_score: 0.8756 - val_loss: 0.0035 - val_mean_absolute_error: 0.0468 - val_mean_squared_error: 0.0035 - val_r2_score: 0.9065
# Epoch 93/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0032 - mean_absolute_error: 0.0411 - mean_squared_error: 0.0032 - r2_score: 0.9066 - val_loss: 0.0066 - val_mean_absolute_error: 0.0585 - val_mean_squared_error: 0.0066 - val_r2_score: 0.8267
# Epoch 94/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0037 - mean_absolute_error: 0.0460 - mean_squared_error: 0.0037 - r2_score: 0.8962 - val_loss: 0.0042 - val_mean_absolute_error: 0.0460 - val_mean_squared_error: 0.0042 - val_r2_score: 0.8903
# Epoch 95/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0038 - mean_absolute_error: 0.0423 - mean_squared_error: 0.0038 - r2_score: 0.8979 - val_loss: 0.0034 - val_mean_absolute_error: 0.0432 - val_mean_squared_error: 0.0034 - val_r2_score: 0.9090
# Epoch 96/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0039 - mean_absolute_error: 0.0414 - mean_squared_error: 0.0039 - r2_score: 0.8808 - val_loss: 0.0050 - val_mean_absolute_error: 0.0475 - val_mean_squared_error: 0.0050 - val_r2_score: 0.8691
# Epoch 97/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0034 - mean_absolute_error: 0.0378 - mean_squared_error: 0.0034 - r2_score: 0.8881 - val_loss: 0.0035 - val_mean_absolute_error: 0.0431 - val_mean_squared_error: 0.0035 - val_r2_score: 0.9073
# Epoch 98/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0039 - mean_absolute_error: 0.0392 - mean_squared_error: 0.0039 - r2_score: 0.9029 - val_loss: 0.0039 - val_mean_absolute_error: 0.0453 - val_mean_squared_error: 0.0039 - val_r2_score: 0.8960
# Epoch 99/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0026 - mean_absolute_error: 0.0380 - mean_squared_error: 0.0026 - r2_score: 0.9252 - val_loss: 0.0043 - val_mean_absolute_error: 0.0489 - val_mean_squared_error: 0.0043 - val_r2_score: 0.8878
# Epoch 100/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0031 - mean_absolute_error: 0.0398 - mean_squared_error: 0.0031 - r2_score: 0.9130 - val_loss: 0.0041 - val_mean_absolute_error: 0.0437 - val_mean_squared_error: 0.0041 - val_r2_score: 0.8929

# %%
y_pred_scaled = best_model.predict(X_test)
y_pred = scaler_y.inverse_transform(y_pred_scaled).ravel()
y_actual = scaler_y.inverse_transform(y_test.reshape(-1, 1)).ravel()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 196ms/step

# %%
mae = mean_absolute_error(y_actual, y_pred)
rmse = np.sqrt(mean_squared_error(y_actual, y_pred))
r2 = r2_score(y_actual, y_pred)

# %%
print(f"LSTM: MAE={mae:.2f}, RMSE={rmse:.2f}, R2={r2:.2f}")
# Out:
# LSTM: MAE=5440620.28, RMSE=9264501.12, R2=0.84

# %%
last_dates = time_series.index[-len(y_test):]
plt.figure(figsize=(12, 6))
plt.plot(last_dates, y_pred, label='LSTM Predicted', color='blue')
plt.plot(last_dates, y_actual, label='Actual', color='black', linewidth=2)
plt.title('Prediksi vs Aktual (LSTM)')
plt.xlabel('Tanggal')
plt.ylabel('Nilai')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training dan Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(history.history['r2_score'], label='Training R2-score')
plt.plot(history.history['val_r2_score'], label='Validation R2-score')
plt.title('Training dan Validation R2-score')
plt.xlabel('Epoch')
plt.ylabel('R2-Score')
plt.legend()
plt.grid()
plt.show()

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
import holidays
import matplotlib.pyplot as plt

def prepare_inference_data(time_series, window=7, scaler_X=None):
    """
    Prepare the latest data for inference by creating lag features and scaling.

    Parameters:
    - time_series: DataFrame with columns ['revenue', 'rollingAvg7d', 'is_holiday', 'is_payday', 'is_weekend']
    - window: Number of lag days (default=7)
    - scaler_X: Fitted MinMaxScaler for features

    Returns:
    - X_scaled: Scaled input features for prediction
    - last_index: Index of the last data point
    """
    # Validate required columns
    required_columns = ['revenue', 'rollingAvg7d', 'is_holiday', 'is_payday', 'is_weekend']
    if not all(col in time_series.columns for col in required_columns):
        raise ValueError("Time series missing required columns")

    # Get the last window+1 rows
    df = time_series.tail(window + 1).copy()

    # Extract features for the last data point
    lag_features = df['revenue'].values[-window:]
    payday = df['is_payday'].values[-1]
    holiday = df['is_holiday'].values[-1]
    weekend = df['is_weekend'].values[-1]
    rolling_avg_7d = df['rollingAvg7d'].values[-1]

    # Combine features
    full_feature = list(lag_features) + [payday, holiday, weekend, rolling_avg_7d]

    # Create DataFrame for features
    X = pd.DataFrame([full_feature], columns=[f'lag_{i}' for i in range(window)] +
                     ['is_payday', 'is_holiday', 'is_weekend', 'rollingAvg7d'])

    # Scale features
    X_scaled = scaler_X.transform(X)
    X_scaled = X_scaled.reshape((X_scaled.shape[0], X_scaled.shape[1], 1))

    return X_scaled, df.index[-1]

def predict_next_day(model, time_series, window=7, scaler_X=None, scaler_y=None):
    """
    Predict the revenue for the next day using the trained model.

    Parameters:
    - model: Trained Keras model
    - time_series: DataFrame with historical data
    - window: Number of lag days (default=7)
    - scaler_X: Fitted MinMaxScaler for features
    - scaler_y: Fitted MinMaxScaler for target

    Returns:
    - prediction: Predicted revenue (unscaled)
    - prediction_date: Date of the prediction
    """
    # Prepare data
    X_scaled, last_index = prepare_inference_data(time_series, window, scaler_X)

    # Make prediction
    y_pred_scaled = model.predict(X_scaled, verbose=0)

    # Inverse transform
    y_pred = scaler_y.inverse_transform(y_pred_scaled).ravel()[0]

    # Calculate next day's date
    prediction_date = last_index + pd.Timedelta(days=1)

    return y_pred, prediction_date

def update_time_series_for_next_day(time_series, predicted_revenue, next_date, id_holidays):
    """
    Update time_series with the predicted revenue and new features.

    Parameters:
    - time_series: Original DataFrame
    - predicted_revenue: Predicted revenue
    - next_date: Date for the prediction
    - id_holidays: holidays.Indonesia object

    Returns:
    - Updated time_series
    """
    # Create new row
    new_row = pd.DataFrame({
        'revenue': [predicted_revenue],
        'is_holiday': [int(next_date in id_holidays)],
        'is_payday': [int(next_date.day in [1, 2, 3, 4, 5])],
        'is_weekend': [int(next_date.weekday() in [5, 6])]
    }, index=[next_date])

    # Append new row
    time_series = pd.concat([time_series, new_row])

    # Update rolling average
    time_series['rollingAvg7d'] = time_series['revenue'].rolling(window=7, min_periods=1).mean()

    return time_series

def predict_7_days(model, time_series, window=7, scaler_X=None, scaler_y=None, id_holidays=None):
    """
    Predict revenue for the next 7 days and update time_series iteratively.

    Parameters:
    - model: Trained Keras model
    - time_series: DataFrame with historical data
    - window: Number of lag days (default=7)
    - scaler_X: Fitted MinMaxScaler for features
    - scaler_y: Fitted MinMaxScaler for target
    - id_holidays: holidays.Indonesia object

    Returns:
    - predictions: DataFrame with dates and predicted revenues
    - updated_time_series: Updated time_series with predictions
    """
    predictions = []
    updated_time_series = time_series.copy()

    for _ in range(7):
        # Predict next day
        pred_revenue, pred_date = predict_next_day(
            model=model,
            time_series=updated_time_series,
            window=window,
            scaler_X=scaler_X,
            scaler_y=scaler_y
        )

        # Store prediction
        predictions.append({'date': pred_date, 'revenue': pred_revenue})

        # Update time_series
        updated_time_series = update_time_series_for_next_day(
            time_series=updated_time_series,
            predicted_revenue=pred_revenue,
            next_date=pred_date,
            id_holidays=id_holidays
        )

    # Convert predictions to DataFrame
    predictions_df = pd.DataFrame(predictions)
    predictions_df['date'] = pd.to_datetime(predictions_df['date'])
    predictions_df.set_index('date', inplace=True)

    return predictions_df, updated_time_series

# Example usage
# Prerequisites:
# - best_model: Trained Keras model
# - time_series: DataFrame with historical data
# - scaler_X: Fitted MinMaxScaler for features
# - scaler_y: Fitted MinMaxScaler for target
# - id_holidays: holidays.Indonesia(years=[2024, 2025])

# Predict 7 days
predictions_df, time_series_updated = predict_7_days(
    model=best_model,
    time_series=time_series,
    window=7,
    scaler_X=scaler_X,
    scaler_y=scaler_y,
    id_holidays=id_holidays
)

# %%
# Combine historical and predicted data for plotting
historical_data = time_series.tail(30)  # Last 30 days of historical data
combined_data = pd.concat([historical_data['revenue'], predictions_df['revenue']])

# Visualize historical and predicted revenue with smooth transition
plt.figure(figsize=(12, 6))
plt.plot(combined_data.index, combined_data.values, label='Revenue', color='blue', marker='o')

# Highlight the transition with a vertical line (optional)
last_historical_date = historical_data.index[-1]

plt.axvline(x=last_historical_date, color='gray', linestyle='--', label='Historical to Predicted')
plt.title('Revenue: Historical dan 7-Day Forecast')
plt.xlabel('Date')
plt.ylabel('Revenue')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Display predictions and updated time_series
print("Predicted revenue for the next 7 days:")
print(predictions_df)
print("\nUpdated time_series tail:")
print(time_series_updated.tail(7))
# Out:
# Predicted revenue for the next 7 days:
#                revenue
# date
# 2025-05-03  66411140.0
# 2025-05-04  60570204.0
# 2025-05-05  67849048.0
# 2025-05-06  57111776.0
# 2025-05-07  18285910.0
# 2025-05-08  19280998.0
# 2025-05-09  20323536.0
#
# Updated time_series tail:
#                revenue  rollingAvg7d  is_holiday  is_payday  is_weekend
# 2025-05-03  66411140.0  3.941092e+07           0          1           1
# 2025-05-04  60570204.0  4.451439e+07           0          1           1
# 2025-05-05  67849048.0  5.227380e+07           0          1           0
# 2025-05-06  57111776.0  5.826837e+07           0          0           0
# 2025-05-07  18285910.0  5.832999e+07           0          0           0
# 2025-05-08  19280998.0  5.795319e+07           0          0           0
# 2025-05-09  20323536.0  4.426180e+07           0          0           0

# %%
best_model.save(f'model_{store_type_id}.keras')
