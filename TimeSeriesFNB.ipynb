# %% [markdown]
# <a href="https://colab.research.google.com/github/zhulkhoirrifat/nuka-pos/blob/main/TimeSeriesFNB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import holidays
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split, GridSearchCV, TimeSeriesSplit
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
products_df = pd.read_csv('products.csv')
transactions_df = pd.read_csv('transactions.csv')
transaction_details_df = pd.read_csv('transaction_details.csv')
stores_df = pd.read_csv('stores.csv')

# %%
transactions_df = transactions_df.rename(columns={
    'discount': 'discountPerson',
    'status': 'statusTransaction'
})
products_df = products_df.rename(columns={
    'name': 'productName',
    'description': 'descriptionProduct',
    'discount': 'productDiscount'
})
stores_df = stores_df.rename(columns={
    'name': 'storeName',
    'description': 'storeDescription',
    'status': 'storeStatus'
})

# %%
transactions_transaction_details_merge = pd.merge(
    transactions_df,
    transaction_details_df,
    on='transactionId',
    how='left'
)

transactions_products_merge = pd.merge(
    transactions_transaction_details_merge,
    products_df,
    on='productId',
    how='left'
)

final_df = pd.merge(
    transactions_products_merge,
    stores_df,
    on='storeId',
    how='left'
)

# %%
final_df.columns
# Out:
# Index(['transactionId', 'invoiceId', 'customerId', 'userId', 'storeId',
#        'paymentMethodId', 'totalAmount', 'cash', 'change', 'discountPerson',
#        'transactionDate', 'statusTransaction', 'transactionDetailId',
#        'productId', 'variantId', 'quantity', 'subtotal', 'productCode',
#        'serialNumber', 'categoryId', 'productName', 'descriptionProduct',
#        'productDiscount', 'basePrice', 'imageUrl', 'isActive', 'StoreCode',
#        'tenantId', 'storeName', 'address', 'email', 'image', 'provinceId',
#        'cityId', 'districtId', 'villageId', 'storeTypeId', 'postalCode',
#        'storeDescription', 'phoneNumber', 'logo', 'permitCertificate',
#        'storeStatus'],
#       dtype='object')

# %%
final_df
# Out:
#         transactionId         invoiceId  customerId  userId  storeId  \
# 0                   1  INV-400629006034         NaN     119        1
# 1                   2  INV-772203887595      2421.0     119        1
# 2                   3  INV-776762836288      1300.0      71        1
# 3                   4  INV-414346015673         NaN     119        1
# 4                   4  INV-414346015673         NaN     119        1
# ...               ...               ...         ...     ...      ...
# 875583         729663  INV-566775883092         NaN      82       30
# 875584         729664  INV-637683440445       785.0      82       30
# 875585         729665  INV-741019537724      2318.0      82       30
# 875586         729666  INV-109100996047         NaN      82       30
# 875587         729667  INV-765851846346         NaN      82       30
#
#         paymentMethodId  totalAmount           cash      change  \
# 0                     7      57151.6   57859.445466  707.845466
# 1                     5      57354.0   58012.820926  658.820926
# 2                     3      57341.9   58152.430705  810.530705
# 3                     3     100818.6  101796.585871  977.985871
# 4                     3     100818.6  101796.585871  977.985871
# ...                 ...          ...            ...         ...
# 875583                5      50629.0   51315.574218  686.574218
# 875584                1      56531.2   56631.625047  100.425047
# 875585                4      57185.7   57531.031116  345.331116
# 875586                5      57327.6   58239.223844  911.623844
# 875587                4      43367.5   43677.144171  309.644171
#
#         discountPerson  ... cityId districtId  villageId  storeTypeId  \
# 0                    0  ...     71       5753      60900            4
# 1                    0  ...     71       5753      60900            4
# 2                    0  ...     71       5753      60900            4
# 3                   10  ...     71       5753      60900            4
# 4                   10  ...     71       5753      60900            4
# ...                ...  ...    ...        ...        ...          ...
# 875583              10  ...     71       5693      61718            6
# 875584               0  ...     71       5693      61718            6
# 875585               0  ...     71       5693      61718            6
# 875586               0  ...     71       5693      61718            6
# 875587               0  ...     71       5693      61718            6
#
#         postalCode                                   storeDescription  \
# 0              984  Explicabo rerum eum veritatis quos doloremque ...
# 1              984  Explicabo rerum eum veritatis quos doloremque ...
# 2              984  Explicabo rerum eum veritatis quos doloremque ...
# 3              984  Explicabo rerum eum veritatis quos doloremque ...
# 4              984  Explicabo rerum eum veritatis quos doloremque ...
# ...            ...                                                ...
# 875583       85193  Illum sapiente esse quas. Rerum beatae digniss...
# 875584       85193  Illum sapiente esse quas. Rerum beatae digniss...
# 875585       85193  Illum sapiente esse quas. Rerum beatae digniss...
# 875586       85193  Illum sapiente esse quas. Rerum beatae digniss...
# 875587       85193  Illum sapiente esse quas. Rerum beatae digniss...
#
#          phoneNumber                             logo  \
# 0       628181628694    https://picsum.photos/104/559
# 1       628181628694    https://picsum.photos/104/559
# 2       628181628694    https://picsum.photos/104/559
# 3       628181628694    https://picsum.photos/104/559
# 4       628181628694    https://picsum.photos/104/559
# ...              ...                              ...
# 875583  628516603904  https://placekitten.com/635/655
# 875584  628516603904  https://placekitten.com/635/655
# 875585  628516603904  https://placekitten.com/635/655
# 875586  628516603904  https://placekitten.com/635/655
# 875587  628516603904  https://placekitten.com/635/655
#
#                       permitCertificate  storeStatus
# 0         https://picsum.photos/477/614       ACTIVE
# 1         https://picsum.photos/477/614       ACTIVE
# 2         https://picsum.photos/477/614       ACTIVE
# 3         https://picsum.photos/477/614       ACTIVE
# 4         https://picsum.photos/477/614       ACTIVE
# ...                                 ...          ...
# 875583  https://placekitten.com/168/455       ACTIVE
# 875584  https://placekitten.com/168/455       ACTIVE
# 875585  https://placekitten.com/168/455       ACTIVE
# 875586  https://placekitten.com/168/455       ACTIVE
# 875587  https://placekitten.com/168/455       ACTIVE
#
# [875588 rows x 43 columns]

# %%
final_df = final_df[final_df['storeTypeId'] == 1]
final_df
# Out:
#         transactionId         invoiceId  customerId  userId  storeId  \
# 148475         123795  INV-740893660041         NaN      64        6
# 148476         123796  INV-656820679399      6382.0     108        6
# 148477         123797  INV-418689168457      3414.0     112        6
# 148478         123798  INV-964756977928      6387.0     111        6
# 148479         123799  INV-143504571282      1245.0      64        6
# ...               ...               ...         ...     ...      ...
# 864063         720069  INV-328837786053       546.0      67       28
# 864064         720070  INV-347338042404         NaN      74       28
# 864065         720070  INV-347338042404         NaN      74       28
# 864066         720071  INV-509619482925      4017.0      61       28
# 864067         720072  INV-361736519583       337.0     123       28
#
#         paymentMethodId  totalAmount          cash      change  \
# 148475                7      25750.3  26045.973611  295.673611
# 148476                6      25934.7  26523.353267  588.653267
# 148477                3      27088.6  27679.460648  590.860648
# 148478                6      57440.9  57572.521655  131.621655
# 148479                3      28017.7  28031.183629   13.483629
# ...                 ...          ...           ...         ...
# 864063                5      19518.4  20098.113400  579.713400
# 864064                6      34086.8  34558.511724  471.711724
# 864065                6      34086.8  34558.511724  471.711724
# 864066                4      56426.7  56755.375849  328.675849
# 864067                2      56137.4  56137.400000    0.000000
#
#         discountPerson  ... cityId districtId  villageId  storeTypeId  \
# 148475               3  ...     71       5689      61407            1
# 148476               0  ...     71       5689      61407            1
# 148477              16  ...     71       5689      61407            1
# 148478               0  ...     71       5689      61407            1
# 148479              17  ...     71       5689      61407            1
# ...                ...  ...    ...        ...        ...          ...
# 864063               0  ...     71       5753      63153            1
# 864064               0  ...     71       5753      63153            1
# 864065               0  ...     71       5753      63153            1
# 864066               0  ...     71       5753      63153            1
# 864067               0  ...     71       5753      63153            1
#
#         postalCode                                   storeDescription  \
# 148475       15265  Hic quas assumenda quas cumque quo totam. Ex u...
# 148476       15265  Hic quas assumenda quas cumque quo totam. Ex u...
# 148477       15265  Hic quas assumenda quas cumque quo totam. Ex u...
# 148478       15265  Hic quas assumenda quas cumque quo totam. Ex u...
# 148479       15265  Hic quas assumenda quas cumque quo totam. Ex u...
# ...            ...                                                ...
# 864063       46811  Explicabo tempora eligendi. Velit at illo odio...
# 864064       46811  Explicabo tempora eligendi. Velit at illo odio...
# 864065       46811  Explicabo tempora eligendi. Velit at illo odio...
# 864066       46811  Explicabo tempora eligendi. Velit at illo odio...
# 864067       46811  Explicabo tempora eligendi. Velit at illo odio...
#
#          phoneNumber                           logo  \
# 148475  628183968324  https://picsum.photos/954/556
# 148476  628183968324  https://picsum.photos/954/556
# 148477  628183968324  https://picsum.photos/954/556
# 148478  628183968324  https://picsum.photos/954/556
# 148479  628183968324  https://picsum.photos/954/556
# ...              ...                            ...
# 864063  628787253709   https://picsum.photos/491/34
# 864064  628787253709   https://picsum.photos/491/34
# 864065  628787253709   https://picsum.photos/491/34
# 864066  628787253709   https://picsum.photos/491/34
# 864067  628787253709   https://picsum.photos/491/34
#
#                       permitCertificate  storeStatus
# 148475   https://dummyimage.com/856x266       ACTIVE
# 148476   https://dummyimage.com/856x266       ACTIVE
# 148477   https://dummyimage.com/856x266       ACTIVE
# 148478   https://dummyimage.com/856x266       ACTIVE
# 148479   https://dummyimage.com/856x266       ACTIVE
# ...                                 ...          ...
# 864063  https://placekitten.com/932/983       ACTIVE
# 864064  https://placekitten.com/932/983       ACTIVE
# 864065  https://placekitten.com/932/983       ACTIVE
# 864066  https://placekitten.com/932/983       ACTIVE
# 864067  https://placekitten.com/932/983       ACTIVE
#
# [193810 rows x 43 columns]

# %%
final_df['storeId'].value_counts()
# Out:
# storeId
# 28    73596
# 9     56055
# 6     41157
# 15    23002
# Name: count, dtype: int64

# %%
checked = final_df[final_df['storeId'] == 28]

# %%
checked.hist(bins=50, figsize=(20, 15))
plt.show()

# %%
final_df = final_df[final_df['storeId'] == 28]

# %%
numeric_columns = final_df.select_dtypes(include='number').columns

plt.figure(figsize=(15, 5 * len(numeric_columns)))

for index, column in enumerate(numeric_columns, 1):
    plt.subplot(len(numeric_columns), 1, index)
    sns.boxplot(x=final_df[column])
    plt.title(f'Boxplot kolom: {column}')
    plt.tight_layout()

plt.show()

# %%
def detect_outliers_iqr(data):
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return (data < lower_bound) | (data > upper_bound)

outliers = detect_outliers_iqr(final_df['totalAmount'])

print(f"Number of outliers detected: {sum(outliers)}")
# Out:
# Number of outliers detected: 1778

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

ax1.scatter(range(len(final_df)), final_df['totalAmount'], c=['blue' if not x else 'red' for x in outliers])
ax1.set_title('Outlier pada totalAmount (Scatter Plot)')
ax1.set_xlabel('Index')
ax1.set_ylabel('Value')

sns.boxplot(x=final_df['totalAmount'], ax=ax2)
ax2.set_title('Outlier pada totalAmount (Box Plot)')
ax2.set_xlabel('Value')

plt.tight_layout()
plt.show()

# %%
final_df['transactionDate'] = pd.to_datetime(final_df['transactionDate'])
# Out:
# <ipython-input-98-0ea110b0c623>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['transactionDate'] = pd.to_datetime(final_df['transactionDate'])

# %%
final_df['transactionSize'] = final_df.groupby('transactionId')['quantity'].transform('sum')
# Out:
# <ipython-input-99-e90816ecff4a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['transactionSize'] = final_df.groupby('transactionId')['quantity'].transform('sum')

# %%
final_df
# Out:
#         transactionId         invoiceId  customerId  userId  storeId  \
# 790472         658683  INV-463649690560         NaN     123       28
# 790473         658684  INV-469186865992         NaN     109       28
# 790474         658684  INV-469186865992         NaN     109       28
# 790475         658685  INV-982496455762      5229.0      74       28
# 790476         658686  INV-574857750023      1058.0     109       28
# ...               ...               ...         ...     ...      ...
# 864063         720069  INV-328837786053       546.0      67       28
# 864064         720070  INV-347338042404         NaN      74       28
# 864065         720070  INV-347338042404         NaN      74       28
# 864066         720071  INV-509619482925      4017.0      61       28
# 864067         720072  INV-361736519583       337.0     123       28
#
#         paymentMethodId  totalAmount          cash      change  \
# 790472                1      13381.5  13631.782776  250.282776
# 790473                6      34446.5  35417.494725  970.994725
# 790474                6      34446.5  35417.494725  970.994725
# 790475                5      18615.3  19359.520058  744.220058
# 790476                2      32125.5  32125.500000    0.000000
# ...                 ...          ...           ...         ...
# 864063                5      19518.4  20098.113400  579.713400
# 864064                6      34086.8  34558.511724  471.711724
# 864065                6      34086.8  34558.511724  471.711724
# 864066                4      56426.7  56755.375849  328.675849
# 864067                2      56137.4  56137.400000    0.000000
#
#         discountPerson  ... districtId villageId  storeTypeId  postalCode  \
# 790472               0  ...       5753     63153            1       46811
# 790473               0  ...       5753     63153            1       46811
# 790474               0  ...       5753     63153            1       46811
# 790475               0  ...       5753     63153            1       46811
# 790476               0  ...       5753     63153            1       46811
# ...                ...  ...        ...       ...          ...         ...
# 864063               0  ...       5753     63153            1       46811
# 864064               0  ...       5753     63153            1       46811
# 864065               0  ...       5753     63153            1       46811
# 864066               0  ...       5753     63153            1       46811
# 864067               0  ...       5753     63153            1       46811
#
#                                          storeDescription   phoneNumber  \
# 790472  Explicabo tempora eligendi. Velit at illo odio...  628787253709
# 790473  Explicabo tempora eligendi. Velit at illo odio...  628787253709
# 790474  Explicabo tempora eligendi. Velit at illo odio...  628787253709
# 790475  Explicabo tempora eligendi. Velit at illo odio...  628787253709
# 790476  Explicabo tempora eligendi. Velit at illo odio...  628787253709
# ...                                                   ...           ...
# 864063  Explicabo tempora eligendi. Velit at illo odio...  628787253709
# 864064  Explicabo tempora eligendi. Velit at illo odio...  628787253709
# 864065  Explicabo tempora eligendi. Velit at illo odio...  628787253709
# 864066  Explicabo tempora eligendi. Velit at illo odio...  628787253709
# 864067  Explicabo tempora eligendi. Velit at illo odio...  628787253709
#
#                                 logo                permitCertificate  \
# 790472  https://picsum.photos/491/34  https://placekitten.com/932/983
# 790473  https://picsum.photos/491/34  https://placekitten.com/932/983
# 790474  https://picsum.photos/491/34  https://placekitten.com/932/983
# 790475  https://picsum.photos/491/34  https://placekitten.com/932/983
# 790476  https://picsum.photos/491/34  https://placekitten.com/932/983
# ...                              ...                              ...
# 864063  https://picsum.photos/491/34  https://placekitten.com/932/983
# 864064  https://picsum.photos/491/34  https://placekitten.com/932/983
# 864065  https://picsum.photos/491/34  https://placekitten.com/932/983
# 864066  https://picsum.photos/491/34  https://placekitten.com/932/983
# 864067  https://picsum.photos/491/34  https://placekitten.com/932/983
#
#         storeStatus  transactionSize
# 790472       ACTIVE                1
# 790473       ACTIVE                2
# 790474       ACTIVE                2
# 790475       ACTIVE                1
# 790476       ACTIVE                2
# ...             ...              ...
# 864063       ACTIVE                1
# 864064       ACTIVE                2
# 864065       ACTIVE                2
# 864066       ACTIVE                1
# 864067       ACTIVE                1
#
# [73596 rows x 44 columns]

# %%
time_series = final_df.groupby(final_df['transactionDate'].dt.date)['totalAmount'].sum().reset_index()
time_series.columns = ['date', 'revenue']
time_series['date'] = pd.to_datetime(time_series['date'])
time_series.set_index('date', inplace=True)

# %%
time_series
# Out:
#                revenue
# date
# 2024-01-01  10817801.0
# 2024-01-02   8027853.1
# 2024-01-03   9468834.6
# 2024-01-04  10320444.9
# 2024-01-05  10399640.9
# ...                ...
# 2025-04-28   2087299.0
# 2025-04-29   2346678.4
# 2025-04-30   1796310.1
# 2025-05-01   4226452.9
# 2025-05-02  24694221.0
#
# [488 rows x 1 columns]

# %%
plt.figure(figsize=(12, 6))
plt.plot(time_series['revenue'], label='Revenue')
plt.title('Daily Revenue (F&B)')
plt.xlabel('Date')
plt.ylabel('Revenue (Rp)')
plt.legend()
plt.show()

# %%
final_df['transactionDate']
# Out:
# 790472   2024-01-07 12:49:23
# 790473   2024-01-07 17:44:44
# 790474   2024-01-07 17:44:44
# 790475   2024-01-04 13:13:32
# 790476   2024-01-02 12:07:56
#                  ...
# 864063   2025-05-02 11:01:34
# 864064   2025-05-02 13:05:51
# 864065   2025-05-02 13:05:51
# 864066   2025-05-02 11:25:06
# 864067   2025-05-02 11:52:27
# Name: transactionDate, Length: 73596, dtype: datetime64[ns]

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plt.figure(figsize=(12, 4))
plot_acf(time_series['revenue'], lags=50)
plt.title('Autocorrelation Function (ACF)')
plt.show()

plt.figure(figsize=(12, 4))
plot_pacf(time_series['revenue'], lags=50)
plt.title('Partial Autocorrelation Function (PACF)')
plt.show()

# %%
time_series['rollingAvg7d'] = time_series['revenue'].rolling(window=7, min_periods=1).mean()

id_holidays = holidays.Indonesia(years=[2024, 2025])
time_series['is_holiday'] = time_series.index.isin(id_holidays).astype(int)
time_series['is_payday'] = time_series.index.day.isin([1, 2, 3, 4, 5]).astype(int)
time_series['is_weekend'] = time_series.index.weekday.isin([5, 6]).astype(int)

def create_lag(df, window=7):
    X, y, check_corr = [], [], []
    for i in range(window, len(df)):
        lag_features = df['revenue'].values[i-window:i]
        payday = df['is_payday'].values[i]
        holiday = df['is_holiday'].values[i]
        weekend = df['is_weekend'].values[i]
        rolling_avg_7d = df['rollingAvg7d'].values[i]

        full_feature = list(lag_features) + [payday, holiday, weekend, rolling_avg_7d]
        benchmark = full_feature + [df['revenue'].values[i]]

        X.append(full_feature)
        y.append(df['revenue'].values[i])
        check_corr.append(benchmark)

    return pd.DataFrame(X, columns=[f'lag_{i}' for i in range(window)] + ['is_payday', 'is_holiday', 'is_weekend', 'rollingAvg7d']), \
       pd.Series(y, name='target'), \
       pd.DataFrame(check_corr, columns=[f'lag_{i}' for i in range(window)] + ['is_payday', 'is_holiday', 'is_weekend', 'rollingAvg7d', 'target'])


X, y, check_corr = create_lag(time_series)
# Out:
# <ipython-input-106-1fac8aae5783>:4: FutureWarning: The behavior of 'isin' with dtype=datetime64[ns] and castable values (e.g. strings) is deprecated. In a future version, these will not be considered matching by isin. Explicitly cast to the appropriate dtype before calling isin instead.
#   time_series['is_holiday'] = time_series.index.isin(id_holidays).astype(int)

# %%
check_corr
# Out:
#           lag_0       lag_1       lag_2       lag_3       lag_4       lag_5  \
# 0    10817801.0   8027853.1   9468834.6  10320444.9  10399640.9   5925855.7
# 1     8027853.1   9468834.6  10320444.9  10399640.9   5925855.7  11207197.7
# 2     9468834.6  10320444.9  10399640.9   5925855.7  11207197.7   2177103.2
# 3    10320444.9  10399640.9   5925855.7  11207197.7   2177103.2   2871145.4
# 4    10399640.9   5925855.7  11207197.7   2177103.2   2871145.4    795837.6
# ..          ...         ...         ...         ...         ...         ...
# 476   2049547.8   2028355.1   1834752.6   1526154.4   2530471.5   6128765.0
# 477   2028355.1   1834752.6   1526154.4   2530471.5   6128765.0   9484359.0
# 478   1834752.6   1526154.4   2530471.5   6128765.0   9484359.0   2087299.0
# 479   1526154.4   2530471.5   6128765.0   9484359.0   2087299.0   2346678.4
# 480   2530471.5   6128765.0   9484359.0   2087299.0   2346678.4   1796310.1
#
#           lag_6  is_payday  is_holiday  is_weekend  rollingAvg7d      target
# 0    11207197.7          0           0           0  8.218133e+06   2177103.2
# 1     2177103.2          0           0           0  7.481460e+06   2871145.4
# 2     2871145.4          0           0           0  6.242461e+06    795837.6
# 3      795837.6          0           0           0  5.023524e+06   1787889.6
# 4     1787889.6          0           0           0  3.978366e+06   3083532.9
# ..          ...        ...         ...         ...           ...         ...
# 476   9484359.0          0           0           0  3.660022e+06   2087299.0
# 477   2087299.0          0           0           0  3.705497e+06   2346678.4
# 478   2346678.4          0           0           0  3.700005e+06   1796310.1
# 479   1796310.1          1           1           0  4.085762e+06   4226452.9
# 480   4226452.9          1           0           0  7.252012e+06  24694221.0
#
# [481 rows x 12 columns]

# %%
corr_matrix = check_corr.corr()

plt.figure(figsize=(16, 12))

sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')

plt.title('Korelasi Antar Variabel')

plt.show()

# %%
X
# Out:
#           lag_0       lag_1       lag_2       lag_3       lag_4       lag_5  \
# 0    10817801.0   8027853.1   9468834.6  10320444.9  10399640.9   5925855.7
# 1     8027853.1   9468834.6  10320444.9  10399640.9   5925855.7  11207197.7
# 2     9468834.6  10320444.9  10399640.9   5925855.7  11207197.7   2177103.2
# 3    10320444.9  10399640.9   5925855.7  11207197.7   2177103.2   2871145.4
# 4    10399640.9   5925855.7  11207197.7   2177103.2   2871145.4    795837.6
# ..          ...         ...         ...         ...         ...         ...
# 476   2049547.8   2028355.1   1834752.6   1526154.4   2530471.5   6128765.0
# 477   2028355.1   1834752.6   1526154.4   2530471.5   6128765.0   9484359.0
# 478   1834752.6   1526154.4   2530471.5   6128765.0   9484359.0   2087299.0
# 479   1526154.4   2530471.5   6128765.0   9484359.0   2087299.0   2346678.4
# 480   2530471.5   6128765.0   9484359.0   2087299.0   2346678.4   1796310.1
#
#           lag_6  is_payday  is_holiday  is_weekend  rollingAvg7d
# 0    11207197.7          0           0           0  8.218133e+06
# 1     2177103.2          0           0           0  7.481460e+06
# 2     2871145.4          0           0           0  6.242461e+06
# 3      795837.6          0           0           0  5.023524e+06
# 4     1787889.6          0           0           0  3.978366e+06
# ..          ...        ...         ...         ...           ...
# 476   9484359.0          0           0           0  3.660022e+06
# 477   2087299.0          0           0           0  3.705497e+06
# 478   2346678.4          0           0           0  3.700005e+06
# 479   1796310.1          1           1           0  4.085762e+06
# 480   4226452.9          1           0           0  7.252012e+06
#
# [481 rows x 11 columns]

# %%
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1)).ravel()

X_scaled = X_scaled.reshape((X_scaled.shape[0], X_scaled.shape[1], 1))

# %%
train_size = int(len(X_scaled) * 0.8)
X_train, X_test = X_scaled[:train_size], X_scaled[train_size:]
y_train, y_test = y_scaled[:train_size], y_scaled[train_size:]

# %%
# !pip install keras_tuner
# Out:
# Requirement already satisfied: keras_tuner in /usr/local/lib/python3.11/dist-packages (1.4.7)
# Requirement already satisfied: keras in /usr/local/lib/python3.11/dist-packages (from keras_tuner) (3.8.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from keras_tuner) (24.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from keras_tuner) (2.32.3)
# Requirement already satisfied: kt-legacy in /usr/local/lib/python3.11/dist-packages (from keras_tuner) (1.0.5)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from keras->keras_tuner) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from keras->keras_tuner) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras->keras_tuner) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras->keras_tuner) (0.0.9)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from keras->keras_tuner) (3.13.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras->keras_tuner) (0.15.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.11/dist-packages (from keras->keras_tuner) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->keras_tuner) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->keras_tuner) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->keras_tuner) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->keras_tuner) (2025.4.26)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from optree->keras->keras_tuner) (4.13.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras->keras_tuner) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras->keras_tuner) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras->keras_tuner) (0.1.2)

# %%
import keras_tuner as kt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Bidirectional, LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import R2Score, MeanSquaredError, MeanAbsoluteError

# %%
def model_builder(hp):
    model = Sequential()

    model.add(Conv1D(
        filters=hp.Int("conv_filters", min_value=32, max_value=128, step=16),
        kernel_size=hp.Int("kernel_size", min_value=2, max_value=5, step=1),
        activation='relu',
        padding='same',
        input_shape=(X_train.shape[1], X_train.shape[2])
    ))

    model.add(MaxPooling1D(pool_size=1))

    model.add(Conv1D(
        filters=hp.Int("conv_filters_2", min_value=64, max_value=256, step=16),
        kernel_size=hp.Int("kernel_size", min_value=2, max_value=5, step=1),
        activation='relu'
    ))
    model.add(MaxPooling1D(pool_size=2))

    model.add(Bidirectional(
        LSTM(
            units=hp.Int("bilstm_units", min_value=16, max_value=128, step=16),
            activation=hp.Choice("lstm_activation", ["relu", "tanh"]),
            return_sequences=True
        )
    ))
    model.add(Dropout(
        rate=hp.Float("dropout_1", min_value=0.2, max_value=0.5, step=0.1)
    ))
    model.add(LSTM(
        units=hp.Int("lstm_units", min_value=16, max_value=64, step=16),
        activation=hp.Choice("lstm2_activation", ["relu", "tanh"]),
        return_sequences=False
    ))
    model.add(Dropout(
        rate=hp.Float("dropout_2", min_value=0.2, max_value=0.5, step=0.1)
    ))

    model.add(Dense(
        units=hp.Int("dense_units", min_value=16, max_value=64, step=16),
        activation=hp.Choice("dense_activation", ["relu", "tanh"])
    ))

    model.add(Dropout(
        rate=hp.Float("dropout_3", min_value=0.2, max_value=0.5, step=0.1)
    ))

    model.add(Dense(
        units=hp.Int("dense_units_2", min_value=32, max_value=128, step=16),
        activation=hp.Choice("dense_activation", ["relu", "tanh"])
    ))

    model.add(Dense(1))

    model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error', metrics=[R2Score(), MeanSquaredError(), MeanAbsoluteError])

    return model

# model = Sequential([
#     Bidirectional(LSTM(32, activation='relu', return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2]))),
#     Dropout(0.2),
#     LSTM(64, activation='relu', return_sequences=False),
#     Dropout(0.2),
#     Dense(32, activation='relu'),
#     Dense(1)
# ])

# %%
# !rm -rf tuner_dir/

# %%
from keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=3, mode='max', start_from_epoch=30, restore_best_weights=True)


tuner = kt.RandomSearch(
    model_builder,
    objective='val_loss',
    max_trials=20,
    executions_per_trial=1,
    directory='tuner_dir',
    project_name='lstm_tuning'
)

tuner.search(X_train, y_train, epochs=100, validation_split=0.2, callbacks=[early_stop])
# Out:
# Trial 20 Complete [00h 00m 30s]
# val_loss: 0.0024484707973897457
#
# Best val_loss So Far: 0.0009335608338005841
# Total elapsed time: 00h 11m 29s

# %%
best_hp = tuner.get_best_hyperparameters(1)[0]
print(best_hp.values)
best_model = tuner.hypermodel.build(best_hp)
# Out:
# {'conv_filters': 96, 'kernel_size': 5, 'conv_filters_2': 80, 'bilstm_units': 112, 'lstm_activation': 'tanh', 'dropout_1': 0.30000000000000004, 'lstm_units': 64, 'lstm2_activation': 'tanh', 'dropout_2': 0.2, 'dense_units': 64, 'dense_activation': 'relu', 'dropout_3': 0.4, 'dense_units_2': 48}

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_r2_score', patience=1, restore_best_weights=True)

# %%
history = best_model.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=32,
    validation_split=0.1,
    verbose=1,
    # callbacks=[early_stopping]
)
# Out:
# Epoch 1/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 216ms/step - loss: 0.0499 - mean_absolute_error: 0.1576 - mean_squared_error: 0.0499 - r2_score: -0.4195 - val_loss: 0.0219 - val_mean_absolute_error: 0.1220 - val_mean_squared_error: 0.0219 - val_r2_score: 0.3627
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0236 - mean_absolute_error: 0.1198 - mean_squared_error: 0.0236 - r2_score: 0.3473 - val_loss: 0.0134 - val_mean_absolute_error: 0.0918 - val_mean_squared_error: 0.0134 - val_r2_score: 0.6111
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.0175 - mean_absolute_error: 0.0980 - mean_squared_error: 0.0175 - r2_score: 0.5180 - val_loss: 0.0067 - val_mean_absolute_error: 0.0591 - val_mean_squared_error: 0.0067 - val_r2_score: 0.8064
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.0089 - mean_absolute_error: 0.0647 - mean_squared_error: 0.0089 - r2_score: 0.7339 - val_loss: 0.0024 - val_mean_absolute_error: 0.0365 - val_mean_squared_error: 0.0024 - val_r2_score: 0.9304
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0055 - mean_absolute_error: 0.0522 - mean_squared_error: 0.0055 - r2_score: 0.8565 - val_loss: 0.0025 - val_mean_absolute_error: 0.0378 - val_mean_squared_error: 0.0025 - val_r2_score: 0.9270
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0069 - mean_absolute_error: 0.0554 - mean_squared_error: 0.0069 - r2_score: 0.8210 - val_loss: 0.0020 - val_mean_absolute_error: 0.0337 - val_mean_squared_error: 0.0020 - val_r2_score: 0.9408
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0048 - mean_absolute_error: 0.0479 - mean_squared_error: 0.0048 - r2_score: 0.8617 - val_loss: 0.0014 - val_mean_absolute_error: 0.0296 - val_mean_squared_error: 0.0014 - val_r2_score: 0.9592
# Epoch 8/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0041 - mean_absolute_error: 0.0465 - mean_squared_error: 0.0041 - r2_score: 0.8983 - val_loss: 0.0015 - val_mean_absolute_error: 0.0290 - val_mean_squared_error: 0.0015 - val_r2_score: 0.9578
# Epoch 9/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0060 - mean_absolute_error: 0.0477 - mean_squared_error: 0.0060 - r2_score: 0.8545 - val_loss: 0.0022 - val_mean_absolute_error: 0.0351 - val_mean_squared_error: 0.0022 - val_r2_score: 0.9349
# Epoch 10/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0041 - mean_absolute_error: 0.0450 - mean_squared_error: 0.0041 - r2_score: 0.8730 - val_loss: 0.0019 - val_mean_absolute_error: 0.0305 - val_mean_squared_error: 0.0019 - val_r2_score: 0.9433
# Epoch 11/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0032 - mean_absolute_error: 0.0410 - mean_squared_error: 0.0032 - r2_score: 0.9039 - val_loss: 0.0031 - val_mean_absolute_error: 0.0399 - val_mean_squared_error: 0.0031 - val_r2_score: 0.9102
# Epoch 12/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0039 - mean_absolute_error: 0.0444 - mean_squared_error: 0.0039 - r2_score: 0.8917 - val_loss: 0.0020 - val_mean_absolute_error: 0.0326 - val_mean_squared_error: 0.0020 - val_r2_score: 0.9413
# Epoch 13/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0046 - mean_absolute_error: 0.0447 - mean_squared_error: 0.0046 - r2_score: 0.8729 - val_loss: 0.0033 - val_mean_absolute_error: 0.0428 - val_mean_squared_error: 0.0033 - val_r2_score: 0.9039
# Epoch 14/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0040 - mean_absolute_error: 0.0452 - mean_squared_error: 0.0040 - r2_score: 0.8767 - val_loss: 0.0023 - val_mean_absolute_error: 0.0357 - val_mean_squared_error: 0.0023 - val_r2_score: 0.9332
# Epoch 15/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0042 - mean_absolute_error: 0.0456 - mean_squared_error: 0.0042 - r2_score: 0.8867 - val_loss: 0.0015 - val_mean_absolute_error: 0.0302 - val_mean_squared_error: 0.0015 - val_r2_score: 0.9568
# Epoch 16/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0038 - mean_absolute_error: 0.0442 - mean_squared_error: 0.0038 - r2_score: 0.9088 - val_loss: 0.0011 - val_mean_absolute_error: 0.0250 - val_mean_squared_error: 0.0011 - val_r2_score: 0.9673
# Epoch 17/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0038 - mean_absolute_error: 0.0419 - mean_squared_error: 0.0038 - r2_score: 0.8884 - val_loss: 0.0011 - val_mean_absolute_error: 0.0255 - val_mean_squared_error: 0.0011 - val_r2_score: 0.9684
# Epoch 18/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0030 - mean_absolute_error: 0.0397 - mean_squared_error: 0.0030 - r2_score: 0.9120 - val_loss: 0.0013 - val_mean_absolute_error: 0.0260 - val_mean_squared_error: 0.0013 - val_r2_score: 0.9615
# Epoch 19/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0030 - mean_absolute_error: 0.0389 - mean_squared_error: 0.0030 - r2_score: 0.9184 - val_loss: 0.0016 - val_mean_absolute_error: 0.0301 - val_mean_squared_error: 0.0016 - val_r2_score: 0.9525
# Epoch 20/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0042 - mean_absolute_error: 0.0468 - mean_squared_error: 0.0042 - r2_score: 0.8915 - val_loss: 0.0024 - val_mean_absolute_error: 0.0357 - val_mean_squared_error: 0.0024 - val_r2_score: 0.9288
# Epoch 21/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0024 - mean_absolute_error: 0.0357 - mean_squared_error: 0.0024 - r2_score: 0.9262 - val_loss: 0.0019 - val_mean_absolute_error: 0.0316 - val_mean_squared_error: 0.0019 - val_r2_score: 0.9459
# Epoch 22/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0022 - mean_absolute_error: 0.0357 - mean_squared_error: 0.0022 - r2_score: 0.9337 - val_loss: 0.0015 - val_mean_absolute_error: 0.0293 - val_mean_squared_error: 0.0015 - val_r2_score: 0.9560
# Epoch 23/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0020 - mean_absolute_error: 0.0336 - mean_squared_error: 0.0020 - r2_score: 0.9368 - val_loss: 0.0020 - val_mean_absolute_error: 0.0325 - val_mean_squared_error: 0.0020 - val_r2_score: 0.9433
# Epoch 24/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0027 - mean_absolute_error: 0.0371 - mean_squared_error: 0.0027 - r2_score: 0.9134 - val_loss: 0.0014 - val_mean_absolute_error: 0.0279 - val_mean_squared_error: 0.0014 - val_r2_score: 0.9583
# Epoch 25/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0029 - mean_absolute_error: 0.0384 - mean_squared_error: 0.0029 - r2_score: 0.9155 - val_loss: 0.0011 - val_mean_absolute_error: 0.0252 - val_mean_squared_error: 0.0011 - val_r2_score: 0.9680
# Epoch 26/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0035 - mean_absolute_error: 0.0382 - mean_squared_error: 0.0035 - r2_score: 0.9133 - val_loss: 9.3514e-04 - val_mean_absolute_error: 0.0234 - val_mean_squared_error: 9.3514e-04 - val_r2_score: 0.9728
# Epoch 27/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0024 - mean_absolute_error: 0.0351 - mean_squared_error: 0.0024 - r2_score: 0.9315 - val_loss: 0.0014 - val_mean_absolute_error: 0.0271 - val_mean_squared_error: 0.0014 - val_r2_score: 0.9597
# Epoch 28/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0025 - mean_absolute_error: 0.0357 - mean_squared_error: 0.0025 - r2_score: 0.9277 - val_loss: 0.0016 - val_mean_absolute_error: 0.0304 - val_mean_squared_error: 0.0016 - val_r2_score: 0.9547
# Epoch 29/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0031 - mean_absolute_error: 0.0382 - mean_squared_error: 0.0031 - r2_score: 0.9130 - val_loss: 0.0020 - val_mean_absolute_error: 0.0319 - val_mean_squared_error: 0.0020 - val_r2_score: 0.9420
# Epoch 30/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0037 - mean_absolute_error: 0.0408 - mean_squared_error: 0.0037 - r2_score: 0.8868 - val_loss: 8.8974e-04 - val_mean_absolute_error: 0.0236 - val_mean_squared_error: 8.8974e-04 - val_r2_score: 0.9741
# Epoch 31/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0023 - mean_absolute_error: 0.0359 - mean_squared_error: 0.0023 - r2_score: 0.9372 - val_loss: 9.1565e-04 - val_mean_absolute_error: 0.0238 - val_mean_squared_error: 9.1565e-04 - val_r2_score: 0.9734
# Epoch 32/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0025 - mean_absolute_error: 0.0361 - mean_squared_error: 0.0025 - r2_score: 0.9220 - val_loss: 0.0011 - val_mean_absolute_error: 0.0254 - val_mean_squared_error: 0.0011 - val_r2_score: 0.9678
# Epoch 33/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0041 - mean_absolute_error: 0.0443 - mean_squared_error: 0.0041 - r2_score: 0.8966 - val_loss: 0.0013 - val_mean_absolute_error: 0.0270 - val_mean_squared_error: 0.0013 - val_r2_score: 0.9617
# Epoch 34/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0030 - mean_absolute_error: 0.0404 - mean_squared_error: 0.0030 - r2_score: 0.8966 - val_loss: 9.7807e-04 - val_mean_absolute_error: 0.0235 - val_mean_squared_error: 9.7807e-04 - val_r2_score: 0.9716
# Epoch 35/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0019 - mean_absolute_error: 0.0318 - mean_squared_error: 0.0019 - r2_score: 0.9354 - val_loss: 0.0014 - val_mean_absolute_error: 0.0265 - val_mean_squared_error: 0.0014 - val_r2_score: 0.9602
# Epoch 36/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0015 - mean_absolute_error: 0.0299 - mean_squared_error: 0.0015 - r2_score: 0.9565 - val_loss: 0.0011 - val_mean_absolute_error: 0.0264 - val_mean_squared_error: 0.0011 - val_r2_score: 0.9694
# Epoch 37/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0016 - mean_absolute_error: 0.0296 - mean_squared_error: 0.0016 - r2_score: 0.9571 - val_loss: 8.2972e-04 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 8.2972e-04 - val_r2_score: 0.9759
# Epoch 38/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0019 - mean_absolute_error: 0.0322 - mean_squared_error: 0.0019 - r2_score: 0.9473 - val_loss: 7.7601e-04 - val_mean_absolute_error: 0.0218 - val_mean_squared_error: 7.7601e-04 - val_r2_score: 0.9774
# Epoch 39/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0018 - mean_absolute_error: 0.0313 - mean_squared_error: 0.0018 - r2_score: 0.9489 - val_loss: 9.4105e-04 - val_mean_absolute_error: 0.0240 - val_mean_squared_error: 9.4105e-04 - val_r2_score: 0.9726
# Epoch 40/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.0025 - mean_absolute_error: 0.0341 - mean_squared_error: 0.0025 - r2_score: 0.9339 - val_loss: 7.6060e-04 - val_mean_absolute_error: 0.0221 - val_mean_squared_error: 7.6060e-04 - val_r2_score: 0.9779
# Epoch 41/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0021 - mean_absolute_error: 0.0323 - mean_squared_error: 0.0021 - r2_score: 0.9420 - val_loss: 0.0013 - val_mean_absolute_error: 0.0266 - val_mean_squared_error: 0.0013 - val_r2_score: 0.9622
# Epoch 42/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0022 - mean_absolute_error: 0.0326 - mean_squared_error: 0.0022 - r2_score: 0.9376 - val_loss: 9.7890e-04 - val_mean_absolute_error: 0.0241 - val_mean_squared_error: 9.7890e-04 - val_r2_score: 0.9715
# Epoch 43/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0019 - mean_absolute_error: 0.0330 - mean_squared_error: 0.0019 - r2_score: 0.9496 - val_loss: 0.0011 - val_mean_absolute_error: 0.0254 - val_mean_squared_error: 0.0011 - val_r2_score: 0.9691
# Epoch 44/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0016 - mean_absolute_error: 0.0282 - mean_squared_error: 0.0016 - r2_score: 0.9492 - val_loss: 0.0011 - val_mean_absolute_error: 0.0243 - val_mean_squared_error: 0.0011 - val_r2_score: 0.9677
# Epoch 45/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0019 - mean_absolute_error: 0.0310 - mean_squared_error: 0.0019 - r2_score: 0.9514 - val_loss: 0.0012 - val_mean_absolute_error: 0.0260 - val_mean_squared_error: 0.0012 - val_r2_score: 0.9655
# Epoch 46/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0017 - mean_absolute_error: 0.0295 - mean_squared_error: 0.0017 - r2_score: 0.9526 - val_loss: 0.0010 - val_mean_absolute_error: 0.0246 - val_mean_squared_error: 0.0010 - val_r2_score: 0.9706
# Epoch 47/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0017 - mean_absolute_error: 0.0295 - mean_squared_error: 0.0017 - r2_score: 0.9609 - val_loss: 9.2243e-04 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 9.2243e-04 - val_r2_score: 0.9732
# Epoch 48/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0020 - mean_absolute_error: 0.0301 - mean_squared_error: 0.0020 - r2_score: 0.9478 - val_loss: 0.0013 - val_mean_absolute_error: 0.0254 - val_mean_squared_error: 0.0013 - val_r2_score: 0.9613
# Epoch 49/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0017 - mean_absolute_error: 0.0299 - mean_squared_error: 0.0017 - r2_score: 0.9535 - val_loss: 0.0018 - val_mean_absolute_error: 0.0326 - val_mean_squared_error: 0.0018 - val_r2_score: 0.9466
# Epoch 50/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0018 - mean_absolute_error: 0.0291 - mean_squared_error: 0.0018 - r2_score: 0.9521 - val_loss: 0.0014 - val_mean_absolute_error: 0.0264 - val_mean_squared_error: 0.0014 - val_r2_score: 0.9580
# Epoch 51/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0021 - mean_absolute_error: 0.0322 - mean_squared_error: 0.0021 - r2_score: 0.9469 - val_loss: 9.1051e-04 - val_mean_absolute_error: 0.0247 - val_mean_squared_error: 9.1051e-04 - val_r2_score: 0.9735
# Epoch 52/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0020 - mean_absolute_error: 0.0300 - mean_squared_error: 0.0020 - r2_score: 0.9445 - val_loss: 6.1973e-04 - val_mean_absolute_error: 0.0193 - val_mean_squared_error: 6.1973e-04 - val_r2_score: 0.9820
# Epoch 53/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0019 - mean_absolute_error: 0.0310 - mean_squared_error: 0.0019 - r2_score: 0.9480 - val_loss: 7.4191e-04 - val_mean_absolute_error: 0.0208 - val_mean_squared_error: 7.4191e-04 - val_r2_score: 0.9784
# Epoch 54/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0015 - mean_absolute_error: 0.0266 - mean_squared_error: 0.0015 - r2_score: 0.9546 - val_loss: 7.4327e-04 - val_mean_absolute_error: 0.0211 - val_mean_squared_error: 7.4327e-04 - val_r2_score: 0.9784
# Epoch 55/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0017 - mean_absolute_error: 0.0296 - mean_squared_error: 0.0017 - r2_score: 0.9564 - val_loss: 6.9963e-04 - val_mean_absolute_error: 0.0210 - val_mean_squared_error: 6.9963e-04 - val_r2_score: 0.9797
# Epoch 56/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0014 - mean_absolute_error: 0.0271 - mean_squared_error: 0.0014 - r2_score: 0.9599 - val_loss: 7.6875e-04 - val_mean_absolute_error: 0.0216 - val_mean_squared_error: 7.6875e-04 - val_r2_score: 0.9776
# Epoch 57/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0023 - mean_absolute_error: 0.0328 - mean_squared_error: 0.0023 - r2_score: 0.9438 - val_loss: 7.6298e-04 - val_mean_absolute_error: 0.0213 - val_mean_squared_error: 7.6298e-04 - val_r2_score: 0.9778
# Epoch 58/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0021 - mean_absolute_error: 0.0318 - mean_squared_error: 0.0021 - r2_score: 0.9438 - val_loss: 7.6166e-04 - val_mean_absolute_error: 0.0200 - val_mean_squared_error: 7.6166e-04 - val_r2_score: 0.9778
# Epoch 59/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0023 - mean_absolute_error: 0.0326 - mean_squared_error: 0.0023 - r2_score: 0.9446 - val_loss: 7.8396e-04 - val_mean_absolute_error: 0.0202 - val_mean_squared_error: 7.8396e-04 - val_r2_score: 0.9772
# Epoch 60/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0018 - mean_absolute_error: 0.0292 - mean_squared_error: 0.0018 - r2_score: 0.9477 - val_loss: 8.8462e-04 - val_mean_absolute_error: 0.0230 - val_mean_squared_error: 8.8462e-04 - val_r2_score: 0.9743
# Epoch 61/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0014 - mean_absolute_error: 0.0255 - mean_squared_error: 0.0014 - r2_score: 0.9616 - val_loss: 6.7187e-04 - val_mean_absolute_error: 0.0201 - val_mean_squared_error: 6.7187e-04 - val_r2_score: 0.9805
# Epoch 62/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0022 - mean_absolute_error: 0.0331 - mean_squared_error: 0.0022 - r2_score: 0.9400 - val_loss: 0.0010 - val_mean_absolute_error: 0.0240 - val_mean_squared_error: 0.0010 - val_r2_score: 0.9707
# Epoch 63/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0019 - mean_absolute_error: 0.0317 - mean_squared_error: 0.0019 - r2_score: 0.9540 - val_loss: 0.0024 - val_mean_absolute_error: 0.0341 - val_mean_squared_error: 0.0024 - val_r2_score: 0.9315
# Epoch 64/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0016 - mean_absolute_error: 0.0283 - mean_squared_error: 0.0016 - r2_score: 0.9482 - val_loss: 8.1801e-04 - val_mean_absolute_error: 0.0214 - val_mean_squared_error: 8.1801e-04 - val_r2_score: 0.9762
# Epoch 65/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0014 - mean_absolute_error: 0.0267 - mean_squared_error: 0.0014 - r2_score: 0.9611 - val_loss: 9.5667e-04 - val_mean_absolute_error: 0.0221 - val_mean_squared_error: 9.5667e-04 - val_r2_score: 0.9722
# Epoch 66/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0016 - mean_absolute_error: 0.0270 - mean_squared_error: 0.0016 - r2_score: 0.9543 - val_loss: 8.5817e-04 - val_mean_absolute_error: 0.0231 - val_mean_squared_error: 8.5817e-04 - val_r2_score: 0.9750
# Epoch 67/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0018 - mean_absolute_error: 0.0298 - mean_squared_error: 0.0018 - r2_score: 0.9555 - val_loss: 5.9694e-04 - val_mean_absolute_error: 0.0192 - val_mean_squared_error: 5.9694e-04 - val_r2_score: 0.9826
# Epoch 68/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0015 - mean_absolute_error: 0.0298 - mean_squared_error: 0.0015 - r2_score: 0.9554 - val_loss: 0.0026 - val_mean_absolute_error: 0.0338 - val_mean_squared_error: 0.0026 - val_r2_score: 0.9235
# Epoch 69/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0022 - mean_absolute_error: 0.0325 - mean_squared_error: 0.0022 - r2_score: 0.9370 - val_loss: 0.0010 - val_mean_absolute_error: 0.0242 - val_mean_squared_error: 0.0010 - val_r2_score: 0.9695
# Epoch 70/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0019 - mean_absolute_error: 0.0301 - mean_squared_error: 0.0019 - r2_score: 0.9440 - val_loss: 6.7313e-04 - val_mean_absolute_error: 0.0194 - val_mean_squared_error: 6.7313e-04 - val_r2_score: 0.9804
# Epoch 71/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0019 - mean_absolute_error: 0.0316 - mean_squared_error: 0.0019 - r2_score: 0.9507 - val_loss: 0.0011 - val_mean_absolute_error: 0.0241 - val_mean_squared_error: 0.0011 - val_r2_score: 0.9694
# Epoch 72/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0014 - mean_absolute_error: 0.0277 - mean_squared_error: 0.0014 - r2_score: 0.9629 - val_loss: 9.7788e-04 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 9.7788e-04 - val_r2_score: 0.9716
# Epoch 73/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0016 - mean_absolute_error: 0.0271 - mean_squared_error: 0.0016 - r2_score: 0.9571 - val_loss: 0.0010 - val_mean_absolute_error: 0.0229 - val_mean_squared_error: 0.0010 - val_r2_score: 0.9699
# Epoch 74/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0019 - mean_absolute_error: 0.0274 - mean_squared_error: 0.0019 - r2_score: 0.9522 - val_loss: 6.2250e-04 - val_mean_absolute_error: 0.0193 - val_mean_squared_error: 6.2250e-04 - val_r2_score: 0.9819
# Epoch 75/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0011 - mean_absolute_error: 0.0232 - mean_squared_error: 0.0011 - r2_score: 0.9703 - val_loss: 7.4761e-04 - val_mean_absolute_error: 0.0209 - val_mean_squared_error: 7.4761e-04 - val_r2_score: 0.9783
# Epoch 76/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0014 - mean_absolute_error: 0.0263 - mean_squared_error: 0.0014 - r2_score: 0.9631 - val_loss: 0.0011 - val_mean_absolute_error: 0.0258 - val_mean_squared_error: 0.0011 - val_r2_score: 0.9675
# Epoch 77/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0015 - mean_absolute_error: 0.0256 - mean_squared_error: 0.0015 - r2_score: 0.9569 - val_loss: 0.0019 - val_mean_absolute_error: 0.0276 - val_mean_squared_error: 0.0019 - val_r2_score: 0.9451
# Epoch 78/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0019 - mean_absolute_error: 0.0303 - mean_squared_error: 0.0019 - r2_score: 0.9526 - val_loss: 0.0015 - val_mean_absolute_error: 0.0291 - val_mean_squared_error: 0.0015 - val_r2_score: 0.9562
# Epoch 79/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0016 - mean_absolute_error: 0.0283 - mean_squared_error: 0.0016 - r2_score: 0.9547 - val_loss: 7.4332e-04 - val_mean_absolute_error: 0.0204 - val_mean_squared_error: 7.4332e-04 - val_r2_score: 0.9784
# Epoch 80/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0013 - mean_absolute_error: 0.0250 - mean_squared_error: 0.0013 - r2_score: 0.9644 - val_loss: 8.1460e-04 - val_mean_absolute_error: 0.0221 - val_mean_squared_error: 8.1460e-04 - val_r2_score: 0.9763
# Epoch 81/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0012 - mean_absolute_error: 0.0249 - mean_squared_error: 0.0012 - r2_score: 0.9688 - val_loss: 5.4806e-04 - val_mean_absolute_error: 0.0179 - val_mean_squared_error: 5.4806e-04 - val_r2_score: 0.9841
# Epoch 82/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0013 - mean_absolute_error: 0.0263 - mean_squared_error: 0.0013 - r2_score: 0.9677 - val_loss: 8.1534e-04 - val_mean_absolute_error: 0.0220 - val_mean_squared_error: 8.1534e-04 - val_r2_score: 0.9763
# Epoch 83/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0012 - mean_absolute_error: 0.0252 - mean_squared_error: 0.0012 - r2_score: 0.9655 - val_loss: 6.7639e-04 - val_mean_absolute_error: 0.0212 - val_mean_squared_error: 6.7639e-04 - val_r2_score: 0.9803
# Epoch 84/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0012 - mean_absolute_error: 0.0241 - mean_squared_error: 0.0012 - r2_score: 0.9659 - val_loss: 0.0015 - val_mean_absolute_error: 0.0256 - val_mean_squared_error: 0.0015 - val_r2_score: 0.9571
# Epoch 85/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0014 - mean_absolute_error: 0.0263 - mean_squared_error: 0.0014 - r2_score: 0.9634 - val_loss: 0.0020 - val_mean_absolute_error: 0.0338 - val_mean_squared_error: 0.0020 - val_r2_score: 0.9417
# Epoch 86/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0015 - mean_absolute_error: 0.0289 - mean_squared_error: 0.0015 - r2_score: 0.9589 - val_loss: 0.0013 - val_mean_absolute_error: 0.0245 - val_mean_squared_error: 0.0013 - val_r2_score: 0.9617
# Epoch 87/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0014 - mean_absolute_error: 0.0267 - mean_squared_error: 0.0014 - r2_score: 0.9599 - val_loss: 0.0011 - val_mean_absolute_error: 0.0248 - val_mean_squared_error: 0.0011 - val_r2_score: 0.9692
# Epoch 88/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0014 - mean_absolute_error: 0.0259 - mean_squared_error: 0.0014 - r2_score: 0.9616 - val_loss: 5.7455e-04 - val_mean_absolute_error: 0.0178 - val_mean_squared_error: 5.7455e-04 - val_r2_score: 0.9833
# Epoch 89/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0011 - mean_absolute_error: 0.0233 - mean_squared_error: 0.0011 - r2_score: 0.9695 - val_loss: 6.7063e-04 - val_mean_absolute_error: 0.0205 - val_mean_squared_error: 6.7063e-04 - val_r2_score: 0.9805
# Epoch 90/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0015 - mean_absolute_error: 0.0269 - mean_squared_error: 0.0015 - r2_score: 0.9625 - val_loss: 6.6318e-04 - val_mean_absolute_error: 0.0188 - val_mean_squared_error: 6.6318e-04 - val_r2_score: 0.9807
# Epoch 91/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0014 - mean_absolute_error: 0.0267 - mean_squared_error: 0.0014 - r2_score: 0.9645 - val_loss: 6.5611e-04 - val_mean_absolute_error: 0.0207 - val_mean_squared_error: 6.5611e-04 - val_r2_score: 0.9809
# Epoch 92/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 9.9922e-04 - mean_absolute_error: 0.0218 - mean_squared_error: 9.9922e-04 - r2_score: 0.9729 - val_loss: 5.3750e-04 - val_mean_absolute_error: 0.0180 - val_mean_squared_error: 5.3750e-04 - val_r2_score: 0.9844
# Epoch 93/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0014 - mean_absolute_error: 0.0265 - mean_squared_error: 0.0014 - r2_score: 0.9597 - val_loss: 5.6953e-04 - val_mean_absolute_error: 0.0177 - val_mean_squared_error: 5.6953e-04 - val_r2_score: 0.9834
# Epoch 94/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0013 - mean_absolute_error: 0.0243 - mean_squared_error: 0.0013 - r2_score: 0.9663 - val_loss: 6.8448e-04 - val_mean_absolute_error: 0.0195 - val_mean_squared_error: 6.8448e-04 - val_r2_score: 0.9801
# Epoch 95/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0013 - mean_absolute_error: 0.0252 - mean_squared_error: 0.0013 - r2_score: 0.9650 - val_loss: 9.9186e-04 - val_mean_absolute_error: 0.0228 - val_mean_squared_error: 9.9186e-04 - val_r2_score: 0.9712
# Epoch 96/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0013 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0013 - r2_score: 0.9641 - val_loss: 7.9702e-04 - val_mean_absolute_error: 0.0208 - val_mean_squared_error: 7.9702e-04 - val_r2_score: 0.9768
# Epoch 97/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0011 - mean_absolute_error: 0.0247 - mean_squared_error: 0.0011 - r2_score: 0.9692 - val_loss: 0.0011 - val_mean_absolute_error: 0.0238 - val_mean_squared_error: 0.0011 - val_r2_score: 0.9677
# Epoch 98/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0012 - mean_absolute_error: 0.0255 - mean_squared_error: 0.0012 - r2_score: 0.9704 - val_loss: 8.9040e-04 - val_mean_absolute_error: 0.0219 - val_mean_squared_error: 8.9040e-04 - val_r2_score: 0.9741
# Epoch 99/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0010 - mean_absolute_error: 0.0235 - mean_squared_error: 0.0010 - r2_score: 0.9659 - val_loss: 6.8953e-04 - val_mean_absolute_error: 0.0199 - val_mean_squared_error: 6.8953e-04 - val_r2_score: 0.9799
# Epoch 100/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 9.9366e-04 - mean_absolute_error: 0.0244 - mean_squared_error: 9.9366e-04 - r2_score: 0.9773 - val_loss: 0.0011 - val_mean_absolute_error: 0.0237 - val_mean_squared_error: 0.0011 - val_r2_score: 0.9684

# %%
y_pred_scaled = best_model.predict(X_test)
y_pred = scaler_y.inverse_transform(y_pred_scaled).ravel()
y_actual = scaler_y.inverse_transform(y_test.reshape(-1, 1)).ravel()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 223ms/step

# %%
mae = mean_absolute_error(y_actual, y_pred)
rmse = np.sqrt(mean_squared_error(y_actual, y_pred))
r2 = r2_score(y_actual, y_pred)

# %%
print(f"LSTM: MAE={mae:.2f}, RMSE={rmse:.2f}, R2={r2:.2f}")
# Out:
# LSTM: MAE=912272.19, RMSE=1690116.71, R2=0.89

# %%
last_dates = time_series.index[-len(y_test):]
plt.figure(figsize=(12, 6))
plt.plot(last_dates, y_pred, label='LSTM Predicted', color='blue')
plt.plot(last_dates, y_actual, label='Actual', color='black', linewidth=2)
plt.title('Prediksi vs Aktual (LSTM)')
plt.xlabel('Tanggal')
plt.ylabel('Nilai')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training dan Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(history.history['r2_score'], label='Training R2-score')
plt.plot(history.history['val_r2_score'], label='Validation R2-score')
plt.title('Training dan Validation R2-score')
plt.xlabel('Epoch')
plt.ylabel('R2-Score')
plt.legend()
plt.grid()
plt.show()

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
import holidays
import matplotlib.pyplot as plt

def prepare_inference_data(time_series, window=7, scaler_X=None):
    """
    Prepare the latest data for inference by creating lag features and scaling.

    Parameters:
    - time_series: DataFrame with columns ['revenue', 'rollingAvg7d', 'is_holiday', 'is_payday', 'is_weekend']
    - window: Number of lag days (default=7)
    - scaler_X: Fitted MinMaxScaler for features

    Returns:
    - X_scaled: Scaled input features for prediction
    - last_index: Index of the last data point
    """
    # Validate required columns
    required_columns = ['revenue', 'rollingAvg7d', 'is_holiday', 'is_payday', 'is_weekend']
    if not all(col in time_series.columns for col in required_columns):
        raise ValueError("Time series missing required columns")

    # Get the last window+1 rows
    df = time_series.tail(window + 1).copy()

    # Extract features for the last data point
    lag_features = df['revenue'].values[-window:]
    payday = df['is_payday'].values[-1]
    holiday = df['is_holiday'].values[-1]
    weekend = df['is_weekend'].values[-1]
    rolling_avg_7d = df['rollingAvg7d'].values[-1]

    # Combine features
    full_feature = list(lag_features) + [payday, holiday, weekend, rolling_avg_7d]

    # Create DataFrame for features
    X = pd.DataFrame([full_feature], columns=[f'lag_{i}' for i in range(window)] +
                     ['is_payday', 'is_holiday', 'is_weekend', 'rollingAvg7d'])

    # Scale features
    X_scaled = scaler_X.transform(X)
    X_scaled = X_scaled.reshape((X_scaled.shape[0], X_scaled.shape[1], 1))

    return X_scaled, df.index[-1]

def predict_next_day(model, time_series, window=7, scaler_X=None, scaler_y=None):
    """
    Predict the revenue for the next day using the trained model.

    Parameters:
    - model: Trained Keras model
    - time_series: DataFrame with historical data
    - window: Number of lag days (default=7)
    - scaler_X: Fitted MinMaxScaler for features
    - scaler_y: Fitted MinMaxScaler for target

    Returns:
    - prediction: Predicted revenue (unscaled)
    - prediction_date: Date of the prediction
    """
    # Prepare data
    X_scaled, last_index = prepare_inference_data(time_series, window, scaler_X)

    # Make prediction
    y_pred_scaled = model.predict(X_scaled, verbose=0)

    # Inverse transform
    y_pred = scaler_y.inverse_transform(y_pred_scaled).ravel()[0]

    # Calculate next day's date
    prediction_date = last_index + pd.Timedelta(days=1)

    return y_pred, prediction_date

def update_time_series_for_next_day(time_series, predicted_revenue, next_date, id_holidays):
    """
    Update time_series with the predicted revenue and new features.

    Parameters:
    - time_series: Original DataFrame
    - predicted_revenue: Predicted revenue
    - next_date: Date for the prediction
    - id_holidays: holidays.Indonesia object

    Returns:
    - Updated time_series
    """
    # Create new row
    new_row = pd.DataFrame({
        'revenue': [predicted_revenue],
        'is_holiday': [int(next_date in id_holidays)],
        'is_payday': [int(next_date.day in [1, 2, 3, 4, 5])],
        'is_weekend': [int(next_date.weekday() in [5, 6])]
    }, index=[next_date])

    # Append new row
    time_series = pd.concat([time_series, new_row])

    # Update rolling average
    time_series['rollingAvg7d'] = time_series['revenue'].rolling(window=7, min_periods=1).mean()

    return time_series

def predict_7_days(model, time_series, window=7, scaler_X=None, scaler_y=None, id_holidays=None):
    """
    Predict revenue for the next 7 days and update time_series iteratively.

    Parameters:
    - model: Trained Keras model
    - time_series: DataFrame with historical data
    - window: Number of lag days (default=7)
    - scaler_X: Fitted MinMaxScaler for features
    - scaler_y: Fitted MinMaxScaler for target
    - id_holidays: holidays.Indonesia object

    Returns:
    - predictions: DataFrame with dates and predicted revenues
    - updated_time_series: Updated time_series with predictions
    """
    predictions = []
    updated_time_series = time_series.copy()

    for _ in range(7):
        # Predict next day
        pred_revenue, pred_date = predict_next_day(
            model=model,
            time_series=updated_time_series,
            window=window,
            scaler_X=scaler_X,
            scaler_y=scaler_y
        )

        # Store prediction
        predictions.append({'date': pred_date, 'revenue': pred_revenue})

        # Update time_series
        updated_time_series = update_time_series_for_next_day(
            time_series=updated_time_series,
            predicted_revenue=pred_revenue,
            next_date=pred_date,
            id_holidays=id_holidays
        )

    # Convert predictions to DataFrame
    predictions_df = pd.DataFrame(predictions)
    predictions_df['date'] = pd.to_datetime(predictions_df['date'])
    predictions_df.set_index('date', inplace=True)

    return predictions_df, updated_time_series

# Example usage
# Prerequisites:
# - best_model: Trained Keras model
# - time_series: DataFrame with historical data
# - scaler_X: Fitted MinMaxScaler for features
# - scaler_y: Fitted MinMaxScaler for target
# - id_holidays: holidays.Indonesia(years=[2024, 2025])

# Predict 7 days
predictions_df, time_series_updated = predict_7_days(
    model=best_model,
    time_series=time_series,
    window=7,
    scaler_X=scaler_X,
    scaler_y=scaler_y,
    id_holidays=id_holidays
)

# %%
# Combine historical and predicted data for plotting
historical_data = time_series.tail(30)  # Last 30 days of historical data
combined_data = pd.concat([historical_data['revenue'], predictions_df['revenue']])

# Visualize historical and predicted revenue with smooth transition
plt.figure(figsize=(12, 6))
plt.plot(combined_data.index, combined_data.values, label='Revenue', color='blue', marker='o')

# Highlight the transition with a vertical line (optional)
last_historical_date = historical_data.index[-1]

plt.axvline(x=last_historical_date, color='gray', linestyle='--', label='Historical to Predicted')
plt.title('Revenue: Historical dan 7-Day Forecast')
plt.xlabel('Date')
plt.ylabel('Revenue')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Display predictions and updated time_series
print("Predicted revenue for the next 7 days:")
print(predictions_df)
print("\nUpdated time_series tail:")
print(time_series_updated.tail(7))
# Out:
# Predicted revenue for the next 7 days:
#                revenue
# date
# 2025-05-03  11307921.0
# 2025-05-04  14397615.0
# 2025-05-05  15475182.0
# 2025-05-06  10167862.0
# 2025-05-07   4308314.0
# 2025-05-08   1964763.5
# 2025-05-09   3032938.5
#
# Updated time_series tail:
#                revenue  rollingAvg7d  is_holiday  is_payday  is_weekend
# 2025-05-03  11307921.0  7.991892e+06           0          1           1
# 2025-05-04  14397615.0  8.693785e+06           0          1           1
# 2025-05-05  15475182.0  1.060634e+07           0          1           0
# 2025-05-06  10167862.0  1.172365e+07           0          0           0
# 2025-05-07   4308314.0  1.208251e+07           0          0           0
# 2025-05-08   1964763.5  1.175941e+07           0          0           0
# 2025-05-09   3032938.5  8.664942e+06           0          0           0

# %% [markdown]
# ## Modeling (LR, DT, RF, KNN, MLP, Boost)

# %%
models = {
    'Linear Regression': LinearRegression(),
    'Decision Tree': DecisionTreeRegressor(),
    'Random Forest': RandomForestRegressor(),
    'KNN': KNeighborsRegressor(),
    'MLP': MLPRegressor(max_iter=1000),
    'Gradient Boost': GradientBoostingRegressor()
}

results = {}

for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred_scaled = model.predict(X_test)

    y_pred = scaler_y.inverse_transform(y_pred_scaled.reshape(-1, 1)).ravel()
    y_actual = scaler_y.inverse_transform(y_test.reshape(-1, 1)).ravel()

    results[name] = {'predicted': y_pred, 'actual': y_actual}

# %%
last_dates = time_series.index[-7:]

plt.figure(figsize=(12,6))
for name, res in results.items():
    plt.plot(last_dates, res['predicted'], label=f'{name} Predicted')
plt.plot(last_dates, results['Linear Regression']['actual'], label='Actual', linewidth=2, color='black')
plt.legend()
plt.title('Prediksi vs Aktual (7 Hari Terakhir)')
plt.xlabel('Tanggal')
plt.ylabel('Nilai')
plt.grid()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

for name, res in results.items():
    y_true = res['actual']
    y_pred = res['predicted']
    print(f"{name}: MAE={mean_absolute_error(y_true, y_pred):.2f}, RMSE={mean_squared_error(y_true, y_pred):.2f}, R2={r2_score(y_true, y_pred):.2f}")

# %% [markdown]
# ## Membangun model prediksi menggunakan prophet

# %%
from prophet import Prophet

prophet_df = time_series.reset_index()[['date', 'revenue']].rename(columns={
    'date': 'ds',
    'revenue': 'y'
})

test_days = 7
train_df = prophet_df.iloc[:-test_days].copy()
test_df = prophet_df.iloc[-test_days:].copy()

model = Prophet(
    yearly_seasonality=True,
    weekly_seasonality=True,
    daily_seasonality=True,
    growth='linear'
)

model.add_country_holidays(country_name='ID')

model.add_regressor('is_payday')
model.add_regressor('is_weekend')
model.add_regressor('is_holiday')

prophet_df['is_payday'] = time_series['is_payday'].values
prophet_df['is_weekend'] = time_series['is_weekend'].values
prophet_df['is_holiday'] = time_series['is_holiday'].values

# %%
prophet_df

# %%
model.fit(prophet_df)

# %%
future_dates = model.make_future_dataframe(periods=7, freq='D')

future_dates['is_payday'] = future_dates['ds'].dt.day.isin([1, 2, 3, 4, 5]).astype(int)
future_dates['is_weekend'] = future_dates['ds'].dt.dayofweek.isin([5, 6]).astype(int)
future_dates['is_holiday'] = future_dates['ds'].isin(id_holidays).astype(int)

# %%
forecast = model.predict(future_dates)

# %%
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(7)

# %%
test_forecast = forecast[forecast['ds'].isin(test_df['ds'])][['ds', 'yhat', 'yhat_lower', 'yhat_upper']]
eval_df = test_forecast.merge(test_df[['ds', 'y']], on='ds')

# %%
mae = mean_absolute_error(eval_df['y'], eval_df['yhat'])
rmse = np.sqrt(mean_squared_error(eval_df['y'], eval_df['yhat']))
mape = np.mean(np.abs((eval_df['y'] - eval_df['yhat']) / eval_df['y'])) * 100
r2_score = r2_score(eval_df['y'], eval_df['yhat'])

# %%
print("\nMetrik Evaluasi pada Data Test:")
print(f'MAE: {mae:.2f}')
print(f'RMSE: {rmse:.2f}')
print(f'MAPE: {mape:.2f}%')
print(f'R2 Score: {r2_score:.2f}%')

# %%
plt.figure(figsize=(10, 6))
plt.plot(train_df['ds'], train_df['y'], label='Data Train', color='blue', alpha=0.5)
plt.plot(test_df['ds'], test_df['y'], label='Data Test (Aktual)', color='green', marker='x')
plt.plot(test_forecast['ds'], test_forecast['yhat'], label='Prediksi Test', color='red', marker='o')
plt.fill_between(test_forecast['ds'],
                 test_forecast['yhat_lower'],
                 test_forecast['yhat_upper'],
                 color='red', alpha=0.1, label='Interval Kepercayaan')

plt.title('Prediksi vs Aktual (Prophet)')
plt.xlabel('Tanggal')
plt.ylabel('Revenue')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
fig = model.plot(forecast)
plt.title('Prediksi dengan Prophet (7 Hari Terakhir)')
plt.xlabel('Tanggal')
plt.ylabel('Nilai Prediksi')
plt.show()
