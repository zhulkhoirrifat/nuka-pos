# %% [markdown]
# <a href="https://colab.research.google.com/github/zhulkhoirrifat/nuka-pos/blob/main/TimeSeriesMinimarket.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install keras_tuner
# Out:
# Requirement already satisfied: keras_tuner in /usr/local/lib/python3.11/dist-packages (1.4.7)
# Requirement already satisfied: keras in /usr/local/lib/python3.11/dist-packages (from keras_tuner) (3.8.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from keras_tuner) (24.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from keras_tuner) (2.32.3)
# Requirement already satisfied: kt-legacy in /usr/local/lib/python3.11/dist-packages (from keras_tuner) (1.0.5)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from keras->keras_tuner) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from keras->keras_tuner) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras->keras_tuner) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras->keras_tuner) (0.0.9)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from keras->keras_tuner) (3.13.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras->keras_tuner) (0.15.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.11/dist-packages (from keras->keras_tuner) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->keras_tuner) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->keras_tuner) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->keras_tuner) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->keras_tuner) (2025.4.26)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from optree->keras->keras_tuner) (4.13.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras->keras_tuner) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras->keras_tuner) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras->keras_tuner) (0.1.2)

# %% [markdown]
# ## Import Library
#
# Langkah pertama adalah mengimpor library yang dibutuhkan untuk proses data dan machine learning.
#
# - `pandas` dan `numpy` untuk manipulasi data
# - `matplotlib` dan `seaborn` untuk visualisasi
# - `sklearn` untuk preprocessing dan model ML

# %%
import os
import holidays
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split, GridSearchCV, TimeSeriesSplit
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

import keras_tuner as kt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Bidirectional, LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import R2Score, MeanSquaredError, MeanAbsoluteError

# %% [markdown]
# ## Load dan Persiapan Data
#
# Dataset diambil dari file CSV. Setelah itu, dilakukan pengecekan awal seperti:
# - Menampilkan 5 data teratas
# - Melihat tipe data dan jumlah missing values
# - Menampilkan statistik deskriptif
# - Menghapus kolom yang tidak relevan
# - Mengubah tipe data jika diperlukan

# %%
products_df = pd.read_csv('products.csv')
transactions_df = pd.read_csv('transactions.csv')
transaction_details_df = pd.read_csv('transaction_details.csv')
stores_df = pd.read_csv('stores.csv')

# %%
transactions_df = transactions_df.rename(columns={
    'discount': 'discountPerson',
    'status': 'statusTransaction'
})
products_df = products_df.rename(columns={
    'name': 'productName',
    'description': 'descriptionProduct',
    'discount': 'productDiscount'
})
stores_df = stores_df.rename(columns={
    'name': 'storeName',
    'description': 'storeDescription',
    'status': 'storeStatus'
})

# %%
transactions_transaction_details_merge = pd.merge(
    transactions_df,
    transaction_details_df,
    on='transactionId',
    how='left'
)

transactions_products_merge = pd.merge(
    transactions_transaction_details_merge,
    products_df,
    on='productId',
    how='left'
)

final_df = pd.merge(
    transactions_products_merge,
    stores_df,
    on='storeId',
    how='left'
)

# %%
final_df.columns
# Out:
# Index(['transactionId', 'invoiceId', 'customerId', 'userId', 'storeId',
#        'paymentMethodId', 'totalAmount', 'cash', 'change', 'discountPerson',
#        'transactionDate', 'statusTransaction', 'transactionDetailId',
#        'productId', 'variantId', 'quantity', 'subtotal', 'productCode',
#        'serialNumber', 'categoryId', 'productName', 'descriptionProduct',
#        'productDiscount', 'basePrice', 'imageUrl', 'isActive', 'StoreCode',
#        'tenantId', 'storeName', 'address', 'email', 'image', 'provinceId',
#        'cityId', 'districtId', 'villageId', 'storeTypeId', 'postalCode',
#        'storeDescription', 'phoneNumber', 'logo', 'permitCertificate',
#        'storeStatus'],
#       dtype='object')

# %%
final_df
# Out:
#         transactionId         invoiceId  customerId  userId  storeId  \
# 0                   1  INV-872171080156      2747.0      62        1
# 1                   1  INV-872171080156      2747.0      62        1
# 2                   2  INV-763345515943       728.0      93        1
# 3                   3  INV-605821091171       870.0      93        1
# 4                   4  INV-411881317458       576.0      93        1
# ...               ...               ...         ...     ...      ...
# 863741         719918  INV-356748409675         NaN      85       30
# 863742         719918  INV-356748409675         NaN      85       30
# 863743         719919  INV-147944059303      4440.0     141       30
# 863744         719920  INV-136116470389       553.0     141       30
# 863745         719920  INV-136116470389       553.0     141       30
#
#         paymentMethodId  totalAmount           cash      change  \
# 0                     4    200000.00  200433.016175  433.016175
# 1                     4    200000.00  200433.016175  433.016175
# 2                     5    200000.00  200976.280882  976.280882
# 3                     1     31300.04   31967.037563  666.997563
# 4                     4     41220.04   41872.546596  652.506596
# ...                 ...          ...            ...         ...
# 863741                4    100000.00  100948.727097  948.727097
# 863742                4    100000.00  100948.727097  948.727097
# 863743                1    100000.00  100327.066901  327.066901
# 863744                7    100000.00  100947.831102  947.831102
# 863745                7    100000.00  100947.831102  947.831102
#
#         discountPerson  ... cityId districtId  villageId  storeTypeId  \
# 0                    0  ...     71       5579      62968            9
# 1                    0  ...     71       5579      62968            9
# 2                    5  ...     71       5579      62968            9
# 3                    5  ...     71       5579      62968            9
# 4                   10  ...     71       5579      62968            9
# ...                ...  ...    ...        ...        ...          ...
# 863741               0  ...     71       5579      62968           12
# 863742               0  ...     71       5579      62968           12
# 863743               0  ...     71       5579      62968           12
# 863744               0  ...     71       5579      62968           12
# 863745               0  ...     71       5579      62968           12
#
#         postalCode                                   storeDescription  \
# 0            35215  Facere eos dignissimos architecto dolor laboru...
# 1            35215  Facere eos dignissimos architecto dolor laboru...
# 2            35215  Facere eos dignissimos architecto dolor laboru...
# 3            35215  Facere eos dignissimos architecto dolor laboru...
# 4            35215  Facere eos dignissimos architecto dolor laboru...
# ...            ...                                                ...
# 863741        2970  Blanditiis repudiandae eius excepturi. Totam m...
# 863742        2970  Blanditiis repudiandae eius excepturi. Totam m...
# 863743        2970  Blanditiis repudiandae eius excepturi. Totam m...
# 863744        2970  Blanditiis repudiandae eius excepturi. Totam m...
# 863745        2970  Blanditiis repudiandae eius excepturi. Totam m...
#
#          phoneNumber                            logo  \
# 0       628143540196  https://dummyimage.com/638x822
# 1       628143540196  https://dummyimage.com/638x822
# 2       628143540196  https://dummyimage.com/638x822
# 3       628143540196  https://dummyimage.com/638x822
# 4       628143540196  https://dummyimage.com/638x822
# ...              ...                             ...
# 863741  628582519226  https://placekitten.com/78/988
# 863742  628582519226  https://placekitten.com/78/988
# 863743  628582519226  https://placekitten.com/78/988
# 863744  628582519226  https://placekitten.com/78/988
# 863745  628582519226  https://placekitten.com/78/988
#
#                      permitCertificate  storeStatus
# 0        https://picsum.photos/923/384       ACTIVE
# 1        https://picsum.photos/923/384       ACTIVE
# 2        https://picsum.photos/923/384       ACTIVE
# 3        https://picsum.photos/923/384       ACTIVE
# 4        https://picsum.photos/923/384       ACTIVE
# ...                                ...          ...
# 863741  https://placekitten.com/715/72       ACTIVE
# 863742  https://placekitten.com/715/72       ACTIVE
# 863743  https://placekitten.com/715/72       ACTIVE
# 863744  https://placekitten.com/715/72       ACTIVE
# 863745  https://placekitten.com/715/72       ACTIVE
#
# [863746 rows x 43 columns]

# %%
store_type_id = 9
final_df = final_df[final_df['storeTypeId'] == store_type_id]
final_df
# Out:
#         transactionId         invoiceId  customerId  userId  storeId  \
# 0                   1  INV-872171080156      2747.0      62        1
# 1                   1  INV-872171080156      2747.0      62        1
# 2                   2  INV-763345515943       728.0      93        1
# 3                   3  INV-605821091171       870.0      93        1
# 4                   4  INV-411881317458       576.0      93        1
# ...               ...               ...         ...     ...      ...
# 696713         580670  INV-618957216769      3425.0      71       24
# 696714         580671  INV-934649411840      6616.0     102       24
# 696715         580672  INV-741774065882      1856.0      71       24
# 696716         580673  INV-266004092044      2934.0      71       24
# 696717         580674  INV-500314311442      2229.0      78       24
#
#         paymentMethodId  totalAmount           cash      change  \
# 0                     4    200000.00  200433.016175  433.016175
# 1                     4    200000.00  200433.016175  433.016175
# 2                     5    200000.00  200976.280882  976.280882
# 3                     1     31300.04   31967.037563  666.997563
# 4                     4     41220.04   41872.546596  652.506596
# ...                 ...          ...            ...         ...
# 696713                6    200000.00  200942.496577  942.496577
# 696714                7     12015.36   12933.187235  917.827235
# 696715                7     33992.00   34685.163886  693.163886
# 696716                5     13851.04   14331.565070  480.525070
# 696717                7     42999.04   43955.944505  956.904505
#
#         discountPerson  ... cityId districtId  villageId  storeTypeId  \
# 0                    0  ...     71       5579      62968            9
# 1                    0  ...     71       5579      62968            9
# 2                    5  ...     71       5579      62968            9
# 3                    5  ...     71       5579      62968            9
# 4                   10  ...     71       5579      62968            9
# ...                ...  ...    ...        ...        ...          ...
# 696713               0  ...     71       5783      61365            9
# 696714               0  ...     71       5783      61365            9
# 696715               0  ...     71       5783      61365            9
# 696716               0  ...     71       5783      61365            9
# 696717               0  ...     71       5783      61365            9
#
#         postalCode                                   storeDescription  \
# 0            35215  Facere eos dignissimos architecto dolor laboru...
# 1            35215  Facere eos dignissimos architecto dolor laboru...
# 2            35215  Facere eos dignissimos architecto dolor laboru...
# 3            35215  Facere eos dignissimos architecto dolor laboru...
# 4            35215  Facere eos dignissimos architecto dolor laboru...
# ...            ...                                                ...
# 696713       89002  Assumenda quibusdam doloremque voluptatum magn...
# 696714       89002  Assumenda quibusdam doloremque voluptatum magn...
# 696715       89002  Assumenda quibusdam doloremque voluptatum magn...
# 696716       89002  Assumenda quibusdam doloremque voluptatum magn...
# 696717       89002  Assumenda quibusdam doloremque voluptatum magn...
#
#          phoneNumber                            logo  \
# 0       628143540196  https://dummyimage.com/638x822
# 1       628143540196  https://dummyimage.com/638x822
# 2       628143540196  https://dummyimage.com/638x822
# 3       628143540196  https://dummyimage.com/638x822
# 4       628143540196  https://dummyimage.com/638x822
# ...              ...                             ...
# 696713  628598186962  https://dummyimage.com/732x678
# 696714  628598186962  https://dummyimage.com/732x678
# 696715  628598186962  https://dummyimage.com/732x678
# 696716  628598186962  https://dummyimage.com/732x678
# 696717  628598186962  https://dummyimage.com/732x678
#
#                       permitCertificate  storeStatus
# 0         https://picsum.photos/923/384       ACTIVE
# 1         https://picsum.photos/923/384       ACTIVE
# 2         https://picsum.photos/923/384       ACTIVE
# 3         https://picsum.photos/923/384       ACTIVE
# 4         https://picsum.photos/923/384       ACTIVE
# ...                                 ...          ...
# 696713  https://placekitten.com/166/111       ACTIVE
# 696714  https://placekitten.com/166/111       ACTIVE
# 696715  https://placekitten.com/166/111       ACTIVE
# 696716  https://placekitten.com/166/111       ACTIVE
# 696717  https://placekitten.com/166/111       ACTIVE
#
# [84670 rows x 43 columns]

# %%
final_df['storeId'].value_counts()
# Out:
# storeId
# 24    49833
# 2     23558
# 1     11279
# Name: count, dtype: int64

# %%
checked = final_df[final_df['storeId'] == 9]

checked.hist(bins=50, figsize=(20, 15))
plt.show()

# %%
final_df = final_df[final_df['storeId'] == 9]

# %%
numeric_columns = final_df.select_dtypes(include='number').columns

plt.figure(figsize=(15, 5 * len(numeric_columns)))

for index, column in enumerate(numeric_columns, 1):
    plt.subplot(len(numeric_columns), 1, index)
    sns.boxplot(x=final_df[column])
    plt.title(f'Boxplot kolom: {column}')
    plt.tight_layout()

plt.show()

# %%
def detect_outliers_iqr(data):
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return (data < lower_bound) | (data > upper_bound)

outliers = detect_outliers_iqr(final_df['totalAmount'])

print(f"Number of outliers detected: {sum(outliers)}")
# Out:
# Number of outliers detected: 0

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

ax1.scatter(range(len(final_df)), final_df['totalAmount'], c=['blue' if not x else 'red' for x in outliers])
ax1.set_title('Outlier pada totalAmount (Scatter Plot)')
ax1.set_xlabel('Index')
ax1.set_ylabel('Value')

sns.boxplot(x=final_df['totalAmount'], ax=ax2)
ax2.set_title('Outlier pada totalAmount (Box Plot)')
ax2.set_xlabel('Value')

plt.tight_layout()
plt.show()

# %%
final_df['transactionDate'] = pd.to_datetime(final_df['transactionDate'])
# Out:
# <ipython-input-19-0ea110b0c623>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['transactionDate'] = pd.to_datetime(final_df['transactionDate'])

# %%
final_df
# Out:
#         transactionId         invoiceId  customerId  userId  storeId  \
# 135815         113286  INV-601854327320      1696.0      99        9
# 135816         113287  INV-865460738290      2212.0     122        9
# 135817         113288  INV-122164698029      1918.0     108        9
# 135818         113289  INV-180626689644      3274.0      99        9
# 135819         113290  INV-809534718058         NaN     151        9
# ...               ...               ...         ...     ...      ...
# 268799         224035  INV-944927501334      4565.0      77        9
# 268800         224036  INV-833912557308      2823.0      99        9
# 268801         224037  INV-118795321427      4494.0     122        9
# 268802         224038  INV-335168418523         NaN      80        9
# 268803         224039  INV-495092114441      2562.0     122        9
#
#         paymentMethodId  totalAmount           cash      change  \
# 135815                2    106560.16  106560.160000    0.000000
# 135816                7     41753.64   41824.672669   71.032669
# 135817                1     18558.40   18753.472599  195.072599
# 135818                6    105847.84  106469.265035  621.425035
# 135819                7     63169.12   64089.547819  920.427819
# ...                 ...          ...            ...         ...
# 268799                5     54626.88   55498.976498  872.096498
# 268800                1     19325.60   19836.481150  510.881150
# 268801                7     46095.84   46199.387895  103.547895
# 268802                2     83977.00   83977.000000    0.000000
# 268803                4    106216.32  106893.182754  676.862754
#
#         discountPerson  ... cityId districtId  villageId  storeTypeId  \
# 135815               0  ...     71       5783      63284           10
# 135816              10  ...     71       5783      63284           10
# 135817               0  ...     71       5783      63284           10
# 135818               0  ...     71       5783      63284           10
# 135819               0  ...     71       5783      63284           10
# ...                ...  ...    ...        ...        ...          ...
# 268799               0  ...     71       5783      63284           10
# 268800               0  ...     71       5783      63284           10
# 268801               0  ...     71       5783      63284           10
# 268802               5  ...     71       5783      63284           10
# 268803               0  ...     71       5783      63284           10
#
#         postalCode                                   storeDescription  \
# 135815       78915  Reiciendis corrupti fugiat alias distinctio ma...
# 135816       78915  Reiciendis corrupti fugiat alias distinctio ma...
# 135817       78915  Reiciendis corrupti fugiat alias distinctio ma...
# 135818       78915  Reiciendis corrupti fugiat alias distinctio ma...
# 135819       78915  Reiciendis corrupti fugiat alias distinctio ma...
# ...            ...                                                ...
# 268799       78915  Reiciendis corrupti fugiat alias distinctio ma...
# 268800       78915  Reiciendis corrupti fugiat alias distinctio ma...
# 268801       78915  Reiciendis corrupti fugiat alias distinctio ma...
# 268802       78915  Reiciendis corrupti fugiat alias distinctio ma...
# 268803       78915  Reiciendis corrupti fugiat alias distinctio ma...
#
#          phoneNumber                            logo  \
# 135815  628110460132  https://dummyimage.com/827x621
# 135816  628110460132  https://dummyimage.com/827x621
# 135817  628110460132  https://dummyimage.com/827x621
# 135818  628110460132  https://dummyimage.com/827x621
# 135819  628110460132  https://dummyimage.com/827x621
# ...              ...                             ...
# 268799  628110460132  https://dummyimage.com/827x621
# 268800  628110460132  https://dummyimage.com/827x621
# 268801  628110460132  https://dummyimage.com/827x621
# 268802  628110460132  https://dummyimage.com/827x621
# 268803  628110460132  https://dummyimage.com/827x621
#
#                       permitCertificate  storeStatus
# 135815  https://placekitten.com/802/459       ACTIVE
# 135816  https://placekitten.com/802/459       ACTIVE
# 135817  https://placekitten.com/802/459       ACTIVE
# 135818  https://placekitten.com/802/459       ACTIVE
# 135819  https://placekitten.com/802/459       ACTIVE
# ...                                 ...          ...
# 268799  https://placekitten.com/802/459       ACTIVE
# 268800  https://placekitten.com/802/459       ACTIVE
# 268801  https://placekitten.com/802/459       ACTIVE
# 268802  https://placekitten.com/802/459       ACTIVE
# 268803  https://placekitten.com/802/459       ACTIVE
#
# [132989 rows x 43 columns]

# %% [markdown]
# ## Convert ke Time Series, Feature Engineering, dan Pre-processing
#
# Tahapan ini digunakan untuk mengubah dataset menjadi time series untuk memprediksi data historis, menambahkan fitur berbasis agregasi historis untuk meningkatkan performa model, dan pre-processing data sebelum digunakan untuk melatih model forecasting

# %%
time_series = final_df.groupby(final_df['transactionDate'].dt.date)['totalAmount'].sum().reset_index()
time_series.columns = ['date', 'revenue']
time_series['date'] = pd.to_datetime(time_series['date'])
time_series.set_index('date', inplace=True)

# %%
time_series
# Out:
#                 revenue
# date
# 2024-01-01  27002666.72
# 2024-01-02  33468910.44
# 2024-01-03  33283795.52
# 2024-01-04  32191587.00
# 2024-01-05  35836049.72
# ...                 ...
# 2025-04-28   8046936.92
# 2025-04-29   8846289.64
# 2025-04-30   6344670.40
# 2025-05-01  10757972.36
# 2025-05-02  78709936.80
#
# [488 rows x 1 columns]

# %%
plt.figure(figsize=(12, 6))
plt.plot(time_series['revenue'], label='Revenue')
plt.title('Daily Revenue (F&B)')
plt.xlabel('Date')
plt.ylabel('Revenue (Rp)')
plt.legend()
plt.show()

# %%
final_df['transactionDate']
# Out:
# 135815   2024-01-06 08:12:25
# 135816   2024-01-01 07:53:54
# 135817   2024-01-02 07:13:17
# 135818   2024-01-07 07:03:28
# 135819   2024-01-06 07:00:56
#                  ...
# 268799   2025-05-02 18:36:51
# 268800   2025-05-02 20:31:06
# 268801   2025-05-02 17:39:28
# 268802   2025-05-02 19:10:19
# 268803   2025-05-02 18:59:02
# Name: transactionDate, Length: 132989, dtype: datetime64[ns]

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plt.figure(figsize=(12, 4))
plot_acf(time_series['revenue'], lags=50)
plt.title('Autocorrelation Function (ACF)')
plt.show()

plt.figure(figsize=(12, 4))
plot_pacf(time_series['revenue'], lags=50)
plt.title('Partial Autocorrelation Function (PACF)')
plt.show()

# %%
time_series['rollingAvg7d'] = time_series['revenue'].rolling(window=7, min_periods=1).mean()

id_holidays = holidays.Indonesia(years=[2024, 2025])
time_series['is_holiday'] = time_series.index.isin(id_holidays).astype(int)
time_series['is_payday'] = time_series.index.day.isin([1, 2, 3, 4, 5]).astype(int)
time_series['is_weekend'] = time_series.index.weekday.isin([5, 6]).astype(int)

def create_lag(df, window=7):
    X, y, check_corr = [], [], []
    for i in range(window, len(df)):
        lag_features = df['revenue'].values[i-window:i]
        payday = df['is_payday'].values[i]
        holiday = df['is_holiday'].values[i]
        weekend = df['is_weekend'].values[i]
        rolling_avg_7d = df['rollingAvg7d'].values[i]

        full_feature = list(lag_features) + [payday, holiday, weekend, rolling_avg_7d]
        benchmark = full_feature + [df['revenue'].values[i]]

        X.append(full_feature)
        y.append(df['revenue'].values[i])
        check_corr.append(benchmark)

    return pd.DataFrame(X, columns=[f'lag_{i}' for i in range(window)] + ['is_payday', 'is_holiday', 'is_weekend', 'rollingAvg7d']), \
       pd.Series(y, name='target'), \
       pd.DataFrame(check_corr, columns=[f'lag_{i}' for i in range(window)] + ['is_payday', 'is_holiday', 'is_weekend', 'rollingAvg7d', 'target'])


X, y, check_corr = create_lag(time_series)
# Out:
# <ipython-input-26-1fac8aae5783>:4: FutureWarning: The behavior of 'isin' with dtype=datetime64[ns] and castable values (e.g. strings) is deprecated. In a future version, these will not be considered matching by isin. Explicitly cast to the appropriate dtype before calling isin instead.
#   time_series['is_holiday'] = time_series.index.isin(id_holidays).astype(int)

# %%
check_corr
# Out:
#            lag_0        lag_1        lag_2        lag_3        lag_4  \
# 0    27002666.72  33468910.44  33283795.52  32191587.00  35836049.72
# 1    33468910.44  33283795.52  32191587.00  35836049.72  18807071.52
# 2    33283795.52  32191587.00  35836049.72  18807071.52  22996172.84
# 3    32191587.00  35836049.72  18807071.52  22996172.84  10217675.64
# 4    35836049.72  18807071.52  22996172.84  10217675.64   8454654.76
# ..           ...          ...          ...          ...          ...
# 476   7543611.76   7127869.28   7763727.88   7895866.36  13657860.96
# 477   7127869.28   7763727.88   7895866.36  13657860.96  22382302.48
# 478   7763727.88   7895866.36  13657860.96  22382302.48  17559606.40
# 479   7895866.36  13657860.96  22382302.48  17559606.40   8046936.92
# 480  13657860.96  22382302.48  17559606.40   8046936.92   8846289.64
#
#            lag_5        lag_6  is_payday  is_holiday  is_weekend  \
# 0    18807071.52  22996172.84          0           0           0
# 1    22996172.84  10217675.64          0           0           0
# 2    10217675.64   8454654.76          0           0           0
# 3     8454654.76   8557778.48          0           0           0
# 4     8557778.48   8034153.24          0           0           0
# ..           ...          ...        ...         ...         ...
# 476  22382302.48  17559606.40          0           0           0
# 477  17559606.40   8046936.92          0           0           0
# 478   8046936.92   8846289.64          0           0           0
# 479   8846289.64   6344670.40          1           1           0
# 480   6344670.40  10757972.36          1           0           0
#
#      rollingAvg7d       target
# 0    2.668589e+07  10217675.64
# 1    2.311243e+07   8454654.76
# 2    1.958014e+07   8557778.48
# 3    1.612908e+07   8034153.24
# 4    1.258509e+07  11028110.20
# ..            ...          ...
# 476  1.206202e+07   8046936.92
# 477  1.230751e+07   8846289.64
# 478  1.210479e+07   6344670.40
# 479  1.251366e+07  10757972.36
# 480  2.180682e+07  78709936.80
#
# [481 rows x 12 columns]

# %%
corr_matrix = check_corr.corr()

plt.figure(figsize=(16, 12))

sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')

plt.title('Korelasi Antar Variabel')

plt.show()

# %%
X
# Out:
#            lag_0        lag_1        lag_2        lag_3        lag_4  \
# 0    27002666.72  33468910.44  33283795.52  32191587.00  35836049.72
# 1    33468910.44  33283795.52  32191587.00  35836049.72  18807071.52
# 2    33283795.52  32191587.00  35836049.72  18807071.52  22996172.84
# 3    32191587.00  35836049.72  18807071.52  22996172.84  10217675.64
# 4    35836049.72  18807071.52  22996172.84  10217675.64   8454654.76
# ..           ...          ...          ...          ...          ...
# 476   7543611.76   7127869.28   7763727.88   7895866.36  13657860.96
# 477   7127869.28   7763727.88   7895866.36  13657860.96  22382302.48
# 478   7763727.88   7895866.36  13657860.96  22382302.48  17559606.40
# 479   7895866.36  13657860.96  22382302.48  17559606.40   8046936.92
# 480  13657860.96  22382302.48  17559606.40   8046936.92   8846289.64
#
#            lag_5        lag_6  is_payday  is_holiday  is_weekend  rollingAvg7d
# 0    18807071.52  22996172.84          0           0           0  2.668589e+07
# 1    22996172.84  10217675.64          0           0           0  2.311243e+07
# 2    10217675.64   8454654.76          0           0           0  1.958014e+07
# 3     8454654.76   8557778.48          0           0           0  1.612908e+07
# 4     8557778.48   8034153.24          0           0           0  1.258509e+07
# ..           ...          ...        ...         ...         ...           ...
# 476  22382302.48  17559606.40          0           0           0  1.206202e+07
# 477  17559606.40   8046936.92          0           0           0  1.230751e+07
# 478   8046936.92   8846289.64          0           0           0  1.210479e+07
# 479   8846289.64   6344670.40          1           1           0  1.251366e+07
# 480   6344670.40  10757972.36          1           0           0  2.180682e+07
#
# [481 rows x 11 columns]

# %%
def save_scalers(scaler_X, scaler_y, store_type_id):
    # Buat direktori untuk tipe toko
    os.makedirs(f'/content/models/store_type_{store_type_id}', exist_ok=True)

    # Simpan scaler_X dan scaler_y
    joblib.dump(scaler_X, f'/content/models/store_type_{store_type_id}/scaler_X.pkl')
    joblib.dump(scaler_y, f'/content/models/store_type_{store_type_id}/scaler_y.pkl')

# %%
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1)).ravel()

X_scaled = X_scaled.reshape((X_scaled.shape[0], X_scaled.shape[1], 1))

# %%
save_scalers(scaler_X, scaler_y, store_type_id)

# %%
train_size = int(len(X_scaled) * 0.8)
X_train, X_test = X_scaled[:train_size], X_scaled[train_size:]
y_train, y_test = y_scaled[:train_size], y_scaled[train_size:]

# %% [markdown]
# ## Modeling

# %%
def model_builder(hp):
    model = Sequential()

    model.add(Conv1D(
        filters=hp.Int("conv_filters", min_value=32, max_value=128, step=16),
        kernel_size=hp.Int("kernel_size", min_value=2, max_value=5, step=1),
        activation='relu',
        padding='same',
        input_shape=(X_train.shape[1], X_train.shape[2])
    ))

    model.add(MaxPooling1D(pool_size=1))

    model.add(Conv1D(
        filters=hp.Int("conv_filters_2", min_value=64, max_value=256, step=16),
        kernel_size=hp.Int("kernel_size", min_value=2, max_value=5, step=1),
        activation='relu'
    ))
    model.add(MaxPooling1D(pool_size=2))

    model.add(Bidirectional(
        LSTM(
            units=hp.Int("bilstm_units", min_value=16, max_value=128, step=16),
            activation=hp.Choice("lstm_activation", ["relu", "tanh"]),
            return_sequences=True
        )
    ))
    model.add(Dropout(
        rate=hp.Float("dropout_1", min_value=0.2, max_value=0.5, step=0.1)
    ))
    model.add(LSTM(
        units=hp.Int("lstm_units", min_value=16, max_value=64, step=16),
        activation=hp.Choice("lstm2_activation", ["relu", "tanh"]),
        return_sequences=False
    ))
    model.add(Dropout(
        rate=hp.Float("dropout_2", min_value=0.2, max_value=0.5, step=0.1)
    ))

    model.add(Dense(
        units=hp.Int("dense_units", min_value=16, max_value=64, step=16),
        activation=hp.Choice("dense_activation", ["relu", "tanh"])
    ))

    model.add(Dropout(
        rate=hp.Float("dropout_3", min_value=0.2, max_value=0.5, step=0.1)
    ))

    model.add(Dense(
        units=hp.Int("dense_units_2", min_value=32, max_value=128, step=16),
        activation=hp.Choice("dense_activation", ["relu", "tanh"])
    ))

    model.add(Dense(1))

    model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error', metrics=[R2Score(), MeanSquaredError(), MeanAbsoluteError()])

    return model

# model = Sequential([
#     Bidirectional(LSTM(32, activation='relu', return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2]))),
#     Dropout(0.2),
#     LSTM(64, activation='relu', return_sequences=False),
#     Dropout(0.2),
#     Dense(32, activation='relu'),
#     Dense(1)
# ])

# %%
# !rm -rf tuner_dir/

# %%
from keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=3, mode='max', start_from_epoch=30, restore_best_weights=True)


tuner = kt.RandomSearch(
    model_builder,
    objective='val_loss',
    max_trials=20,
    executions_per_trial=1,
    directory='tuner_dir',
    project_name='lstm_tuning'
)

tuner.search(X_train, y_train, epochs=100, validation_split=0.2, callbacks=[early_stop])
# Out:
# Trial 20 Complete [00h 00m 25s]
# val_loss: 0.0029890350997447968
#
# Best val_loss So Far: 0.0005075391381978989
# Total elapsed time: 00h 10m 01s

# %%
best_hp = tuner.get_best_hyperparameters(1)[0]
print(best_hp.values)
best_model = tuner.hypermodel.build(best_hp)
# Out:
# {'conv_filters': 112, 'kernel_size': 3, 'conv_filters_2': 96, 'bilstm_units': 48, 'lstm_activation': 'tanh', 'dropout_1': 0.4, 'lstm_units': 64, 'lstm2_activation': 'tanh', 'dropout_2': 0.4, 'dense_units': 64, 'dense_activation': 'tanh', 'dropout_3': 0.2, 'dense_units_2': 112}

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_r2_score', patience=1, restore_best_weights=True)

# %%
history = best_model.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=32,
    validation_split=0.1,
    verbose=1,
    # callbacks=[early_stopping]
)
# Out:
# Epoch 1/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 119ms/step - loss: 0.0440 - mean_absolute_error: 0.1487 - mean_squared_error: 0.0440 - r2_score: -0.4084 - val_loss: 0.0189 - val_mean_absolute_error: 0.1004 - val_mean_squared_error: 0.0189 - val_r2_score: 0.3103
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0176 - mean_absolute_error: 0.0991 - mean_squared_error: 0.0176 - r2_score: 0.3618 - val_loss: 0.0096 - val_mean_absolute_error: 0.0679 - val_mean_squared_error: 0.0096 - val_r2_score: 0.6513
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0134 - mean_absolute_error: 0.0824 - mean_squared_error: 0.0134 - r2_score: 0.5299 - val_loss: 0.0060 - val_mean_absolute_error: 0.0447 - val_mean_squared_error: 0.0060 - val_r2_score: 0.7814
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0100 - mean_absolute_error: 0.0671 - mean_squared_error: 0.0100 - r2_score: 0.7269 - val_loss: 0.0042 - val_mean_absolute_error: 0.0473 - val_mean_squared_error: 0.0042 - val_r2_score: 0.8451
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0075 - mean_absolute_error: 0.0583 - mean_squared_error: 0.0075 - r2_score: 0.7738 - val_loss: 0.0025 - val_mean_absolute_error: 0.0320 - val_mean_squared_error: 0.0025 - val_r2_score: 0.9105
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0045 - mean_absolute_error: 0.0459 - mean_squared_error: 0.0045 - r2_score: 0.8443 - val_loss: 0.0028 - val_mean_absolute_error: 0.0373 - val_mean_squared_error: 0.0028 - val_r2_score: 0.8961
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0042 - mean_absolute_error: 0.0454 - mean_squared_error: 0.0042 - r2_score: 0.8106 - val_loss: 0.0017 - val_mean_absolute_error: 0.0266 - val_mean_squared_error: 0.0017 - val_r2_score: 0.9373
# Epoch 8/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0037 - mean_absolute_error: 0.0442 - mean_squared_error: 0.0037 - r2_score: 0.8812 - val_loss: 0.0022 - val_mean_absolute_error: 0.0303 - val_mean_squared_error: 0.0022 - val_r2_score: 0.9211
# Epoch 9/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0033 - mean_absolute_error: 0.0399 - mean_squared_error: 0.0033 - r2_score: 0.8873 - val_loss: 0.0043 - val_mean_absolute_error: 0.0427 - val_mean_squared_error: 0.0043 - val_r2_score: 0.8446
# Epoch 10/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0041 - mean_absolute_error: 0.0462 - mean_squared_error: 0.0041 - r2_score: 0.8666 - val_loss: 0.0028 - val_mean_absolute_error: 0.0383 - val_mean_squared_error: 0.0028 - val_r2_score: 0.8992
# Epoch 11/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0030 - mean_absolute_error: 0.0397 - mean_squared_error: 0.0030 - r2_score: 0.8987 - val_loss: 0.0015 - val_mean_absolute_error: 0.0254 - val_mean_squared_error: 0.0015 - val_r2_score: 0.9466
# Epoch 12/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0031 - mean_absolute_error: 0.0382 - mean_squared_error: 0.0031 - r2_score: 0.8945 - val_loss: 0.0011 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 0.0011 - val_r2_score: 0.9610
# Epoch 13/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0022 - mean_absolute_error: 0.0335 - mean_squared_error: 0.0022 - r2_score: 0.9234 - val_loss: 0.0012 - val_mean_absolute_error: 0.0277 - val_mean_squared_error: 0.0012 - val_r2_score: 0.9549
# Epoch 14/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0025 - mean_absolute_error: 0.0363 - mean_squared_error: 0.0025 - r2_score: 0.9253 - val_loss: 0.0012 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 0.0012 - val_r2_score: 0.9550
# Epoch 15/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0020 - mean_absolute_error: 0.0329 - mean_squared_error: 0.0020 - r2_score: 0.9236 - val_loss: 8.9330e-04 - val_mean_absolute_error: 0.0204 - val_mean_squared_error: 8.9330e-04 - val_r2_score: 0.9674
# Epoch 16/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0023 - mean_absolute_error: 0.0339 - mean_squared_error: 0.0023 - r2_score: 0.9252 - val_loss: 7.7319e-04 - val_mean_absolute_error: 0.0214 - val_mean_squared_error: 7.7319e-04 - val_r2_score: 0.9718
# Epoch 17/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0024 - mean_absolute_error: 0.0349 - mean_squared_error: 0.0024 - r2_score: 0.9211 - val_loss: 0.0012 - val_mean_absolute_error: 0.0251 - val_mean_squared_error: 0.0012 - val_r2_score: 0.9545
# Epoch 18/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0022 - mean_absolute_error: 0.0359 - mean_squared_error: 0.0022 - r2_score: 0.9272 - val_loss: 0.0015 - val_mean_absolute_error: 0.0258 - val_mean_squared_error: 0.0015 - val_r2_score: 0.9435
# Epoch 19/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0026 - mean_absolute_error: 0.0382 - mean_squared_error: 0.0026 - r2_score: 0.9202 - val_loss: 0.0010 - val_mean_absolute_error: 0.0217 - val_mean_squared_error: 0.0010 - val_r2_score: 0.9620
# Epoch 20/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0024 - mean_absolute_error: 0.0339 - mean_squared_error: 0.0024 - r2_score: 0.9256 - val_loss: 0.0013 - val_mean_absolute_error: 0.0237 - val_mean_squared_error: 0.0013 - val_r2_score: 0.9514
# Epoch 21/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0023 - mean_absolute_error: 0.0343 - mean_squared_error: 0.0023 - r2_score: 0.9200 - val_loss: 0.0018 - val_mean_absolute_error: 0.0301 - val_mean_squared_error: 0.0018 - val_r2_score: 0.9344
# Epoch 22/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0020 - mean_absolute_error: 0.0335 - mean_squared_error: 0.0020 - r2_score: 0.9253 - val_loss: 4.8374e-04 - val_mean_absolute_error: 0.0171 - val_mean_squared_error: 4.8374e-04 - val_r2_score: 0.9823
# Epoch 23/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0020 - mean_absolute_error: 0.0320 - mean_squared_error: 0.0020 - r2_score: 0.9303 - val_loss: 8.6792e-04 - val_mean_absolute_error: 0.0228 - val_mean_squared_error: 8.6792e-04 - val_r2_score: 0.9683
# Epoch 24/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0020 - mean_absolute_error: 0.0333 - mean_squared_error: 0.0020 - r2_score: 0.9305 - val_loss: 5.6165e-04 - val_mean_absolute_error: 0.0185 - val_mean_squared_error: 5.6165e-04 - val_r2_score: 0.9795
# Epoch 25/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0014 - mean_absolute_error: 0.0288 - mean_squared_error: 0.0014 - r2_score: 0.9471 - val_loss: 4.3288e-04 - val_mean_absolute_error: 0.0164 - val_mean_squared_error: 4.3288e-04 - val_r2_score: 0.9842
# Epoch 26/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0017 - mean_absolute_error: 0.0301 - mean_squared_error: 0.0017 - r2_score: 0.9354 - val_loss: 4.2578e-04 - val_mean_absolute_error: 0.0167 - val_mean_squared_error: 4.2578e-04 - val_r2_score: 0.9845
# Epoch 27/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0027 - mean_absolute_error: 0.0355 - mean_squared_error: 0.0027 - r2_score: 0.9045 - val_loss: 0.0021 - val_mean_absolute_error: 0.0313 - val_mean_squared_error: 0.0021 - val_r2_score: 0.9219
# Epoch 28/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0036 - mean_absolute_error: 0.0434 - mean_squared_error: 0.0036 - r2_score: 0.8510 - val_loss: 0.0024 - val_mean_absolute_error: 0.0358 - val_mean_squared_error: 0.0024 - val_r2_score: 0.9114
# Epoch 29/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0027 - mean_absolute_error: 0.0392 - mean_squared_error: 0.0027 - r2_score: 0.9056 - val_loss: 0.0011 - val_mean_absolute_error: 0.0222 - val_mean_squared_error: 0.0011 - val_r2_score: 0.9600
# Epoch 30/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0021 - mean_absolute_error: 0.0347 - mean_squared_error: 0.0021 - r2_score: 0.9236 - val_loss: 8.8541e-04 - val_mean_absolute_error: 0.0200 - val_mean_squared_error: 8.8541e-04 - val_r2_score: 0.9677
# Epoch 31/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0018 - mean_absolute_error: 0.0317 - mean_squared_error: 0.0018 - r2_score: 0.9412 - val_loss: 8.2913e-04 - val_mean_absolute_error: 0.0207 - val_mean_squared_error: 8.2913e-04 - val_r2_score: 0.9697
# Epoch 32/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0020 - mean_absolute_error: 0.0332 - mean_squared_error: 0.0020 - r2_score: 0.9323 - val_loss: 0.0013 - val_mean_absolute_error: 0.0247 - val_mean_squared_error: 0.0013 - val_r2_score: 0.9518
# Epoch 33/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0025 - mean_absolute_error: 0.0371 - mean_squared_error: 0.0025 - r2_score: 0.9176 - val_loss: 0.0012 - val_mean_absolute_error: 0.0287 - val_mean_squared_error: 0.0012 - val_r2_score: 0.9551
# Epoch 34/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0025 - mean_absolute_error: 0.0379 - mean_squared_error: 0.0025 - r2_score: 0.9219 - val_loss: 7.7282e-04 - val_mean_absolute_error: 0.0197 - val_mean_squared_error: 7.7282e-04 - val_r2_score: 0.9718
# Epoch 35/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0022 - mean_absolute_error: 0.0321 - mean_squared_error: 0.0022 - r2_score: 0.9136 - val_loss: 7.4332e-04 - val_mean_absolute_error: 0.0200 - val_mean_squared_error: 7.4332e-04 - val_r2_score: 0.9729
# Epoch 36/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0018 - mean_absolute_error: 0.0315 - mean_squared_error: 0.0018 - r2_score: 0.9435 - val_loss: 0.0015 - val_mean_absolute_error: 0.0267 - val_mean_squared_error: 0.0015 - val_r2_score: 0.9442
# Epoch 37/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0022 - mean_absolute_error: 0.0335 - mean_squared_error: 0.0022 - r2_score: 0.9263 - val_loss: 0.0011 - val_mean_absolute_error: 0.0225 - val_mean_squared_error: 0.0011 - val_r2_score: 0.9600
# Epoch 38/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0025 - mean_absolute_error: 0.0343 - mean_squared_error: 0.0025 - r2_score: 0.9197 - val_loss: 8.0953e-04 - val_mean_absolute_error: 0.0203 - val_mean_squared_error: 8.0953e-04 - val_r2_score: 0.9705
# Epoch 39/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0021 - mean_absolute_error: 0.0325 - mean_squared_error: 0.0021 - r2_score: 0.9275 - val_loss: 0.0012 - val_mean_absolute_error: 0.0242 - val_mean_squared_error: 0.0012 - val_r2_score: 0.9556
# Epoch 40/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0018 - mean_absolute_error: 0.0315 - mean_squared_error: 0.0018 - r2_score: 0.9424 - val_loss: 5.0416e-04 - val_mean_absolute_error: 0.0168 - val_mean_squared_error: 5.0416e-04 - val_r2_score: 0.9816
# Epoch 41/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0013 - mean_absolute_error: 0.0269 - mean_squared_error: 0.0013 - r2_score: 0.9544 - val_loss: 5.1965e-04 - val_mean_absolute_error: 0.0178 - val_mean_squared_error: 5.1965e-04 - val_r2_score: 0.9810
# Epoch 42/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0020 - mean_absolute_error: 0.0331 - mean_squared_error: 0.0020 - r2_score: 0.9287 - val_loss: 4.5820e-04 - val_mean_absolute_error: 0.0173 - val_mean_squared_error: 4.5820e-04 - val_r2_score: 0.9833
# Epoch 43/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0018 - mean_absolute_error: 0.0297 - mean_squared_error: 0.0018 - r2_score: 0.9391 - val_loss: 9.1946e-04 - val_mean_absolute_error: 0.0263 - val_mean_squared_error: 9.1946e-04 - val_r2_score: 0.9664
# Epoch 44/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0017 - mean_absolute_error: 0.0331 - mean_squared_error: 0.0017 - r2_score: 0.9293 - val_loss: 3.9408e-04 - val_mean_absolute_error: 0.0166 - val_mean_squared_error: 3.9408e-04 - val_r2_score: 0.9856
# Epoch 45/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0016 - mean_absolute_error: 0.0285 - mean_squared_error: 0.0016 - r2_score: 0.9469 - val_loss: 6.1771e-04 - val_mean_absolute_error: 0.0186 - val_mean_squared_error: 6.1771e-04 - val_r2_score: 0.9775
# Epoch 46/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0027 - mean_absolute_error: 0.0347 - mean_squared_error: 0.0027 - r2_score: 0.9119 - val_loss: 4.5414e-04 - val_mean_absolute_error: 0.0162 - val_mean_squared_error: 4.5414e-04 - val_r2_score: 0.9834
# Epoch 47/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0017 - mean_absolute_error: 0.0311 - mean_squared_error: 0.0017 - r2_score: 0.9425 - val_loss: 0.0011 - val_mean_absolute_error: 0.0230 - val_mean_squared_error: 0.0011 - val_r2_score: 0.9610
# Epoch 48/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0017 - mean_absolute_error: 0.0289 - mean_squared_error: 0.0017 - r2_score: 0.9432 - val_loss: 4.2419e-04 - val_mean_absolute_error: 0.0167 - val_mean_squared_error: 4.2419e-04 - val_r2_score: 0.9845
# Epoch 49/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0017 - mean_absolute_error: 0.0300 - mean_squared_error: 0.0017 - r2_score: 0.9404 - val_loss: 4.6678e-04 - val_mean_absolute_error: 0.0171 - val_mean_squared_error: 4.6678e-04 - val_r2_score: 0.9830
# Epoch 50/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0023 - mean_absolute_error: 0.0335 - mean_squared_error: 0.0023 - r2_score: 0.9223 - val_loss: 4.5458e-04 - val_mean_absolute_error: 0.0169 - val_mean_squared_error: 4.5458e-04 - val_r2_score: 0.9834
# Epoch 51/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0018 - mean_absolute_error: 0.0308 - mean_squared_error: 0.0018 - r2_score: 0.9416 - val_loss: 6.5775e-04 - val_mean_absolute_error: 0.0202 - val_mean_squared_error: 6.5775e-04 - val_r2_score: 0.9760
# Epoch 52/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0018 - mean_absolute_error: 0.0298 - mean_squared_error: 0.0018 - r2_score: 0.9432 - val_loss: 5.7039e-04 - val_mean_absolute_error: 0.0184 - val_mean_squared_error: 5.7039e-04 - val_r2_score: 0.9792
# Epoch 53/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0014 - mean_absolute_error: 0.0275 - mean_squared_error: 0.0014 - r2_score: 0.9521 - val_loss: 8.0460e-04 - val_mean_absolute_error: 0.0202 - val_mean_squared_error: 8.0460e-04 - val_r2_score: 0.9706
# Epoch 54/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0013 - mean_absolute_error: 0.0283 - mean_squared_error: 0.0013 - r2_score: 0.9524 - val_loss: 6.7767e-04 - val_mean_absolute_error: 0.0203 - val_mean_squared_error: 6.7767e-04 - val_r2_score: 0.9753
# Epoch 55/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0015 - mean_absolute_error: 0.0297 - mean_squared_error: 0.0015 - r2_score: 0.9452 - val_loss: 4.0560e-04 - val_mean_absolute_error: 0.0165 - val_mean_squared_error: 4.0560e-04 - val_r2_score: 0.9852
# Epoch 56/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0018 - mean_absolute_error: 0.0313 - mean_squared_error: 0.0018 - r2_score: 0.9466 - val_loss: 8.3347e-04 - val_mean_absolute_error: 0.0228 - val_mean_squared_error: 8.3347e-04 - val_r2_score: 0.9696
# Epoch 57/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0019 - mean_absolute_error: 0.0322 - mean_squared_error: 0.0019 - r2_score: 0.9401 - val_loss: 6.9256e-04 - val_mean_absolute_error: 0.0192 - val_mean_squared_error: 6.9256e-04 - val_r2_score: 0.9747
# Epoch 58/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0021 - mean_absolute_error: 0.0342 - mean_squared_error: 0.0021 - r2_score: 0.9347 - val_loss: 5.0443e-04 - val_mean_absolute_error: 0.0172 - val_mean_squared_error: 5.0443e-04 - val_r2_score: 0.9816
# Epoch 59/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0022 - mean_absolute_error: 0.0324 - mean_squared_error: 0.0022 - r2_score: 0.9216 - val_loss: 5.0157e-04 - val_mean_absolute_error: 0.0173 - val_mean_squared_error: 5.0157e-04 - val_r2_score: 0.9817
# Epoch 60/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0024 - mean_absolute_error: 0.0349 - mean_squared_error: 0.0024 - r2_score: 0.9250 - val_loss: 5.8828e-04 - val_mean_absolute_error: 0.0190 - val_mean_squared_error: 5.8828e-04 - val_r2_score: 0.9785
# Epoch 61/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0023 - mean_absolute_error: 0.0353 - mean_squared_error: 0.0023 - r2_score: 0.9207 - val_loss: 0.0011 - val_mean_absolute_error: 0.0252 - val_mean_squared_error: 0.0011 - val_r2_score: 0.9598
# Epoch 62/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0019 - mean_absolute_error: 0.0323 - mean_squared_error: 0.0019 - r2_score: 0.9331 - val_loss: 5.5204e-04 - val_mean_absolute_error: 0.0172 - val_mean_squared_error: 5.5204e-04 - val_r2_score: 0.9799
# Epoch 63/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0018 - mean_absolute_error: 0.0321 - mean_squared_error: 0.0018 - r2_score: 0.9461 - val_loss: 6.1658e-04 - val_mean_absolute_error: 0.0195 - val_mean_squared_error: 6.1658e-04 - val_r2_score: 0.9775
# Epoch 64/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0021 - mean_absolute_error: 0.0327 - mean_squared_error: 0.0021 - r2_score: 0.9366 - val_loss: 8.8702e-04 - val_mean_absolute_error: 0.0212 - val_mean_squared_error: 8.8702e-04 - val_r2_score: 0.9676
# Epoch 65/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0017 - mean_absolute_error: 0.0299 - mean_squared_error: 0.0017 - r2_score: 0.9501 - val_loss: 5.8707e-04 - val_mean_absolute_error: 0.0183 - val_mean_squared_error: 5.8707e-04 - val_r2_score: 0.9786
# Epoch 66/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0015 - mean_absolute_error: 0.0293 - mean_squared_error: 0.0015 - r2_score: 0.9421 - val_loss: 5.9925e-04 - val_mean_absolute_error: 0.0180 - val_mean_squared_error: 5.9925e-04 - val_r2_score: 0.9781
# Epoch 67/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0014 - mean_absolute_error: 0.0270 - mean_squared_error: 0.0014 - r2_score: 0.9584 - val_loss: 6.2835e-04 - val_mean_absolute_error: 0.0193 - val_mean_squared_error: 6.2835e-04 - val_r2_score: 0.9771
# Epoch 68/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0012 - mean_absolute_error: 0.0260 - mean_squared_error: 0.0012 - r2_score: 0.9607 - val_loss: 5.7459e-04 - val_mean_absolute_error: 0.0184 - val_mean_squared_error: 5.7459e-04 - val_r2_score: 0.9790
# Epoch 69/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0019 - mean_absolute_error: 0.0306 - mean_squared_error: 0.0019 - r2_score: 0.9370 - val_loss: 6.0304e-04 - val_mean_absolute_error: 0.0198 - val_mean_squared_error: 6.0304e-04 - val_r2_score: 0.9780
# Epoch 70/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0015 - mean_absolute_error: 0.0287 - mean_squared_error: 0.0015 - r2_score: 0.9497 - val_loss: 5.5203e-04 - val_mean_absolute_error: 0.0186 - val_mean_squared_error: 5.5203e-04 - val_r2_score: 0.9799
# Epoch 71/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0015 - mean_absolute_error: 0.0296 - mean_squared_error: 0.0015 - r2_score: 0.9441 - val_loss: 6.2529e-04 - val_mean_absolute_error: 0.0198 - val_mean_squared_error: 6.2529e-04 - val_r2_score: 0.9772
# Epoch 72/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0014 - mean_absolute_error: 0.0289 - mean_squared_error: 0.0014 - r2_score: 0.9551 - val_loss: 4.6735e-04 - val_mean_absolute_error: 0.0171 - val_mean_squared_error: 4.6735e-04 - val_r2_score: 0.9829
# Epoch 73/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0012 - mean_absolute_error: 0.0270 - mean_squared_error: 0.0012 - r2_score: 0.9603 - val_loss: 5.2782e-04 - val_mean_absolute_error: 0.0175 - val_mean_squared_error: 5.2782e-04 - val_r2_score: 0.9807
# Epoch 74/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0011 - mean_absolute_error: 0.0244 - mean_squared_error: 0.0011 - r2_score: 0.9625 - val_loss: 7.4667e-04 - val_mean_absolute_error: 0.0211 - val_mean_squared_error: 7.4667e-04 - val_r2_score: 0.9728
# Epoch 75/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0019 - mean_absolute_error: 0.0310 - mean_squared_error: 0.0019 - r2_score: 0.9407 - val_loss: 5.7124e-04 - val_mean_absolute_error: 0.0184 - val_mean_squared_error: 5.7124e-04 - val_r2_score: 0.9792
# Epoch 76/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0012 - mean_absolute_error: 0.0273 - mean_squared_error: 0.0012 - r2_score: 0.9564 - val_loss: 5.5312e-04 - val_mean_absolute_error: 0.0187 - val_mean_squared_error: 5.5312e-04 - val_r2_score: 0.9798
# Epoch 77/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0016 - mean_absolute_error: 0.0303 - mean_squared_error: 0.0016 - r2_score: 0.9372 - val_loss: 9.5836e-04 - val_mean_absolute_error: 0.0215 - val_mean_squared_error: 9.5836e-04 - val_r2_score: 0.9650
# Epoch 78/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0022 - mean_absolute_error: 0.0327 - mean_squared_error: 0.0022 - r2_score: 0.9301 - val_loss: 0.0011 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 0.0011 - val_r2_score: 0.9606
# Epoch 79/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0014 - mean_absolute_error: 0.0288 - mean_squared_error: 0.0014 - r2_score: 0.9459 - val_loss: 7.7615e-04 - val_mean_absolute_error: 0.0227 - val_mean_squared_error: 7.7615e-04 - val_r2_score: 0.9717
# Epoch 80/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0013 - mean_absolute_error: 0.0276 - mean_squared_error: 0.0013 - r2_score: 0.9528 - val_loss: 5.5842e-04 - val_mean_absolute_error: 0.0181 - val_mean_squared_error: 5.5842e-04 - val_r2_score: 0.9796
# Epoch 81/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0015 - mean_absolute_error: 0.0295 - mean_squared_error: 0.0015 - r2_score: 0.9498 - val_loss: 0.0011 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 0.0011 - val_r2_score: 0.9602
# Epoch 82/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0016 - mean_absolute_error: 0.0274 - mean_squared_error: 0.0016 - r2_score: 0.9494 - val_loss: 8.1184e-04 - val_mean_absolute_error: 0.0213 - val_mean_squared_error: 8.1184e-04 - val_r2_score: 0.9704
# Epoch 83/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0017 - mean_absolute_error: 0.0305 - mean_squared_error: 0.0017 - r2_score: 0.9463 - val_loss: 0.0012 - val_mean_absolute_error: 0.0235 - val_mean_squared_error: 0.0012 - val_r2_score: 0.9579
# Epoch 84/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0019 - mean_absolute_error: 0.0314 - mean_squared_error: 0.0019 - r2_score: 0.9409 - val_loss: 0.0015 - val_mean_absolute_error: 0.0264 - val_mean_squared_error: 0.0015 - val_r2_score: 0.9454
# Epoch 85/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0021 - mean_absolute_error: 0.0328 - mean_squared_error: 0.0021 - r2_score: 0.9357 - val_loss: 0.0011 - val_mean_absolute_error: 0.0251 - val_mean_squared_error: 0.0011 - val_r2_score: 0.9594
# Epoch 86/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0013 - mean_absolute_error: 0.0271 - mean_squared_error: 0.0013 - r2_score: 0.9507 - val_loss: 5.4857e-04 - val_mean_absolute_error: 0.0179 - val_mean_squared_error: 5.4857e-04 - val_r2_score: 0.9800
# Epoch 87/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0018 - mean_absolute_error: 0.0310 - mean_squared_error: 0.0018 - r2_score: 0.9417 - val_loss: 0.0014 - val_mean_absolute_error: 0.0310 - val_mean_squared_error: 0.0014 - val_r2_score: 0.9489
# Epoch 88/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0017 - mean_absolute_error: 0.0320 - mean_squared_error: 0.0017 - r2_score: 0.9488 - val_loss: 6.5454e-04 - val_mean_absolute_error: 0.0197 - val_mean_squared_error: 6.5454e-04 - val_r2_score: 0.9761
# Epoch 89/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0016 - mean_absolute_error: 0.0296 - mean_squared_error: 0.0016 - r2_score: 0.9439 - val_loss: 6.1702e-04 - val_mean_absolute_error: 0.0181 - val_mean_squared_error: 6.1702e-04 - val_r2_score: 0.9775
# Epoch 90/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0013 - mean_absolute_error: 0.0262 - mean_squared_error: 0.0013 - r2_score: 0.9577 - val_loss: 8.5249e-04 - val_mean_absolute_error: 0.0212 - val_mean_squared_error: 8.5249e-04 - val_r2_score: 0.9689
# Epoch 91/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0015 - mean_absolute_error: 0.0275 - mean_squared_error: 0.0015 - r2_score: 0.9502 - val_loss: 0.0016 - val_mean_absolute_error: 0.0269 - val_mean_squared_error: 0.0016 - val_r2_score: 0.9407
# Epoch 92/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0018 - mean_absolute_error: 0.0307 - mean_squared_error: 0.0018 - r2_score: 0.9356 - val_loss: 9.8627e-04 - val_mean_absolute_error: 0.0245 - val_mean_squared_error: 9.8627e-04 - val_r2_score: 0.9640
# Epoch 93/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0017 - mean_absolute_error: 0.0308 - mean_squared_error: 0.0017 - r2_score: 0.9463 - val_loss: 9.6071e-04 - val_mean_absolute_error: 0.0222 - val_mean_squared_error: 9.6071e-04 - val_r2_score: 0.9649
# Epoch 94/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0018 - mean_absolute_error: 0.0312 - mean_squared_error: 0.0018 - r2_score: 0.9453 - val_loss: 7.1574e-04 - val_mean_absolute_error: 0.0206 - val_mean_squared_error: 7.1574e-04 - val_r2_score: 0.9739
# Epoch 95/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0015 - mean_absolute_error: 0.0293 - mean_squared_error: 0.0015 - r2_score: 0.9543 - val_loss: 0.0011 - val_mean_absolute_error: 0.0221 - val_mean_squared_error: 0.0011 - val_r2_score: 0.9606
# Epoch 96/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0017 - mean_absolute_error: 0.0312 - mean_squared_error: 0.0017 - r2_score: 0.9445 - val_loss: 5.1041e-04 - val_mean_absolute_error: 0.0173 - val_mean_squared_error: 5.1041e-04 - val_r2_score: 0.9814
# Epoch 97/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0013 - mean_absolute_error: 0.0288 - mean_squared_error: 0.0013 - r2_score: 0.9567 - val_loss: 0.0010 - val_mean_absolute_error: 0.0219 - val_mean_squared_error: 0.0010 - val_r2_score: 0.9630
# Epoch 98/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0015 - mean_absolute_error: 0.0292 - mean_squared_error: 0.0015 - r2_score: 0.9511 - val_loss: 7.2220e-04 - val_mean_absolute_error: 0.0207 - val_mean_squared_error: 7.2220e-04 - val_r2_score: 0.9736
# Epoch 99/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0017 - mean_absolute_error: 0.0303 - mean_squared_error: 0.0017 - r2_score: 0.9444 - val_loss: 4.4206e-04 - val_mean_absolute_error: 0.0166 - val_mean_squared_error: 4.4206e-04 - val_r2_score: 0.9839
# Epoch 100/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0014 - mean_absolute_error: 0.0270 - mean_squared_error: 0.0014 - r2_score: 0.9542 - val_loss: 4.7985e-04 - val_mean_absolute_error: 0.0178 - val_mean_squared_error: 4.7985e-04 - val_r2_score: 0.9825

# %%
y_pred_scaled = best_model.predict(X_test)
y_pred = scaler_y.inverse_transform(y_pred_scaled).ravel()
y_actual = scaler_y.inverse_transform(y_test.reshape(-1, 1)).ravel()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 203ms/step

# %%
mae = mean_absolute_error(y_actual, y_pred)
rmse = np.sqrt(mean_squared_error(y_actual, y_pred))
r2 = r2_score(y_actual, y_pred)

# %%
print(f"LSTM: MAE={mae:.2f}, RMSE={rmse:.2f}, R2={r2:.2f}")
# Out:
# LSTM: MAE=2744653.89, RMSE=5801890.06, R2=0.85

# %%
last_dates = time_series.index[-len(y_test):]
plt.figure(figsize=(12, 6))
plt.plot(last_dates, y_pred, label='LSTM Predicted', color='blue')
plt.plot(last_dates, y_actual, label='Actual', color='black', linewidth=2)
plt.title('Prediksi vs Aktual (LSTM)')
plt.xlabel('Tanggal')
plt.ylabel('Nilai')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training dan Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(history.history['r2_score'], label='Training R2-score')
plt.plot(history.history['val_r2_score'], label='Validation R2-score')
plt.title('Training dan Validation R2-score')
plt.xlabel('Epoch')
plt.ylabel('R2-Score')
plt.legend()
plt.grid()
plt.show()

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
import holidays
import matplotlib.pyplot as plt

def prepare_inference_data(time_series, window=7, scaler_X=None):
    """
    Prepare the latest data for inference by creating lag features and scaling.

    Parameters:
    - time_series: DataFrame with columns ['revenue', 'rollingAvg7d', 'is_holiday', 'is_payday', 'is_weekend']
    - window: Number of lag days (default=7)
    - scaler_X: Fitted MinMaxScaler for features

    Returns:
    - X_scaled: Scaled input features for prediction
    - last_index: Index of the last data point
    """
    # Validate required columns
    required_columns = ['revenue', 'rollingAvg7d', 'is_holiday', 'is_payday', 'is_weekend']
    if not all(col in time_series.columns for col in required_columns):
        raise ValueError("Time series missing required columns")

    # Get the last window+1 rows
    df = time_series.tail(window + 1).copy()

    # Extract features for the last data point
    lag_features = df['revenue'].values[-window:]
    payday = df['is_payday'].values[-1]
    holiday = df['is_holiday'].values[-1]
    weekend = df['is_weekend'].values[-1]
    rolling_avg_7d = df['rollingAvg7d'].values[-1]

    # Combine features
    full_feature = list(lag_features) + [payday, holiday, weekend, rolling_avg_7d]

    # Create DataFrame for features
    X = pd.DataFrame([full_feature], columns=[f'lag_{i}' for i in range(window)] +
                     ['is_payday', 'is_holiday', 'is_weekend', 'rollingAvg7d'])

    # Scale features
    X_scaled = scaler_X.transform(X)
    X_scaled = X_scaled.reshape((X_scaled.shape[0], X_scaled.shape[1], 1))

    return X_scaled, df.index[-1]

def predict_next_day(model, time_series, window=7, scaler_X=None, scaler_y=None):
    """
    Predict the revenue for the next day using the trained model.

    Parameters:
    - model: Trained Keras model
    - time_series: DataFrame with historical data
    - window: Number of lag days (default=7)
    - scaler_X: Fitted MinMaxScaler for features
    - scaler_y: Fitted MinMaxScaler for target

    Returns:
    - prediction: Predicted revenue (unscaled)
    - prediction_date: Date of the prediction
    """
    # Prepare data
    X_scaled, last_index = prepare_inference_data(time_series, window, scaler_X)

    # Make prediction
    y_pred_scaled = model.predict(X_scaled, verbose=0)

    # Inverse transform
    y_pred = scaler_y.inverse_transform(y_pred_scaled).ravel()[0]

    # Calculate next day's date
    prediction_date = last_index + pd.Timedelta(days=1)

    return y_pred, prediction_date

def update_time_series_for_next_day(time_series, predicted_revenue, next_date, id_holidays):
    """
    Update time_series with the predicted revenue and new features.

    Parameters:
    - time_series: Original DataFrame
    - predicted_revenue: Predicted revenue
    - next_date: Date for the prediction
    - id_holidays: holidays.Indonesia object

    Returns:
    - Updated time_series
    """
    # Create new row
    new_row = pd.DataFrame({
        'revenue': [predicted_revenue],
        'is_holiday': [int(next_date in id_holidays)],
        'is_payday': [int(next_date.day in [1, 2, 3, 4, 5])],
        'is_weekend': [int(next_date.weekday() in [5, 6])]
    }, index=[next_date])

    # Append new row
    time_series = pd.concat([time_series, new_row])

    # Update rolling average
    time_series['rollingAvg7d'] = time_series['revenue'].rolling(window=7, min_periods=1).mean()

    return time_series

def predict_7_days(model, time_series, window=7, scaler_X=None, scaler_y=None, id_holidays=None):
    """
    Predict revenue for the next 7 days and update time_series iteratively.

    Parameters:
    - model: Trained Keras model
    - time_series: DataFrame with historical data
    - window: Number of lag days (default=7)
    - scaler_X: Fitted MinMaxScaler for features
    - scaler_y: Fitted MinMaxScaler for target
    - id_holidays: holidays.Indonesia object

    Returns:
    - predictions: DataFrame with dates and predicted revenues
    - updated_time_series: Updated time_series with predictions
    """
    predictions = []
    updated_time_series = time_series.copy()

    for _ in range(7):
        # Predict next day
        pred_revenue, pred_date = predict_next_day(
            model=model,
            time_series=updated_time_series,
            window=window,
            scaler_X=scaler_X,
            scaler_y=scaler_y
        )

        # Store prediction
        predictions.append({'date': pred_date, 'revenue': pred_revenue})

        # Update time_series
        updated_time_series = update_time_series_for_next_day(
            time_series=updated_time_series,
            predicted_revenue=pred_revenue,
            next_date=pred_date,
            id_holidays=id_holidays
        )

    # Convert predictions to DataFrame
    predictions_df = pd.DataFrame(predictions)
    predictions_df['date'] = pd.to_datetime(predictions_df['date'])
    predictions_df.set_index('date', inplace=True)

    return predictions_df, updated_time_series

# Example usage
# Prerequisites:
# - best_model: Trained Keras model
# - time_series: DataFrame with historical data
# - scaler_X: Fitted MinMaxScaler for features
# - scaler_y: Fitted MinMaxScaler for target
# - id_holidays: holidays.Indonesia(years=[2024, 2025])

# Predict 7 days
predictions_df, time_series_updated = predict_7_days(
    model=best_model,
    time_series=time_series,
    window=7,
    scaler_X=scaler_X,
    scaler_y=scaler_y,
    id_holidays=id_holidays
)

# %%
# Combine historical and predicted data for plotting
historical_data = time_series.tail(30)  # Last 30 days of historical data
combined_data = pd.concat([historical_data['revenue'], predictions_df['revenue']])

# Visualize historical and predicted revenue with smooth transition
plt.figure(figsize=(12, 6))
plt.plot(combined_data.index, combined_data.values, label='Revenue', color='blue', marker='o')

# Highlight the transition with a vertical line (optional)
last_historical_date = historical_data.index[-1]

plt.axvline(x=last_historical_date, color='gray', linestyle='--', label='Historical to Predicted')
plt.title('Revenue: Historical dan 7-Day Forecast')
plt.xlabel('Date')
plt.ylabel('Revenue')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Display predictions and updated time_series
print("Predicted revenue for the next 7 days:")
print(predictions_df)
print("\nUpdated time_series tail:")
print(time_series_updated.tail(7))
# Out:
# Predicted revenue for the next 7 days:
#                revenue
# date
# 2025-05-03  34924848.0
# 2025-05-04  48274232.0
# 2025-05-05  54920032.0
# 2025-05-06  35589452.0
# 2025-05-07  12998153.0
# 2025-05-08   5823420.5
# 2025-05-09  11758330.0
#
# Updated time_series tail:
#                revenue  rollingAvg7d  is_holiday  is_payday  is_weekend
# 2025-05-03  34924848.0  2.359861e+07           0          1           1
# 2025-05-04  48274232.0  2.798641e+07           0          1           1
# 2025-05-05  54920032.0  3.468257e+07           0          1           0
# 2025-05-06  35589452.0  3.850302e+07           0          0           0
# 2025-05-07  12998153.0  3.945352e+07           0          0           0
# 2025-05-08   5823420.5  3.874858e+07           0          0           0
# 2025-05-09  11758330.0  2.918407e+07           0          0           0

# %%
best_model.save(f'model_{store_type_id}.keras')
